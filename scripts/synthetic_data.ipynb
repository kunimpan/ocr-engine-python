# %%
from PIL import Image, ImageDraw, ImageFont
from pathlib import Path

# %% [markdown]
# ## English Uppercase

# %% [markdown]
# ### Classic method

# %%
# ระบุโฟลเดอร์ที่ต้องการอ่านไฟล์ทั้งหมด
output_folder = Path("dataset/eng_uppercase")
folder_path = Path("font/GoogleFont")
font_number = 1

# อ่านเฉพาะไฟล์ .ttf ในโฟลเดอร์และโฟลเดอร์ย่อย
for font_file in folder_path.rglob("*.ttf"):  # ลูปภายในโฟลเดอร์ font
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':  # ตรวจสอบเฉพาะไฟล์ฟอนต์
            font = ImageFont.truetype(str(font_file), 28)  # โหลดฟอนต์
            for char in "ABCDEFGHIJKLMNOPQRSTUVWXYZ":
                # สร้างโฟลเดอร์สำหรับตัวอักษร
                char_folder = output_folder / char
                char_folder.mkdir(parents=True, exist_ok=True)  # ถ้าโฟลเดอร์มีอยู่แล้ว จะไม่เกิดข้อผิดพลาด

                img = Image.new("RGB", (32, 32), "white")
                draw = ImageDraw.Draw(img)

                # คำนวณขนาดของตัวอักษรด้วย font.getbbox()
                # (left, top, right, bottom)
                bbox = font.getbbox(char)
                text_width = bbox[2] - bbox[0]
                text_height = bbox[3] - bbox[1]

                # คำนวณตำแหน่งตรงกลางของภาพ
                x = (img.width - text_width) / 2
                #y = (text_height - img.height) / 4
                #y = (img.height - text_height) / 2
    
                # วาดตัวอักษรตรงกลาง
                draw.text((x, -5), char, font=font, fill="black")
                img.save(char_folder / f"{char}_{font_number}.png")  # บันทึกภาพ
                print(f"Saved: {char_folder / f'{char}_{font_number}.png'}")
            font_number+=1

# %% [markdown]
# ### Padding method

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# กำหนดโฟลเดอร์
output_folder = Path("../data/raw_images/eng_uppercase")
folder_path = Path("../font/GoogleFont")

if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':
        try:
            font = ImageFont.truetype(str(font_file), 28)  # โหลดฟอนต์
        except Exception as e:
            print(f"Skipping font {font_file}: {e}")
            continue

        for char in "ABCDEFGHIJKLMNOPQRSTUVWXYZ":
            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / char
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y
            y_offset = ascent - bbox[3] + 1

            if(char == "Q"):
                y_offset+=1
                if(171 <= font_number <= 207):
                    y_offset+=3
                elif(217 <= font_number <= 253):
                    y_offset+=4
                elif(294 <= font_number <= 311):
                    y_offset+=3

            if(char == "J"):
                y_offset+=1
                if(171 <= font_number <= 207):
                    y_offset+=3
                elif(217 <= font_number <= 253):
                    y_offset+=4
                elif(294 <= font_number <= 311):
                    y_offset+=3
                    
            draw.text((0, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            output_path = char_folder / f"{char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")

# %% [markdown]
# ### Padding method with new font size

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# กำหนดโฟลเดอร์
output_folder = Path("../data/raw_images/eng_uppercase")
folder_path = Path("../font/GoogleFont")

if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':

        for char in "ABCDEFGHIJKLMNOPQRSTUVWXYZ":
            try:
                if(char == "Q"):
                    font = ImageFont.truetype(str(font_file), 30)
                if(char == "M" or char == "W"):
                    font = ImageFont.truetype(str(font_file), 30)
                else:
                    font = ImageFont.truetype(str(font_file), 36)
            except Exception as e:
                print(f"Skipping font {font_file}: {e}")
                continue

            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / f"{char}_U"
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y
            y_offset = ascent - bbox[3] + 1

            if(char == "J"):
                y_offset+=2
                if(1 <= font_number <= 14):
                    y_offset-=2
                elif(15 <= font_number <= 26):
                    y_offset-=2
                elif(27 <= font_number <= 49):
                    y_offset-=3
                elif(50 <= font_number <= 63):
                    y_offset+=0
                elif(64 <= font_number <= 80):
                    y_offset-=4
                elif(81 <= font_number <= 110):
                    y_offset-=3
                elif(111 <= font_number <= 122):
                    y_offset-=4
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(135 <= font_number <= 140):
                    y_offset-=1
                elif(141 <= font_number <= 158):
                    y_offset-=4
                elif(159 <= font_number <= 170):
                    y_offset-=6
                elif(171 <= font_number <= 207):
                    y_offset+=1
                elif(208 <= font_number <= 216):
                    y_offset-=4
                elif(217 <= font_number <= 253):
                    y_offset+=3
                elif(278 <= font_number <= 293):
                    y_offset-=4
                elif(294 <= font_number <= 315):
                    y_offset+=1
                elif(322 <= font_number <= 333):
                    y_offset-=2
            elif(char == "Q"):
                y_offset+=4
                if(1 <= font_number <= 14):
                    y_offset-=2
                elif(15 <= font_number <= 26):
                    y_offset-=2
                elif(27 <= font_number <= 49):
                    y_offset-=3
                elif(50 <= font_number <= 63):
                    y_offset+=0
                elif(64 <= font_number <= 80):
                    y_offset-=4
                elif(81 <= font_number <= 110):
                    y_offset-=3
                elif(111 <= font_number <= 122):
                    y_offset-=4
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(135 <= font_number <= 140):
                    y_offset-=1
                elif(141 <= font_number <= 158):
                    y_offset-=4
                elif(159 <= font_number <= 170):
                    y_offset-=6
                elif(171 <= font_number <= 207):
                    y_offset+=1
                elif(208 <= font_number <= 216):
                    y_offset-=4
                elif(217 <= font_number <= 253):
                    y_offset+=3
                elif(260 <= font_number <= 277):
                    y_offset-=4
                elif(278 <= font_number <= 293):
                    y_offset-=4
                elif(294 <= font_number <= 315):
                    y_offset+=1
                elif(322 <= font_number <= 333):
                    y_offset-=2
            else:
                if(1 <= font_number <= 14):
                    y_offset-=2
                elif(15 <= font_number <= 26):
                    y_offset-=2
                elif(27 <= font_number <= 49):
                    y_offset-=1
                elif(50 <= font_number <= 63):
                    y_offset+=1
                elif(64 <= font_number <= 80):
                    y_offset-=2
                elif(81 <= font_number <= 110):
                    y_offset-=1
                elif(111 <= font_number <= 122):
                    y_offset-=3
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(135 <= font_number <= 140):
                    y_offset-=1
                elif(141 <= font_number <= 158):
                    y_offset-=2
                elif(159 <= font_number <= 170):
                    y_offset-=4
                elif(171 <= font_number <= 207):
                    y_offset+=1
                elif(208 <= font_number <= 216):
                    y_offset-=4
                elif(217 <= font_number <= 253):
                    y_offset+=3
                elif(278 <= font_number <= 293):
                    y_offset-=4
                elif(294 <= font_number <= 315):
                    y_offset+=0
                elif(322 <= font_number <= 333):
                    y_offset-=1
                    
            draw.text((0, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            output_path = char_folder / f"{char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")

# %% [markdown]
# ## English Lowercase

# %% [markdown]
# ### Classic method

# %%
# ระบุโฟลเดอร์ที่ต้องการอ่านไฟล์ทั้งหมด
output_folder = Path("dataset/eng_lowercase")
folder_path = Path("font/GoogleFont")
font_number = 1

# อ่านเฉพาะไฟล์ .ttf ในโฟลเดอร์และโฟลเดอร์ย่อย
for font_file in folder_path.rglob("*.ttf"):  # ลูปภายในโฟลเดอร์ font
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':  # ตรวจสอบเฉพาะไฟล์ฟอนต์
            font = ImageFont.truetype(str(font_file), 28)  # โหลดฟอนต์
            for char in "abcdefghijklmnopqrstuvwxyz":
                # สร้างโฟลเดอร์สำหรับตัวอักษร
                char_folder = output_folder / char
                char_folder.mkdir(parents=True, exist_ok=True)  # ถ้าโฟลเดอร์มีอยู่แล้ว จะไม่เกิดข้อผิดพลาด

                img = Image.new("RGB", (32, 32), "white")
                draw = ImageDraw.Draw(img)

                # คำนวณขนาดของตัวอักษรด้วย font.getbbox()
                # (left, top, right, bottom)
                bbox = font.getbbox(char)
                text_width = bbox[2] - bbox[0]
                text_height = bbox[3] - bbox[1]

                # คำนวณตำแหน่งตรงกลางของภาพ
                x = (img.width - text_width) / 2
                #y = (text_height - img.height) / 4
                #y = (img.height - text_height) / 2
    
                # วาดตัวอักษรตรงกลาง
                draw.text((x, -5), char, font=font, fill="black")
                img.save(char_folder / f"{char}_{font_number}.png")  # บันทึกภาพ
                print(f"Saved: {char_folder / f'{char}_{font_number}.png'}")
            font_number+=1

# %% [markdown]
# ### Padding method

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# กำหนดโฟลเดอร์
output_folder = Path("../data/raw_images/eng_lowercase")
folder_path = Path("../font/GoogleFont")

if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':
        try:
            font = ImageFont.truetype(str(font_file), 30)  # โหลดฟอนต์
        except Exception as e:
            print(f"Skipping font {font_file}: {e}")
            continue

        for char in "abcdefghijklmnopqrstuvwxyz":
            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / char
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y ทั่วไป
            y_offset = ascent - bbox[3]

            # ปรับตำแหน่ง y_offset เฉพาะจุด

            if(char == "b" or char == "d" or char == "h" or char == "k" or char == "l" or char == "t"):
                if(171 <= font_number <= 207):
                    y_offset+=3
                elif(217 <= font_number <= 253):
                    y_offset+=4
                elif(294 <= font_number <= 311):
                    y_offset+=2

            if(char == "a" or char == "e" or char == "s" or char == "u" or char == "o" or char == "w" or char == "x" or char == "z"):
                y_offset-=2
                if(64 <= font_number <= 68):
                    y_offset-=3
                elif(69 <= font_number <= 80):
                    y_offset-=3
                elif(111 <= font_number <= 122):
                    y_offset-=3
                elif(141 <= font_number <= 170):
                    y_offset-=3
                elif(171 <= font_number <= 207):
                    y_offset+=2
                elif(208 <= font_number <= 216):
                    y_offset-=3
                elif(217 <= font_number <= 253):
                    y_offset+=4
                if(278 <= font_number <= 293):
                    y_offset-=3

        
            if(char == "f"):
                if(171 <= font_number <= 207):
                    y_offset+=4
                elif(217 <= font_number <= 253):
                    y_offset+=5
                elif(294 <= font_number <= 311):
                    y_offset+=3

            if(char == "g"):
                y_offset+=1
                if(171 <= font_number <= 207):
                    y_offset+=4
                elif(217 <= font_number <= 253):
                    y_offset+=5
                elif(278 <= font_number <= 293):
                    y_offset-=2
                elif(294 <= font_number <= 311):
                    y_offset+=3

            if(char == "j"):
                y_offset+=3
                if(50 <= font_number <= 62 and not font_number == 56):
                    y_offset+=3
                if(87 <= font_number <= 89):
                    y_offset+=2
                if(171 <= font_number <= 207):
                    y_offset+=3
                elif(217 <= font_number <= 253):
                    y_offset+=4
                elif(294 <= font_number <= 311):
                    y_offset+=2

            if(char == "p" or char == "q" or char == "y"):
                y_offset+=1
                if(171 <= font_number <= 207):
                    y_offset+=4
                elif(217 <= font_number <= 253):
                    y_offset+=5
                elif(294 <= font_number <= 311):
                    y_offset+=3
            
            
            #if(char == "f"):y_offset+=1
            #if(char == "j"):y_offset+=3
            #if(char == "p"):y_offset+=1
            #if(char == "q"):y_offset+=1
            #if(char == "y"):y_offset+=1


            draw.text((0, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            output_path = char_folder / f"{char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")

# %% [markdown]
# ### Padding method with new font size

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# กำหนดโฟลเดอร์
output_folder = Path("../data/raw_images/eng_lowercase")
folder_path = Path("../font/GoogleFont")

if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':
        for char in "abcdefghijklmnopqrstuvwxyz":
            try:
                if(char == "j"):
                    font = ImageFont.truetype(str(font_file), 28)
                elif(char == "g" or char == "m" or char == "w" or char == "f"):
                    font = ImageFont.truetype(str(font_file), 34)
                elif(char == "b" or char == "d" or char == "h" or char == "k" or char == "l" or 
                     char == "t" or char == "p" or char == "q" or char == "y" or char == "i" ):
                    font = ImageFont.truetype(str(font_file), 36)
                elif(char == "a" or char == "c" or char == "e" or char == "s" or char == "m" or 
                     char == "o" or char == "r" or char == "s" or char == "n" or char == "o" or 
                     char == "u" or char == "v" or char == "w" or char == "x" or char == "z"):
                    font = ImageFont.truetype(str(font_file), 44)
            except Exception as e:
                print(f"Skipping font {font_file}: {e}")
                continue

            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / f"{char}_L"
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y ทั่วไป
            y_offset = ascent - bbox[3]

            # ปรับตำแหน่ง y_offset เฉพาะจุด
            # +ลง -ขึ้น
            if(char == "b" or char == "d" or char == "h" or char == "i" or char == "k" or char == "l" or char == "t"):
                if(50 <= font_number <= 63):
                    y_offset+=3
                elif(65 <= font_number <= 80):
                    y_offset-=2
                elif(111 <= font_number <= 122):
                    y_offset-=2
                elif(141 <= font_number <= 152):
                    y_offset+=2
                elif(159 <= font_number <= 170):
                    y_offset-=2
                elif(171 <= font_number <= 207):
                    y_offset+=3
                elif(208 <= font_number <= 216):
                    y_offset-=2
                elif(217 <= font_number <= 253):
                    y_offset+=5
                elif(278 <= font_number <= 293):
                    y_offset-=3
                elif(278 <= font_number <= 293):
                    y_offset-=3
                elif(294 <= font_number <= 311):
                    y_offset+=2
                elif(322 <= font_number <= 333):
                    y_offset+=2

            if(char == "a" or char == "c" or char == "e" or char == "s" or char == "m" or char == "o" or 
               char == "r" or char == "s" or char == "n" or char == "o" or char == "u" or char == "v" or
               char == "w" or char == "x" or char == "z"):
                y_offset-=2
                if(1 <= font_number <= 14):
                    y_offset-=2
                elif(15 <= font_number <= 49):
                    y_offset-=3
                elif(50 <= font_number <= 63):
                    y_offset+=1
                elif(64 <= font_number <= 80):
                    y_offset-=3
                elif(81 <= font_number <= 110):
                    y_offset-=3
                elif(111 <= font_number <= 122):
                    y_offset-=3
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(141 <= font_number <= 158):
                    y_offset-=4
                elif(159 <= font_number <= 170):
                    y_offset-=7
                elif(171 <= font_number <= 207):
                    y_offset+=2
                elif(208 <= font_number <= 216):
                    y_offset-=3
                elif(217 <= font_number <= 253):
                    y_offset+=4
                elif(278 <= font_number <= 293):
                    y_offset-=4
                elif(294 <= font_number <= 315):
                    y_offset-=3
                elif(322 <= font_number <= 333):
                    y_offset-=1

        
            if(char == "f"):
                if(50 <= font_number <= 63):
                    y_offset+=3
                elif(65 <= font_number <= 80):
                    y_offset-=2
                elif(111 <= font_number <= 122):
                    y_offset-=2
                elif(141 <= font_number <= 152):
                    y_offset+=2
                elif(159 <= font_number <= 170):
                    y_offset-=2
                elif(171 <= font_number <= 207):
                    y_offset+=3
                elif(208 <= font_number <= 216):
                    y_offset-=2
                elif(217 <= font_number <= 253):
                    y_offset+=5
                elif(278 <= font_number <= 293):
                    y_offset-=3
                elif(278 <= font_number <= 293):
                    y_offset-=3
                elif(294 <= font_number <= 311):
                    y_offset+=2
                elif(322 <= font_number <= 333):
                    y_offset+=2

            if(char == "g"):
                if(1 <= font_number <= 8):
                    y_offset+=2
                elif(50 <= font_number <= 63):
                    y_offset+=4
                elif(65 <= font_number <= 80):
                    y_offset-=2
                elif(111 <= font_number <= 122):
                    y_offset-=2
                elif(141 <= font_number <= 152):
                    y_offset+=0
                elif(159 <= font_number <= 170):
                    y_offset-=3
                elif(171 <= font_number <= 207):
                    y_offset+=3
                elif(208 <= font_number <= 216):
                    y_offset-=2
                elif(217 <= font_number <= 253):
                    y_offset+=5
                elif(278 <= font_number <= 293):
                    y_offset-=3
                elif(278 <= font_number <= 293):
                    y_offset-=3
                elif(294 <= font_number <= 311):
                    y_offset+=2
                elif(322 <= font_number <= 333):
                    y_offset+=2

            if(char == "j"):
                y_offset+=3
                if(50 <= font_number <= 62 and not font_number == 56):
                    y_offset+=3
                if(87 <= font_number <= 89):
                    y_offset+=2
                if(171 <= font_number <= 207):
                    y_offset+=3
                elif(217 <= font_number <= 253):
                    y_offset+=4
                elif(294 <= font_number <= 311):
                    y_offset+=2

            if(char == "p" or char == "q" or char == "y"):
                if(50 <= font_number <= 63):
                    y_offset+=3
                elif(65 <= font_number <= 80):
                    y_offset-=2
                elif(111 <= font_number <= 122):
                    y_offset-=2
                elif(141 <= font_number <= 152):
                    y_offset+=2
                elif(159 <= font_number <= 170):
                    y_offset-=2
                elif(171 <= font_number <= 207):
                    y_offset+=3
                elif(208 <= font_number <= 216):
                    y_offset-=2
                elif(217 <= font_number <= 253):
                    y_offset+=5
                elif(278 <= font_number <= 293):
                    y_offset-=3
                elif(278 <= font_number <= 293):
                    y_offset-=3
                elif(294 <= font_number <= 311):
                    y_offset+=2
                elif(322 <= font_number <= 333):
                    y_offset+=2
            
            
            draw.text((0, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            output_path = char_folder / f"{char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")

# %% [markdown]
# ## Thai Consonant

# %% [markdown]
# ### Classic

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# ระบุโฟลเดอร์ที่ต้องการอ่านไฟล์ทั้งหมด
output_folder = Path("../data/raw_images/thai_consonants")
folder_path = Path("../font/GoogleFont")


if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':
        for char in "กขฃคฅฆงจฉชซฌญฎฏฐฑฒณดตถทธนบปผฝพฟภมยรฤลฦวศษสหฬอฮ":
            try:
                if(char == "ฌ" or char == "ญ" or char == "ฒ" or char == "ณ"):
                    font = ImageFont.truetype(str(font_file), 32)
                elif(char == "ฎ" or char == "ฏ" or char == "ฐ"):
                    font = ImageFont.truetype(str(font_file), 32)
                elif(char == "ป" or char == "ฝ" or char == "ฟ" or char == "ฬ"):
                    font = ImageFont.truetype(str(font_file), 34)
                else:
                    font = ImageFont.truetype(str(font_file), 46)
            except Exception as e:
                print(f"Skipping font {font_file}: {e}")
                continue

            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / f"{char}"
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y ทั่วไป
            y_offset = ascent - bbox[3]

            # ปรับตำแหน่ง y_offset เฉพาะจุด
            # +ลง -ขึ้น
            if(char == "ช" or char == "ซ" or char == "ศ" or char == "ส" or char == "ฮ"):
                if(1 <= font_number <= 26):
                    y_offset-=4
                elif(27 <= font_number <= 36):
                    y_offset-=2
                elif(37 <= font_number <= 49):
                    y_offset-=3
                elif(50 <= font_number <= 63):#ADD
                    y_offset+=3
                elif(64 <= font_number <= 80):
                    y_offset-=4
                elif(81 <= font_number <= 110):
                    y_offset-=3
                elif(111 <= font_number <= 122):
                    y_offset-=5
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(135 <= font_number <= 140):
                    y_offset-=2
                elif(141 <= font_number <= 152):
                    y_offset-=4
                elif(153 <= font_number <= 158):
                    y_offset-=4
                elif(159 <= font_number <= 170):
                    y_offset-=7
                elif(171 <= font_number <= 207):
                    y_offset-=1
                elif(208 <= font_number <= 216):
                    y_offset-=7
                elif(217 <= font_number <= 253):
                    y_offset+=2
                elif(254 <= font_number <= 259):
                    y_offset-=3
                elif(260 <= font_number <= 277):
                    y_offset-=3
                elif(278 <= font_number <= 293):
                    y_offset-=5
                elif(294 <= font_number <= 311):
                    y_offset-=1
                elif(312 <= font_number <= 315):
                    y_offset-=2
                elif(316 <= font_number <= 333):
                    y_offset-=2
            elif(char == "ญ"):
                if(1 <= font_number <= 26):
                    y_offset+=2
                elif(27 <= font_number <= 36):
                    y_offset+=2
                elif(37 <= font_number <= 49):
                    y_offset+=3
                elif(50 <= font_number <= 63):#ADD
                    y_offset+=3
                elif(64 <= font_number <= 80):
                    y_offset+=2
                elif(81 <= font_number <= 98): # edit
                    y_offset-=1
                elif(99 <= font_number <= 110): # add
                    y_offset+=2
                elif(111 <= font_number <= 122):
                    y_offset+=2
                elif(123 <= font_number <= 134):
                    y_offset+=3
                elif(135 <= font_number <= 140):
                    y_offset+=3
                elif(141 <= font_number <= 152):
                    y_offset+=2
                elif(153 <= font_number <= 158):
                    y_offset+=1
                elif(159 <= font_number <= 170):
                    y_offset-=1
                elif(171 <= font_number <= 207):
                    y_offset+=3
                elif(208 <= font_number <= 216):
                    y_offset+=0
                elif(217 <= font_number <= 253):
                    y_offset+=6
                elif(254 <= font_number <= 259):
                    y_offset+=2
                elif(260 <= font_number <= 277):
                    y_offset+=2
                elif(278 <= font_number <= 293):
                    y_offset+=2
                elif(294 <= font_number <= 311):
                    y_offset+=3
                elif(312 <= font_number <= 315):
                    y_offset+=2
                elif(316 <= font_number <= 333):
                    y_offset+=4
            elif(char == "ฎ" or char == "ฏ" or char == "ฐ"):
                if(1 <= font_number <= 26):
                    y_offset+=2
                elif(27 <= font_number <= 36):
                    y_offset+=2
                elif(37 <= font_number <= 49):
                    y_offset+=2
                elif(50 <= font_number <= 63):#ADD
                    y_offset+=3
                elif(64 <= font_number <= 80):
                    y_offset+=2
                elif(81 <= font_number <= 110):
                    y_offset+=2
                elif(111 <= font_number <= 122):
                    y_offset+=2
                elif(123 <= font_number <= 134):
                    y_offset+=2
                elif(135 <= font_number <= 140):
                    y_offset+=2
                elif(141 <= font_number <= 152):
                    y_offset+=2
                elif(153 <= font_number <= 158):
                    y_offset+=2
                elif(159 <= font_number <= 170):
                    y_offset+=2
                elif(171 <= font_number <= 207):
                    y_offset+=3
                elif(208 <= font_number <= 216):
                    y_offset+=0
                elif(217 <= font_number <= 253):
                    y_offset+=4
                elif(254 <= font_number <= 259):
                    y_offset+=3
                elif(260 <= font_number <= 277):
                    y_offset+=3
                elif(278 <= font_number <= 293):
                    y_offset+=2
                elif(294 <= font_number <= 311):
                    y_offset+=2
                elif(312 <= font_number <= 315):
                    y_offset+=2
                elif(316 <= font_number <= 333):
                    y_offset+=3
            elif(char == "ฌ" or char == "ณ"):
                if(1 <= font_number <= 26):
                    y_offset-=4
                elif(27 <= font_number <= 36):
                    y_offset-=2
                elif(37 <= font_number <= 49):
                    y_offset-=3
                elif(64 <= font_number <= 80):
                    y_offset-=4
                elif(81 <= font_number <= 110):
                    y_offset-=3
                elif(111 <= font_number <= 122):
                    y_offset-=5
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(135 <= font_number <= 140):
                    y_offset-=2
                elif(141 <= font_number <= 152):
                    y_offset-=4
                elif(153 <= font_number <= 158):
                    y_offset-=4
                elif(159 <= font_number <= 170):
                    y_offset-=7
                elif(171 <= font_number <= 207):
                    y_offset-=1
                elif(208 <= font_number <= 216):
                    y_offset-=7
                elif(217 <= font_number <= 253):
                    y_offset+=2
                elif(254 <= font_number <= 259):
                    y_offset-=3
                elif(260 <= font_number <= 277):
                    y_offset-=3
                elif(278 <= font_number <= 293):
                    y_offset-=5
                elif(294 <= font_number <= 311):
                    y_offset-=1
                elif(312 <= font_number <= 315):
                    y_offset-=2
                elif(316 <= font_number <= 333):
                    y_offset-=2
            elif(char == "ป" or char == "ฝ" or char == "ฟ" or char == "ฬ"):
                #00000
                if(1 <= font_number <= 26):
                    y_offset+=1
                elif(27 <= font_number <= 36):
                    y_offset+=2
                elif(37 <= font_number <= 49):
                    y_offset+=2
                elif(50 <= font_number <= 63):#ADD
                    y_offset+=2
                elif(64 <= font_number <= 80):
                    y_offset+=1
                elif(81 <= font_number <= 98): # edit
                    y_offset+=1
                elif(99 <= font_number <= 110): # add
                    y_offset+=2
                elif(111 <= font_number <= 122):
                    y_offset+=1
                elif(123 <= font_number <= 134):
                    y_offset+=2
                elif(135 <= font_number <= 140):
                    y_offset+=2
                elif(141 <= font_number <= 152):
                    y_offset+=2
                elif(153 <= font_number <= 158):
                    y_offset+=1
                elif(159 <= font_number <= 170):
                    y_offset+=0
                elif(171 <= font_number <= 207):
                    y_offset+=3
                elif(208 <= font_number <= 216):
                    y_offset-=1
                elif(217 <= font_number <= 253):
                    y_offset+=4
                elif(254 <= font_number <= 259):
                    y_offset+=2
                elif(260 <= font_number <= 277):
                    y_offset+=3
                elif(278 <= font_number <= 293):
                    y_offset+=1
                elif(294 <= font_number <= 311):
                    y_offset+=2
                elif(312 <= font_number <= 315):
                    y_offset+=2
                elif(316 <= font_number <= 333):
                    y_offset+=2
            else:
                if(1 <= font_number <= 26):
                    y_offset-=4
                elif(27 <= font_number <= 36):
                    y_offset-=2
                elif(37 <= font_number <= 49):
                    y_offset-=3
                elif(64 <= font_number <= 80):
                    y_offset-=4
                elif(81 <= font_number <= 110):
                    y_offset-=3
                elif(111 <= font_number <= 122):
                    y_offset-=5
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(135 <= font_number <= 140):
                    y_offset-=2
                elif(141 <= font_number <= 152):
                    y_offset-=4
                elif(153 <= font_number <= 158):
                    y_offset-=4
                elif(159 <= font_number <= 170):
                    y_offset-=7
                elif(171 <= font_number <= 207):
                    y_offset-=1
                elif(208 <= font_number <= 216):
                    y_offset-=7
                elif(217 <= font_number <= 253):
                    y_offset+=2
                elif(254 <= font_number <= 259):
                    y_offset-=3
                elif(260 <= font_number <= 277):
                    y_offset-=3
                elif(278 <= font_number <= 293):
                    y_offset-=5
                elif(294 <= font_number <= 311):
                    y_offset-=1
                elif(312 <= font_number <= 315):
                    y_offset-=2
                elif(316 <= font_number <= 333):
                    y_offset-=2

            
            draw.text((0, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            output_path = char_folder / f"{char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")

# %% [markdown]
# ### Padding method

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# กำหนดโฟลเดอร์
output_folder = Path("../data/raw_images/thai_consonants")
folder_path = Path("../font/GoogleFont")

if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':
        try:
            font = ImageFont.truetype(str(font_file), 28)  # โหลดฟอนต์
        except Exception as e:
            print(f"Skipping font {font_file}: {e}")
            continue

        for char in "กขฃคฅฆงจฉชซฌญฎฏฐฑฒณดตถทธนบปผฝพฟภมยรรฤลฦวศษสหฬอฮ":
            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / char
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y
            y_offset = ascent - bbox[3]
            draw.text((0, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            output_path = char_folder / f"{char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")

# %% [markdown]
# ## Thai Vowels

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# ระบุโฟลเดอร์ที่ต้องการอ่านไฟล์ทั้งหมด
output_folder = Path("../data/raw_images/thai_vowels")
folder_path = Path("../font/GoogleFont")


if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':
        
        

        for char in "ะาิีึืุูเโฤใไ็ัํ": 
            try:
                if(char == "เ" or char == "า" or char == "ะ"):
                    font = ImageFont.truetype(str(font_file), 46)
                elif(char == "โ" or char == "ใ" or char == "ไ"):
                    font = ImageFont.truetype(str(font_file), 30)
                elif(char == "ฤ"):
                    font = ImageFont.truetype(str(font_file), 32)
                elif(char == "ิ" or char == "ี"  or char == "ื"):
                    font = ImageFont.truetype(str(font_file), 54)
                elif(char == "ึ" ):
                    font = ImageFont.truetype(str(font_file), 43)
                elif(char == "ุ" ):
                    font = ImageFont.truetype(str(font_file), 95)
                elif(char == "ู"):
                    font = ImageFont.truetype(str(font_file), 65)
                elif(char == "็"):
                    font = ImageFont.truetype(str(font_file), 58)
                elif(char == "ํ"):
                    font = ImageFont.truetype(str(font_file), 120)
                elif(char == "ั"):
                    font = ImageFont.truetype(str(font_file), 58)
            except Exception as e:
                print(f"Skipping font {font_file}: {e}")
                continue

            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / f"{char}"
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y ทั่วไป
            y_offset = ascent - bbox[3]
            x_offset = 0

            # ปรับตำแหน่ง y_offset เฉพาะจุด
            # +ลง -ขึ้น

            # ปรับตำแหน่ง x_offset เฉพาะจุด
            # ยิ่งเลขมากยิ่งไปทางซ้าย

            if(char == "เ" or char == "า" or char == "ะ"):
                if(1 <= font_number <= 26):
                    y_offset-=4
                elif(27 <= font_number <= 36):
                    y_offset-=2
                elif(37 <= font_number <= 49):
                    y_offset-=3
                elif(50 <= font_number <= 63):#ADD
                    y_offset+=3
                elif(64 <= font_number <= 80):
                    y_offset-=4
                elif(81 <= font_number <= 110):
                    y_offset-=3
                elif(111 <= font_number <= 122):
                    y_offset-=5
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(135 <= font_number <= 140):
                    y_offset-=2
                elif(141 <= font_number <= 152):
                    y_offset-=4
                elif(153 <= font_number <= 158):
                    y_offset-=4
                elif(159 <= font_number <= 170):
                    y_offset-=7
                elif(171 <= font_number <= 207):
                    y_offset-=1
                elif(208 <= font_number <= 216):
                    y_offset-=7
                elif(217 <= font_number <= 253):
                    y_offset+=2
                elif(254 <= font_number <= 259):
                    y_offset-=3
                elif(260 <= font_number <= 277):
                    y_offset-=3
                elif(278 <= font_number <= 293):
                    y_offset-=5
                elif(294 <= font_number <= 311):
                    y_offset-=1
                elif(312 <= font_number <= 315):
                    y_offset-=2
                elif(316 <= font_number <= 333):
                    y_offset-=2
            elif(char == "โ" or char == "ใ" or char == "ไ"):
                if(1 <= font_number <= 26):
                    y_offset+=3
                elif(27 <= font_number <= 36):
                    y_offset+=3
                elif(37 <= font_number <= 49):
                    y_offset+=3
                elif(50 <= font_number <= 63):#ADD
                    y_offset+=5
                elif(64 <= font_number <= 80):
                    y_offset+=4
                elif(81 <= font_number <= 98):#ADD
                    y_offset+=3
                    x_offset+=1
                elif(99 <= font_number <= 110):
                    y_offset+=5
                    x_offset+=3
                elif(111 <= font_number <= 122):
                    y_offset+=3
                    x_offset+=3
                elif(123 <= font_number <= 134):
                    y_offset+=4
                    x_offset+=3
                elif(135 <= font_number <= 140):
                    y_offset+=3
                    x_offset+=3
                elif(141 <= font_number <= 152):
                    y_offset+=4
                    x_offset+=2
                elif(153 <= font_number <= 158):
                    y_offset+=0
                    x_offset+=2
                elif(159 <= font_number <= 170):
                    y_offset+=3
                    x_offset+=2
                elif(171 <= font_number <= 207):
                    y_offset+=3
                elif(208 <= font_number <= 216):
                    y_offset+=2
                    x_offset+=1
                elif(217 <= font_number <= 253):
                    y_offset+=9
                    x_offset+=2
                elif(254 <= font_number <= 259):
                    y_offset+=3
                    x_offset+=2
                elif(260 <= font_number <= 277):
                    y_offset+=3
                    x_offset+=2
                elif(278 <= font_number <= 293):
                    y_offset+=3
                elif(294 <= font_number <= 311):
                    y_offset+=4
                    x_offset+=2
                elif(312 <= font_number <= 315):
                    y_offset+=3
                elif(316 <= font_number <= 333):
                    y_offset+=4
                    x_offset+=2
            elif(char == "ฤ"):
                y_offset+=1
                if(217 <= font_number <= 253):
                    y_offset+=4
                elif(259 <= font_number <= 265):
                    y_offset+=3
            elif(char == "ิ" or char == "ี"  or char == "ื"):
                if(208 <= font_number <= 216):
                    y_offset+=17
                    x_offset+=2
                elif(1 <= font_number <= 14):
                    y_offset+=18
                    x_offset+=27
                elif(font_number == 15 or font_number == 17 or font_number == 20 or font_number == 22 or font_number == 24 or font_number == 25 or font_number == 27 or font_number == 32 or font_number == 35 ):
                    y_offset+=22
                    x_offset+=32
                elif(font_number == 37):
                    y_offset+=20
                    x_offset+=37
                elif(font_number == 16 or font_number == 18 or font_number == 19 or font_number == 21 or font_number == 23 or font_number == 26 or 28 <= font_number <= 31 or 33 <= font_number <= 34 or font_number == 36 ):
                    y_offset+=22
                    x_offset+=25
                elif(font_number == 38 or font_number == 40 or font_number == 43 or font_number == 45 or 47 <= font_number <= 48 ):
                    y_offset+=22
                    x_offset+=35
                elif(font_number == 39 or 41 <= font_number <= 42 or font_number == 44 or font_number == 46 or 49 <= font_number <= 50 or font_number == 55 or font_number == 60):
                    y_offset+=22
                    x_offset+=30
                elif(font_number == 57):
                    y_offset+=25
                    x_offset+=30
                elif(font_number == 64):
                    y_offset+=15
                    x_offset+=30
                elif(51 <= font_number <= 54  or font_number==56 ):
                    y_offset+=24
                    x_offset+=22
                elif( 58 <= font_number <= 59  ):
                    y_offset+=25
                    x_offset+=26
                elif(font_number == 62 or 81 <= font_number <= 83 or font_number == 65 or font_number == 67 or 76 <= font_number <= 77 or font_number == 72 or font_number == 74 or font_number == 79 or font_number == 85):
                    y_offset+=22
                    x_offset+=30
                elif(font_number == 63 or font_number == 73 or font_number == 80  or font_number == 84 or font_number == 88 or font_number == 89 ):
                    y_offset+=22
                    x_offset+=25
                elif(font_number == 61 or font_number == 66 or 68 <= font_number <= 71 or font_number == 75 or font_number == 78 or 86 <= font_number <= 87 or font_number == 90  ):
                    y_offset+=18
                    x_offset+=27
                elif(font_number == 92 or font_number == 95 or 108<= font_number <= 109  or font_number == 100 or font_number == 101 or font_number == 104 or font_number == 106):
                    y_offset+=22
                    x_offset+=30
                elif(font_number == 99):
                    y_offset+=20
                    x_offset+=35
                elif(font_number == 91 or font_number == 93 or font_number == 96):
                    y_offset+=20
                    x_offset+=30
                elif(97 <= font_number <= 98 ):
                    y_offset+=20
                    x_offset+=25
                elif(font_number == 94 or 102<= font_number <= 103 or font_number ==105 or font_number ==107 or font_number ==110  ):
                    y_offset+=20
                    x_offset+=26
                elif(font_number == 114 or  font_number == 142 or 144 <= font_number <=145 or font_number ==147 or font_number ==149 or font_number == 152 or  font_number == 165 or 162 <= font_number <=163 or font_number == 167 or  font_number == 170 or 181 <= font_number <=183  ):
                    y_offset+=20
                    x_offset+=26
                elif(font_number == 141 or font_number == 143 or font_number == 148 or font_number == 151 or font_number == 159 or font_number == 166 or 168<= font_number <= 169):
                    y_offset+=20
                    x_offset+=35
                elif(111 <= font_number <= 113 or 115 <= font_number <= 140 or font_number == 146 or font_number == 150 or 153 <= font_number <= 158 or 160 <= font_number <= 161 or font_number == 164 or 171 <= font_number <= 180 or 184 <= font_number <= 207   ):
                    y_offset+=20
                    x_offset+=30
                elif(230 <= font_number <= 235 or 239 <= font_number <= 244 or font_number == 261 or font_number == 263 or 265<= font_number <=268 or font_number == 272 or font_number == 275 or font_number == 277 or font_number == 279  ):
                    y_offset+=20
                    x_offset+=25
                elif(font_number == 270):
                    y_offset+=20
                    x_offset+=23
                elif(217 <= font_number <= 229 or 236 <= font_number <= 238 or 245 <= font_number <= 260 or font_number == 262 or font_number == 264 or font_number == 269 or font_number == 271 or font_number == 273 or font_number == 274 or font_number == 276 or font_number == 278 or font_number == 280  ):
                    y_offset+=22
                    x_offset+=31
                elif(329 <=font_number <= 330 or font_number == 282 or font_number == 285 or font_number == 287 or font_number == 289 or font_number == 290 or font_number == 2292 or font_number == 303 or font_number == 305 or font_number == 307 or font_number == 310 or font_number == 312 or font_number == 322 or font_number == 325 or font_number == 327 or font_number == 332):
                    y_offset+=20
                    x_offset+=30
                elif(font_number == 302 or 313 <= font_number <= 214 or  font_number == 293 or font_number == 304   or font_number == 326    ):
                    y_offset+=22
                    x_offset+=23
                elif( font_number == 301 or font_number == 311 or font_number == 323 or font_number == 333 ):
                    y_offset+=22
                    x_offset+=20
                elif( font_number == 264 or font_number == 296 or font_number == 298 or font_number == 308 or font_number == 316 or font_number == 318 or font_number == 320 ):
                    y_offset+=22
                    x_offset+=33
                elif( font_number == 281 or 283 <= font_number <= 284 or font_number == 286 or font_number == 288 or font_number == 291 or font_number == 295 or font_number == 297 or font_number == 299 or font_number == 300 or font_number == 306 or font_number == 309 or font_number == 315 or font_number == 317 or font_number == 319 or font_number == 321 or font_number == 324 or font_number == 328 or font_number == 331):
                    y_offset+=22
                    x_offset+=25
                elif(313 <= font_number <= 314  ):
                    y_offset+=22
                    x_offset+=25
                elif(font_number == 292  ):
                    y_offset+=22
                    x_offset+=30
                elif(font_number == 294  ):
                    y_offset+=22
                    x_offset+=35
            elif(char == "ุ" ):
                if(1 <= font_number <= 7 or 9<= font_number <=14):
                    y_offset-=20
                    x_offset+=26
                elif(24<= font_number <=25 or 34 <= font_number <= 35 or 47<= font_number <=48 or font_number == 15 or font_number == 17 or font_number == 20 or font_number == 22 or font_number == 27 or font_number == 30 or font_number == 32 or font_number == 38 or font_number == 40 or font_number == 43 or font_number == 45):
                    y_offset-=20
                    x_offset+=30
                elif(18<= font_number <=19 or 28 <= font_number <= 29 or 41<= font_number <=42 or font_number == 16 or font_number == 21 or font_number == 23 or font_number == 26 or font_number == 31 or font_number == 33 or font_number == 39 or 36<= font_number <= 37 or font_number == 44 or font_number == 46 or font_number == 49):
                    y_offset-=20
                    x_offset+=40
                elif(font_number == 8 ):
                    y_offset-=25
                    x_offset+=20
                elif(font_number == 50 ):
                    y_offset-=15
                    x_offset+=18
                elif(font_number == 64 or font_number == 65 or font_number == 67 or font_number == 77 or font_number == 81 or font_number == 88 or font_number == 91 or font_number == 98 or font_number == 99):
                    y_offset-=20
                    x_offset+=30
                elif(52<= font_number <= 55 or font_number == 63 ):
                    y_offset-=15
                    x_offset+=15
                elif(font_number == 51 or font_number == 56 ):
                    y_offset-=15
                    x_offset+=10
                elif(58<= font_number <= 59 or font_number == 61 ):
                    y_offset-=15
                    x_offset+=20
                elif( font_number == 87 or font_number == 97 or font_number == 90 ):
                    y_offset-=20
                    x_offset+=20
                elif( font_number == 57  ):
                    y_offset-=15
                    x_offset+=25
                elif( font_number == 60 or font_number == 62 ):
                    y_offset-=15
                    x_offset+=25
                elif( font_number == 89  ):
                    y_offset-=23
                    x_offset+=35
                elif(font_number == 66 or font_number == 68 or 70<= font_number <= 71 or font_number == 73 or font_number == 75 or font_number == 78 or font_number == 80 or font_number == 82 or font_number == 84 or font_number == 86 or  font_number == 93 or font_number == 96 or font_number == 100 ):
                    y_offset-=20
                    x_offset+=38
                elif( 94<= font_number <= 95 or font_number == 69 or font_number == 72 or font_number == 74 or font_number == 76 or font_number == 79 or font_number == 83 or  font_number == 85  or font_number == 92 ):
                    y_offset-=25
                    x_offset+=25
                elif(font_number ==113 or font_number ==116 or font_number ==120  ):
                    y_offset-=25
                    x_offset+=25
                elif(font_number ==112 or font_number ==144  ):
                    y_offset-=25
                    x_offset+=45
                elif(102<= font_number <= 103 or font_number ==105 or font_number ==107 or font_number ==110  or font_number ==117 or font_number ==119 or font_number ==124 or 126<= font_number <= 127 or font_number ==129 or font_number ==131 or font_number ==134   ):
                    y_offset-=21
                    x_offset+=40
                elif(font_number ==142 or font_number ==149 ):
                    y_offset-=20
                    x_offset+=45
                elif(font_number ==115):
                    y_offset-=25
                    x_offset+=35
                elif(font_number ==114 or font_number ==122 or 144<= font_number <=145 or font_number ==147 ):
                    y_offset-=24
                    x_offset+=43
                elif(font_number ==101 or font_number ==104 or 135<= font_number <=141 or font_number ==106 or font_number ==108 or font_number ==109 or font_number ==111 or font_number ==118 or font_number ==121 or font_number ==123 or font_number ==125 or font_number ==128 or font_number ==130 or font_number ==132 or font_number ==133 or font_number ==143 or font_number ==146 or font_number ==148 or font_number ==150 ):
                    y_offset-=24
                    x_offset+=30
                elif(162<= font_number <= 163 or font_number ==165 or font_number ==167 or font_number ==170   ):
                    y_offset-=29
                    x_offset+=40
                elif( font_number ==151 or  font_number ==153   ):
                    y_offset-=20
                    x_offset+=33
                elif(154<= font_number <= 155 or  175<= font_number <= 176 or 184<= font_number <= 187 or 193 <= font_number <= 198 or font_number == 180 or font_number ==189):
                    y_offset-=20
                    x_offset+=20
                elif(font_number ==156 or  font_number ==158 or 172<= font_number <=174 or  font_number ==179 or  font_number ==181 or  font_number ==183 or 199<= font_number <=200  ):
                    y_offset-=20
                    x_offset+=30
                elif(font_number ==152 ):
                    y_offset-=20
                    x_offset+=42
                elif(font_number == 160 ):
                    y_offset-=28
                    x_offset+=42
                elif(  font_number ==159 or  font_number ==164  or  font_number ==166 or 168<=  font_number <=169 or  font_number ==161 ):
                    y_offset-=30
                    x_offset+=29
                elif(198<= font_number <=199  ):
                    y_offset-=20
                    x_offset+=30
                elif(190<= font_number <=192 or 177<= font_number <=178  or  font_number ==157  or  font_number ==171 or  font_number ==182 or  font_number ==188 ):
                    y_offset-=20
                    x_offset+=30
                elif(254<= font_number <=260 or 300<= font_number <=303 or 323<= font_number <=330  ):
                    y_offset-=20
                    x_offset+=30
                elif(font_number ==201 or  font_number ==262 or font_number ==264 or font_number ==267 or font_number ==270 or font_number ==271 or 277<= font_number <=278 or font_number ==280 or font_number ==287 or font_number ==316 or font_number ==318 or font_number ==320 or font_number ==333  ):
                    y_offset-=20
                    x_offset+=33
                elif(289<= font_number <=290):
                    y_offset-=25
                    x_offset+=30
                elif(font_number ==255 or font_number == 297 or font_number == 299 or font_number == 331 ):
                    y_offset-=15
                    x_offset+=40
                elif(font_number ==207):
                    y_offset-=20
                    x_offset+=20
                elif(font_number ==261):
                    y_offset-=20
                    x_offset+=45
                elif(font_number ==266):
                    y_offset-=22
                    x_offset+=23
                elif(font_number ==202 or font_number == 276 ):
                    y_offset-=20
                    x_offset+=20
                elif(font_number ==203 or font_number == 332 ):
                    y_offset-=20
                    x_offset+=25
                elif(208<= font_number <=216):
                    y_offset-=28
                    x_offset+=0
                elif(204<= font_number <=206 or 273<= font_number <=274):
                    y_offset-=20
                    x_offset+=25
                elif(font_number ==269 or font_number ==282 or font_number ==285 or font_number ==292 or font_number ==307 or font_number ==310 or font_number ==312 or font_number ==315 or font_number ==322):
                    y_offset-=20
                    x_offset+=25
                elif(283<= font_number <=284 ):
                    y_offset-=22
                    x_offset+=35
                elif(font_number ==263 or font_number ==272 or font_number ==265 or font_number ==268 or font_number ==275 or font_number ==279 or font_number ==281 or font_number ==286 or font_number ==288 or font_number ==291 or font_number ==293 or font_number ==309 or font_number ==311 or font_number ==317 or font_number ==319 or font_number ==321 ):
                    y_offset-=21
                    x_offset+=40
                elif( 313<= font_number <=314):
                    y_offset-=20
                    x_offset+=35
                elif( 217<= font_number <=253):
                    y_offset-=15
                    x_offset+=30
                elif( font_number ==294 or font_number ==296 or font_number ==298 or font_number ==308 ):
                    y_offset-=15
                    x_offset+=28
                elif( font_number ==306 or font_number ==304 ):
                    y_offset-=15
                    x_offset+=33
                elif( font_number ==305 ):
                    y_offset-=15
                    x_offset+=28
                elif( font_number ==295 ):
                    y_offset-=15
                    x_offset+=40
            elif(char == "็"):
                if(1<= font_number<= 100):
                    if(font_number == 64):
                        y_offset+=20
                        x_offset+=30
                    elif( font_number == 58 or font_number == 63 ):
                        y_offset+=30
                        x_offset+=20
                    elif( font_number == 51 or font_number == 56 ):
                        y_offset+=30
                        x_offset+=20
                    elif(52<= font_number <=55  ):
                        y_offset+=30
                        x_offset+=24
                    elif(font_number ==26 or font_number ==28 or font_number ==36 or font_number ==66 or font_number ==68 or font_number ==82 or font_number ==84 or font_number ==86  ):
                        y_offset+=25
                        x_offset+=24
                    elif(37<= font_number <=38 or 47<= font_number <=48  ):
                        y_offset+=25
                        x_offset+=35
                    elif(font_number ==43 or font_number ==45 or  font_number ==81 or font_number ==83 or font_number ==85 or font_number ==92 or font_number ==99 ):
                        y_offset+=25
                        x_offset+=35
                    elif(font_number ==61  ):
                        y_offset+=30
                        x_offset+=25
                    elif(font_number == 16):
                        y_offset+=28
                        x_offset+=25
                    elif(18 <=font_number <= 19 or font_number ==11 or font_number ==13  ):
                        y_offset+=28
                        x_offset+=23
                    elif(font_number == 21 or font_number ==23 or font_number ==29 or font_number ==31 or font_number ==33   ):
                        y_offset+=28
                        x_offset+=23
                    elif(font_number == 50 or font_number ==59 or font_number ==70 or font_number ==71 or font_number ==73 or font_number ==75 or font_number ==78  ):
                        y_offset+=28
                        x_offset+=24
                    elif(font_number == 80 or font_number ==89 or font_number ==88 or font_number ==91 or font_number ==93 or font_number ==98 ):
                        y_offset+=28
                        x_offset+=24
                    else:
                        y_offset+=28
                        x_offset+=30
                elif(101<= font_number<= 200):
                    if(120<=font_number <= 121 or 154<=font_number <= 159 ):
                        y_offset+=23
                        x_offset+=30
                    elif( font_number == 111 or font_number == 116 or font_number == 118 or font_number == 137 ):
                        y_offset+=23
                        x_offset+=30
                    elif(193<=font_number <= 198  ):
                        y_offset+=28
                        x_offset+=23
                    elif(114<=font_number <= 115 or 184<=font_number <= 185  ):
                        y_offset+=28
                        x_offset+=23
                    elif(font_number == 112 or font_number == 117  or font_number == 187 or font_number == 189 ):
                        y_offset+=28
                        x_offset+=23
                    elif( font_number == 144 or font_number == 147 ):
                        y_offset+=28
                        x_offset+=20
                    elif(108<= font_number <= 109 ):
                        y_offset+=28
                        x_offset+=34
                    elif(190<= font_number <= 192 ):
                        y_offset+=28
                        x_offset+=25
                    elif(font_number == 101 or font_number == 104 or font_number == 106  ):
                        y_offset+=28
                        x_offset+=34
                    elif(font_number == 123 or font_number == 133 or font_number == 141 or font_number == 148 or font_number == 151  ):
                        y_offset+=28
                        x_offset+=34
                    elif(font_number == 153 or font_number == 166 or font_number == 168   ):
                        y_offset+=23
                        x_offset+=32
                    elif(102<= font_number <= 103 or font_number == 163 ):
                        y_offset+=25
                        x_offset+=25
                    elif( font_number == 162 ):
                        y_offset+=25
                        x_offset+=23
                    elif(font_number == 105 or font_number == 107 or font_number == 110 or font_number == 113 ):
                        y_offset+=25
                        x_offset+=26
                    elif(font_number == 119 ):
                        y_offset+=25
                        x_offset+=23
                    elif( font_number == 122 or font_number == 126 or font_number == 136 or font_number == 142 ):
                        y_offset+=28
                        x_offset+=26
                    elif( font_number == 145 or font_number == 149 or font_number == 152 or font_number == 160 ):
                        y_offset+=28
                        x_offset+=24
                    elif(font_number == 152 or font_number == 160 ):
                        y_offset+=28
                        x_offset+=26
                    elif(font_number == 165 or font_number == 167 or font_number == 170 or font_number == 186 or font_number == 188 ):
                        y_offset+=28
                        x_offset+=26
                    else:
                        y_offset+=28
                        x_offset+=30
                elif(201<= font_number<= 300):
                    if(208<= font_number <=216):
                        y_offset+=20
                        x_offset+=0
                    elif(267<=font_number <= 268 or font_number == 270 or font_number == 272 or font_number == 275 or font_number == 277 or font_number == 293  ):
                        y_offset+=25
                        x_offset+=22
                    elif( font_number == 295):
                        y_offset+=30
                        x_offset+=26
                    elif( font_number == 283):
                        y_offset+=28
                        x_offset+=20
                    elif(font_number == 218 ):
                        y_offset+=30
                        x_offset+=35
                    elif(font_number == 294 ):
                        y_offset+=28
                        x_offset+=33
                    elif(font_number == 260 or font_number == 262 or font_number == 264 ):
                        y_offset+=28
                        x_offset+=33
                    elif(font_number == 284 or font_number == 286 or font_number == 288 or font_number == 291  ):
                        y_offset+=28
                        x_offset+=24
                    elif(202<= font_number <=203 or 230<= font_number <=244 ):
                        y_offset+=28
                        x_offset+=25
                    elif(font_number == 207 or font_number == 261 or font_number == 263 or font_number == 265  ):
                        y_offset+=24
                        x_offset+=25
                    elif(font_number == 279 or font_number == 281 or font_number == 297 or font_number == 299  ):
                        y_offset+=28
                        x_offset+=25
                    else:
                        y_offset+=28
                        x_offset+=30
                elif(301<= font_number<= 333):
                    if(font_number == 302 ):
                        y_offset+=30
                        x_offset+=22
                    elif(font_number == 316 or font_number ==  318 or font_number == 320 ):
                        y_offset+=30
                        x_offset+=33
                    elif(323<= font_number <= 324 ):
                        y_offset+=28
                        x_offset+=18
                    elif(font_number == 301 or font_number == 304 or font_number == 311 or font_number == 326 or font_number == 333  ):
                        y_offset+=28
                        x_offset+=18
                    elif(309<= font_number <= 310 or 313<= font_number <= 314 ):
                        y_offset+=28
                        x_offset+=23
                    elif( font_number == 319 or font_number == 321 or font_number == 331 ):
                        y_offset+=28
                        x_offset+=23
                    elif(font_number == 306   or font_number == 328 ):
                        y_offset+=28
                        x_offset+=20
                    elif( font_number == 317  ):
                        y_offset+=28
                        x_offset+=25
                    else:
                        y_offset+=28
                        x_offset+=30
            elif(char == "ู"):
                if(1<= font_number<=100):
                    if(font_number == 50 or font_number ==61):
                        y_offset-=10
                        x_offset+=26
                    elif( font_number ==60  or font_number ==62):
                        y_offset-=10
                        x_offset+=30
                    elif(font_number == 57 ):
                        y_offset-=10
                        x_offset+=32
                    elif( font_number ==20  or font_number ==22 or font_number ==27 or font_number ==32 or font_number ==35):
                        y_offset-=15
                        x_offset+=30
                    elif(24 <= font_number <= 25 ):
                        y_offset-=15
                        x_offset+=30
                    elif( font_number ==65  or font_number ==67 or font_number ==74 or font_number ==77 or font_number ==91):
                        y_offset-=15
                        x_offset+=28
                    elif(80 <= font_number <= 81 ):
                        y_offset-=15
                        x_offset+=32
                    elif(51 <= font_number <= 52  ):
                        y_offset-=13
                        x_offset+=20
                    elif( font_number ==56):
                        y_offset-=13
                        x_offset+=18
                    elif( font_number ==54):
                        y_offset-=10
                        x_offset+=20
                    elif( font_number == 53 or font_number ==55  ):
                        y_offset-=10
                        x_offset+=23
                    elif( font_number ==87 or font_number ==97 ):
                        y_offset-=13
                        x_offset+=20
                    elif( font_number ==16 or font_number ==23):
                        y_offset-=15
                        x_offset+=40
                    elif( font_number ==39):
                        y_offset-=15
                        x_offset+=42
                    elif(36 <= font_number <= 37 ):
                        y_offset-=15
                        x_offset+=40
                    elif( font_number ==38):
                        y_offset-=15
                        x_offset+=35
                    elif( font_number ==46 or font_number ==49 or font_number ==82 ):
                        y_offset-=15
                        x_offset+=40
                    elif( font_number ==84 or font_number ==86 or font_number ==100 ):
                        y_offset-=15
                        x_offset+=38
                    elif(18 <= font_number <= 19 or 28 <= font_number <= 29 ):
                        y_offset-=15
                        x_offset+=38
                    elif( 70 <= font_number <= 71 ):
                        y_offset-=15
                        x_offset+=35
                    elif( 47 <= font_number <= 48 or font_number ==40 or font_number ==43 or font_number ==45 ):
                        y_offset-=15
                        x_offset+=33
                    elif( 41 <= font_number <= 42 or font_number == 44):
                        y_offset-=15
                        x_offset+=38
                    elif(font_number == 9 or font_number == 15 ):
                        y_offset-=15
                        x_offset+=31
                    elif(font_number == 21 or font_number == 26 or font_number == 31 or font_number == 33 or font_number == 66 or font_number == 68):
                        y_offset-=15
                        x_offset+=38
                    elif(font_number == 73 or font_number == 75 or font_number == 78 or font_number == 89):
                        y_offset-=15
                        x_offset+=36
                    elif( font_number == 93 or font_number == 96 or font_number == 99 ):
                        y_offset-=15
                        x_offset+=34
                    elif( font_number == 90 or font_number == 3  ):
                        y_offset-=15
                        x_offset+=25
                    elif( font_number == 8 or font_number == 58  ):
                        y_offset-=15
                        x_offset+=23
                    elif( font_number == 63   ):
                        y_offset-=13
                        x_offset+=22
                    else:
                        y_offset-=15
                        x_offset+=28
                elif(101<= font_number<=200):
                    if(font_number == 112 ):
                        y_offset-=15
                        x_offset+=42
                    elif(186 <=font_number <= 187 or 190 <=font_number <= 192 ):
                        y_offset-=10
                        x_offset+=25
                    elif(171 <=font_number <= 183 or font_number == 188 or font_number == 199 or font_number == 200  ):
                        y_offset-=10
                        x_offset+=29
                    elif(font_number == 113 or font_number == 154  ):
                        y_offset-=15
                        x_offset+=23
                    elif( font_number == 196 ):
                        y_offset-=10
                        x_offset+=23
                    elif(184<=font_number <= 185 or 193<=font_number <= 194 or font_number == 189 or font_number == 198 ):
                        y_offset-=13
                        x_offset+=19
                    elif(102<=font_number <= 103 or font_number == 105 or font_number == 107 or font_number == 110 ):
                        y_offset-=15
                        x_offset+=38
                    elif(font_number == 119 or font_number == 122 or font_number == 124 or font_number == 131 ):
                        y_offset-=15
                        x_offset+=38
                    elif(font_number == 165 or font_number == 170 ):
                        y_offset-=19
                        x_offset+=35
                    elif(font_number == 116 or font_number == 120 or font_number == 125 or font_number == 128 ):
                        y_offset-=15
                        x_offset+=25
                    elif(font_number == 130 or font_number == 155 or font_number == 161 or font_number == 164 ):
                        y_offset-=17
                        x_offset+=26
                    elif(font_number == 168 ):
                        y_offset-=17
                        x_offset+=25
                    elif( font_number == 195 or font_number == 197 ):
                        y_offset-=10
                        x_offset+=25
                    elif(144 <=font_number <= 145  or font_number == 114 or font_number == 117  ):
                        y_offset-=15
                        x_offset+=34
                    elif( font_number == 106 or font_number == 109 ):
                        y_offset-=15
                        x_offset+=31
                    elif( font_number == 126 or font_number == 127 or font_number == 129 or font_number == 134  ):
                        y_offset-=15
                        x_offset+=35
                    elif( font_number == 142 ):
                        y_offset-=15
                        x_offset+=38
                    elif( font_number == 147 or font_number == 149 or font_number == 152 ):
                        y_offset-=15
                        x_offset+=38
                    elif( font_number == 160 or font_number == 163 or font_number == 167 ):
                        y_offset-=20
                        x_offset+=35
                    else:
                        y_offset-=15
                        x_offset+=29
                elif(201<= font_number<=300):
                    if(font_number == 207 ):
                        y_offset-=10
                        x_offset+=23
                    elif(218 <=font_number <= 220 or font_number == 225 ):
                        y_offset-=8
                        x_offset+=32
                    elif(208<=font_number <= 216):
                        y_offset-=20
                        x_offset-=2
                    elif(font_number == 289 or font_number == 292 ):
                        y_offset-=15
                        x_offset+=28
                    elif(font_number == 290 ):
                        y_offset-=15
                        x_offset+=30
                    elif(font_number == 282 or font_number == 285 or font_number == 287 ):
                        y_offset-=15
                        x_offset+=28
                    elif(font_number == 284 or font_number == 286 or font_number == 288 or font_number == 291 or font_number == 293 ):
                        y_offset-=15
                        x_offset+=35
                    elif(font_number == 261 or font_number == 263 or font_number == 265 ):
                        y_offset-=10
                        x_offset+=38
                    elif(202 <=font_number <= 203 or 230 <=font_number <= 235 or 239 <=font_number <= 244 ):
                        y_offset-=10
                        x_offset+=25
                    elif(font_number == 266 or font_number == 269 or font_number == 276 ):
                        y_offset-=10
                        x_offset+=25
                    elif(245 <=font_number <= 247 or 259<=font_number <= 260 or  font_number == 267 ):
                        y_offset-=10
                        x_offset+=30
                    elif (font_number== 268):
                        y_offset-=10
                        x_offset+=33
                    elif (font_number== 254 or font_number== 264  ):
                        y_offset-=10
                        x_offset+=30
                    elif (font_number== 272 or font_number== 270 ):
                        y_offset-=10
                        x_offset+=33
                    elif ( font_number== 275 ):
                        y_offset-=10
                        x_offset+=30
                    elif(font_number == 278 or font_number ==280 ):
                        y_offset-=15
                        x_offset+=30
                    elif(font_number == 279 or font_number ==281 ):
                        y_offset-=15
                        x_offset+=38
                    elif(font_number == 294 or font_number == 296 or font_number == 298):
                        y_offset-=10
                        x_offset+=33
                    elif(font_number == 295 or font_number ==297 or font_number == 299 ):
                        y_offset-=10
                        x_offset+=38
                    else:
                        y_offset-=10
                        x_offset+=28
                elif(301<= font_number<=333):
                    if(font_number == 317 or font_number == 321 ):
                        y_offset-=10
                        x_offset+=38
                    elif(font_number == 312 or font_number == 315 or font_number == 322 or font_number == 329 or font_number == 332 ):
                        y_offset-=10
                        x_offset+=26
                    elif(301<=font_number <= 302 or font_number == 304 or font_number == 306 ):
                        y_offset-=10
                        x_offset+=35
                    elif(font_number == 309  or font_number == 319 ):
                        y_offset-=10
                        x_offset+=37
                    elif(  font_number == 316 ):
                        y_offset-=10
                        x_offset+=32
                    elif(font_number == 308  ):
                        y_offset-=10
                        x_offset+=30
                    elif(font_number == 328  or font_number == 331 ):
                        y_offset-=10
                        x_offset+=35
                    elif(313<=font_number <= 314 or 323<=font_number <= 324 ):
                        y_offset-=13
                        x_offset+=33
                    elif(font_number == 311  or font_number == 318 or font_number == 320 or font_number == 326 ):
                        y_offset-=10
                        x_offset+=31
                    else:
                        y_offset-=10
                        x_offset+=28
            elif(char == "ึ" ):
                if(1<= font_number <=100):
                    if(font_number == 64):
                        y_offset+=15
                        x_offset+=25
                    elif(font_number == 56 or font_number == 88 or font_number == 98 ):
                        y_offset+=20
                        x_offset+=16
                    elif(51 <= font_number <= 52 ):
                        y_offset+=20
                        x_offset+=16
                    elif(font_number == 37):
                        y_offset+=15
                        x_offset+=30
                    elif( font_number == 38 or 47<= font_number <= 48  ):
                        y_offset+=20
                        x_offset+=26
                    elif( font_number == 45 or font_number == 60 ):
                        y_offset+=20
                        x_offset+=26
                    elif( font_number == 57 or font_number == 62 or font_number == 99 ):
                        y_offset+=20
                        x_offset+=28
                    elif(10<= font_number <= 13 or 18<= font_number <= 19  ):
                        y_offset+=18
                        x_offset+=19
                    elif(font_number == 21 or  font_number == 29 or  font_number == 31  ):
                        y_offset+=18
                        x_offset+=19
                    elif(font_number == 80 or  font_number == 89 or  font_number == 91 or  font_number == 93  ):
                        y_offset+=18
                        x_offset+=18
                    elif(16<= font_number <= 17 or  font_number ==55 or 70<= font_number <= 71 or  86<= font_number <= 87 ):
                        y_offset+=20
                        x_offset+=21
                    elif(font_number == 3 or  font_number ==8 or  font_number == 14 or   font_number == 20 ):
                        y_offset+=20
                        x_offset+=21
                    elif(font_number == 23 or  font_number ==26 or  font_number == 28 or font_number == 30 or font_number == 33 ):
                        y_offset+=20
                        x_offset+=21
                    elif(font_number == 36 or  font_number ==41 or  font_number == 44  or font_number == 50 ):
                        y_offset+=20
                        x_offset+=21
                    elif( font_number == 46):
                        y_offset+=20
                        x_offset+=23
                    elif( font_number == 94 or font_number == 92 ):
                        y_offset+=20
                        x_offset+=23
                    elif(53<= font_number <= 54 or  font_number == 96 ):
                        y_offset+=20
                        x_offset+=18
                    elif(font_number == 66 or  font_number ==73 or  font_number == 75  or font_number == 78 ):
                        y_offset+=20
                        x_offset+=21
                    elif(font_number == 82 or  font_number ==84  or font_number == 97 ):
                        y_offset+=20
                        x_offset+=21
                    elif(font_number == 49 or  font_number ==42 ):
                        y_offset+=20
                        x_offset+=23
                    else:
                        y_offset+=20
                        x_offset+=25
                elif(101<= font_number <=200):
                    if(font_number == 141 or font_number == 148 or font_number == 151 or font_number == 159 ):
                        y_offset+=20
                        x_offset+=28
                    elif(102 <=font_number <= 103 or 114 <=font_number <= 117 or 126 <=font_number <= 127  ):
                        y_offset+=20
                        x_offset+=22
                    elif(font_number == 105 or font_number ==107 or font_number == 110 or font_number == 129 or font_number == 131  ):
                        y_offset+=20
                        x_offset+=23
                    elif(136<=font_number <= 137 or 144 <=font_number <= 145 or 162 <=font_number <= 163  ):
                        y_offset+=20
                        x_offset+=22
                    elif(186<=font_number <= 188 or 190 <=font_number <= 192 or 195 <=font_number <= 197  ):
                        y_offset+=20
                        x_offset+=20
                    elif(font_number == 147 or font_number == 165    ):
                        y_offset+=18
                        x_offset+=22
                    elif(font_number == 139 or font_number == 167   ):
                        y_offset+=18
                        x_offset+=23
                    elif(153 <=font_number <= 158 or 181 <=font_number <= 183  ):
                        y_offset+=18
                        x_offset+=23
                    elif(font_number == 124 or font_number == 134 or font_number == 149 or font_number == 160 or font_number == 170  ):
                        y_offset+=18
                        x_offset+=23
                    elif(184 <=font_number <= 185 or font_number == 189  ):
                        y_offset+=20
                        x_offset+=20
                    elif(193 <=font_number <= 194   ):
                        y_offset+=20
                        x_offset+=15
                    elif( font_number == 198  ):
                        y_offset+=20
                        x_offset+=18
                    else:
                        y_offset+=20
                        x_offset+=25
                elif(201<= font_number <=300):
                    if(font_number == 228 ):
                        y_offset+=20
                        x_offset+=23
                    elif(218 <=font_number <= 220  ):
                        y_offset+=20
                        x_offset+=27
                    elif(239 <=font_number <= 240 or font_number == 244   ):
                        y_offset+=20
                        x_offset+=20
                    elif(font_number == 277 or font_number == 293):
                        y_offset+=20
                        x_offset+=17
                    elif(202 <=font_number <= 207 ):
                        y_offset+=20
                        x_offset+=22
                    elif(230 <=font_number <= 238 ):
                        y_offset+=20
                        x_offset+=22
                    elif(font_number == 242 ):
                        y_offset+=20
                        x_offset+=20
                    elif(font_number == 241 ):
                        y_offset+=20
                        x_offset+=20
                    elif(font_number == 243 or 248<=font_number <= 249 ):
                        y_offset+=20
                        x_offset+=22
                    elif(font_number == 251 or font_number == 253 or 255<=font_number <= 256 ):
                        y_offset+=20
                        x_offset+=22
                    elif(font_number == 264 or font_number == 269 or font_number == 271 or font_number == 273 ):
                        y_offset+=20
                        x_offset+=22
                    elif( 267<= font_number <= 268   ):
                        y_offset+=20
                        x_offset+=18
                    elif(font_number == 272 ):
                        y_offset+=20
                        x_offset+=20
                    elif(font_number == 276 or  font_number == 279 or 281<=font_number <= 282 ):
                        y_offset+=20
                        x_offset+=22
                    elif(font_number == 278 ):
                        y_offset+=20
                        x_offset+=23
                    elif(font_number == 285 or  font_number == 295 or font_number == 292 or font_number == 287 or font_number == 289 ):
                        y_offset+=20
                        x_offset+=22
                    elif(font_number == 290 ):
                        y_offset+=20
                        x_offset+=24
                    elif(font_number == 288    or font_number == 291 ):
                        y_offset+=20
                        x_offset+=20
                    elif(font_number == 297 or 299<= font_number <= 300   ):
                        y_offset+=20
                        x_offset+=22
                    elif(font_number == 261   or  font_number == 266  ):
                        y_offset+=20
                        x_offset+=22
                    elif( font_number == 263 or font_number == 265 ):
                        y_offset+=20
                        x_offset+=20
                    elif(font_number == 270  or 283<= font_number <= 284 or font_number == 286   ):
                        y_offset+=20
                        x_offset+=18
                    elif(font_number == 275 ):
                        y_offset+=20
                        x_offset+=20
                    elif( 208 <=font_number <= 216 ):
                        y_offset+=15
                        x_offset+=0
                    else:
                        y_offset+=20
                        x_offset+=25
                elif(301<= font_number <=333):
                    if(313 <=font_number <= 314  ):
                        y_offset+=20
                        x_offset+=18
                    elif(font_number == 301 or font_number == 311 or font_number == 326 or font_number == 333 ):
                        y_offset+=20
                        x_offset+=15
                    elif(font_number == 315  ):
                        y_offset+=20
                        x_offset+=19
                    elif(323 <=font_number <= 324  ):
                        y_offset+=20
                        x_offset+=15
                    elif(font_number == 302 or font_number == 304 or font_number == 306 or font_number == 319 or font_number == 328 ):
                        y_offset+=20
                        x_offset+=18
                    elif(309<= font_number <= 310 or 321<= font_number <= 322 or 331<= font_number <= 332  ):
                        y_offset+=20
                        x_offset+=20
                    elif(font_number == 303 or font_number == 325 or font_number == 329 ):
                        y_offset+=20
                        x_offset+=23
                    elif( font_number == 312 ):
                        y_offset+=20
                        x_offset+=25
                    elif( font_number == 317 ):
                        y_offset+=20
                        x_offset+=21
                    else:
                        y_offset+=20
                        x_offset+=25
            elif(char == "ํ" ):
                if(1<= font_number <=100):
                    if(1<= font_number <= 2 or 4<= font_number <= 7 ):
                        y_offset+=35
                        x_offset+=23
                    elif(11<= font_number <=14 ):
                        y_offset+=30
                        x_offset+=25
                    elif( font_number ==9 ):
                        y_offset+=33
                        x_offset+=33
                    elif( font_number ==10 ):
                        y_offset+=35
                        x_offset+=23
                    elif( font_number ==15 ):
                        y_offset+=35
                        x_offset+=25
                    elif( font_number ==17  ):
                        y_offset+=35
                        x_offset+=22
                    elif( font_number ==19 or font_number ==21  ):
                        y_offset+=35
                        x_offset+=14
                    elif( font_number ==18):
                        y_offset+=35
                        x_offset+=13
                    elif( font_number ==23 or font_number ==26 or font_number ==29  ):
                        y_offset+=37
                        x_offset+=15
                    elif(font_number ==33 or 41<= font_number <=42  ):
                        y_offset+=37
                        x_offset+=15
                    elif( font_number ==31 ):
                        y_offset+=37
                        x_offset+=12
                    elif(font_number ==44 or font_number ==46 or font_number ==66 or font_number ==68 or font_number ==78    ):
                        y_offset+=35
                        x_offset+=15
                    elif(font_number ==71 or font_number ==73 or font_number ==75 ):
                        y_offset+=35
                        x_offset+=13
                    elif( font_number ==89 or font_number ==93    ):
                        y_offset+=35
                        x_offset+=15
                    elif(font_number ==88 or font_number ==91 ):
                        y_offset+=35
                        x_offset+=11
                    elif( font_number ==70 or font_number ==80   or font_number ==98   ):
                        y_offset+=35
                        x_offset+=11
                    elif(font_number ==20 ):
                        y_offset+=37
                        x_offset+=20
                    elif( font_number ==22 ):
                        y_offset+=35
                        x_offset+=23
                    elif(font_number ==25 or font_number ==27  ):
                        y_offset+=37
                        x_offset+=23
                    elif(font_number ==24  ):
                        y_offset+=37
                        x_offset+=22
                    elif(font_number ==34 or font_number ==35 or font_number ==43  ):
                        y_offset+=37
                        x_offset+=22
                    elif(font_number ==38 ):
                        y_offset+=37
                        x_offset+=25
                    elif(font_number ==40 ):
                        y_offset+=37
                        x_offset+=21
                    elif(font_number ==45 or font_number ==47 or font_number ==48):
                        y_offset+=35
                        x_offset+=24
                    elif(font_number ==65 or font_number ==67 ):
                        y_offset+=35
                        x_offset+=23
                    elif(font_number ==76 ):
                        y_offset+=35
                        x_offset+=20
                    elif( font_number ==77 ):
                        y_offset+=35
                        x_offset+=21
                    elif( font_number ==81 or  font_number ==85 ):
                        y_offset+=35
                        x_offset+=27
                    elif( font_number ==83  ):
                        y_offset+=35
                        x_offset+=25
                    elif( font_number ==90 ):
                        y_offset+=35
                        x_offset+=20
                    elif( font_number ==92 or  font_number ==94 ):
                        y_offset+=35
                        x_offset+=22
                    elif( font_number ==95 or  font_number ==99  ):
                        y_offset+=35
                        x_offset+=23
                    elif( font_number ==37 ):
                        y_offset+=35
                        x_offset+=33
                    elif( font_number ==50 or font_number ==58 or font_number ==63 ):
                        y_offset+=40
                        x_offset+=19
                    elif(  font_number ==55 ):
                        y_offset+=40
                        x_offset+=18
                    elif(  font_number ==82 ):
                        y_offset+=35
                        x_offset+=20
                    elif(  font_number ==64 ):
                        y_offset+=25
                        x_offset+=22
                    elif(  font_number ==30 or  font_number ==32):
                        y_offset+=35
                        x_offset+=22
                    elif(font_number ==57):
                        y_offset+=42
                        x_offset+=27
                    elif(font_number ==59 ):
                        y_offset+=42
                        x_offset+=20
                    elif(60<=font_number <=61 ):
                        y_offset+=42
                        x_offset+=24
                    elif(font_number ==62 ):
                        y_offset+=42
                        x_offset+=26
                    elif(font_number ==51 ):
                        y_offset+=42
                        x_offset+=10
                    elif(font_number ==52 ):
                        y_offset+=42
                        x_offset+=13
                    elif(font_number ==53 ):
                        y_offset+=40
                        x_offset+=16
                    elif(font_number ==54 ):
                        y_offset+=40
                        x_offset+=13
                    elif(font_number ==56 ):
                        y_offset+=40
                        x_offset+=8
                    elif(font_number ==74 ):
                        y_offset+=35
                        x_offset+=20
                    else:
                        y_offset+=35
                        x_offset+=18
                elif(101<= font_number <=200):
                    if(162<= font_number <= 163 or font_number == 165 ):
                        y_offset+=28
                        x_offset+=12
                    elif(font_number ==161 ):
                        y_offset+=28
                        x_offset+=18
                    elif(font_number ==164 or font_number ==168 ):
                        y_offset+=28
                        x_offset+=20
                    elif(font_number ==160 or font_number ==167 or font_number ==170  ):
                        y_offset+=28
                        x_offset+=15
                    elif(font_number ==126 or font_number ==127 or font_number ==129  ):
                        y_offset+=38
                        x_offset+=16
                    elif(font_number ==131 or font_number ==142  ):
                        y_offset+=38
                        x_offset+=18
                    elif(font_number ==128 ):
                        y_offset+=34
                        x_offset+=20
                    elif(font_number ==123 or font_number ==135 ):
                        y_offset+=38
                        x_offset+=25
                    elif(font_number ==141 ):
                        y_offset+=38
                        x_offset+=27
                    elif(font_number ==159  ):
                        y_offset+=28
                        x_offset+=23
                    elif( font_number ==166 ):
                        y_offset+=28
                        x_offset+=21
                    elif(font_number ==169 ):
                        y_offset+=30
                        x_offset+=22
                    elif(102<=font_number <=103 or font_number ==105   ):
                        y_offset+=30
                        x_offset+=13
                    elif( font_number ==107 or font_number ==110 ):
                        y_offset+=30
                        x_offset+=15
                    elif( font_number ==114 or font_number ==117  ):
                        y_offset+=30
                        x_offset+=15
                    elif( font_number ==119  ):
                        y_offset+=30
                        x_offset+=18
                    elif(font_number ==145  ):
                        y_offset+=37
                        x_offset+=15
                    elif( font_number ==125 ):
                        y_offset+=37
                        x_offset+=19
                    elif(font_number ==144 ):
                        y_offset+=37
                        x_offset+=13
                    elif(font_number ==147):
                        y_offset+=37
                        x_offset+=13
                    elif( font_number ==149 or font_number ==152 or font_number ==198 ):
                        y_offset+=37
                        x_offset+=17
                    elif( font_number ==104 or font_number ==106 ):
                        y_offset+=35
                        x_offset+=22
                    elif( font_number ==109):
                        y_offset+=35
                        x_offset+=23
                    elif( font_number ==108 ):
                        y_offset+=35
                        x_offset+=21
                    elif( font_number ==132 ):
                        y_offset+=35
                        x_offset+=20
                    elif( font_number ==111 or font_number ==112 or font_number ==121 ):
                        y_offset+=30
                        x_offset+=22
                    elif( font_number ==130):
                        y_offset+=38
                        x_offset+=22
                    elif( font_number ==133 or font_number ==138 or font_number ==139 or font_number ==140 ):
                        y_offset+=38
                        x_offset+=24
                    elif( font_number ==143 or font_number ==146  ):
                        y_offset+=35
                        x_offset+=24
                    elif(  font_number ==148 ):
                        y_offset+=38
                        x_offset+=25
                    elif( font_number ==150  or 155<= font_number <=158  ):
                        y_offset+=35
                        x_offset+=24
                    elif(font_number ==151 ):
                        y_offset+=40
                        x_offset+=26
                    elif(font_number ==153):
                        y_offset+=30
                        x_offset+=28
                    elif(font_number ==171 or 175<= font_number <=183  or 186<= font_number <=188 or 190<= font_number <=192  ):
                        y_offset+=35
                        x_offset+=26
                    elif( 172<= font_number <=174 ):
                        y_offset+=35
                        x_offset+=32
                    elif( 193<= font_number <=196 ):
                        y_offset+=38
                        x_offset+=20
                    elif(font_number ==199 or font_number ==200 ):
                        y_offset+=36
                        x_offset+=28
                    elif(font_number ==197 ):
                        y_offset+=36
                        x_offset+=25
                    elif(font_number ==189 ):
                        y_offset+=35
                        x_offset+=20
                    elif(184<=font_number <=185 ):
                        y_offset+=35
                        x_offset+=20
                    else:
                        y_offset+=30
                        x_offset+=20
                elif(201<= font_number <=300):
                    if(267<= font_number <= 268 or font_number == 270 or font_number == 272  ):
                        y_offset+=33
                        x_offset+=13
                    elif(font_number == 293 ):
                        y_offset+=33
                        x_offset+=10
                    elif(font_number ==239 or font_number ==240 ):
                        y_offset+=40
                        x_offset+=22
                    elif(font_number ==266 or font_number ==285 ):
                        y_offset+=35
                        x_offset+=22
                    elif(font_number ==286 or font_number ==288 ):
                        y_offset+=35
                        x_offset+=15
                    elif( font_number ==295 or font_number ==297 ):
                        y_offset+=38
                        x_offset+=17
                    elif( font_number ==299 ):
                        y_offset+=40
                        x_offset+=16
                    elif( font_number ==300 ):
                        y_offset+=40
                        x_offset+=20
                    elif(font_number ==220 or font_number ==218 ):
                        y_offset+=40
                        x_offset+=30
                    elif(font_number ==219  ):
                        y_offset+=40
                        x_offset+=28
                    elif(font_number ==227 or font_number ==229 or font_number ==225  ):
                        y_offset+=40
                        x_offset+=28
                    elif(font_number ==236 or font_number ==294 or font_number ==296 or font_number ==298  ):
                        y_offset+=40
                        x_offset+=28
                    elif(font_number ==254 or font_number ==259 or font_number ==262 ):
                        y_offset+=35
                        x_offset+=24
                    elif(font_number ==269 or font_number ==290 ):
                        y_offset+=35
                        x_offset+=22
                    elif(font_number ==201 or font_number ==260 or font_number ==264 ):
                        y_offset+=35
                        x_offset+=26
                    elif(255<=font_number <=256  or font_number ==261 or font_number ==263 ):
                        y_offset+=35
                        x_offset+=18
                    elif(font_number ==258 ):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number ==257 or font_number ==287  ):
                        y_offset+=35
                        x_offset+=22
                    elif(font_number ==284  or font_number ==265 ):
                        y_offset+=35
                        x_offset+=16
                    elif(font_number ==283 ):
                        y_offset+=35
                        x_offset+=12
                    elif(font_number ==292  ):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number ==291 ):
                        y_offset+=35
                        x_offset+=15
                    elif(font_number ==282 ):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number ==281   ):
                        y_offset+=35
                        x_offset+=17
                    elif( font_number ==275  ):
                        y_offset+=35
                        x_offset+=15
                    elif( font_number ==276  ):
                        y_offset+=35
                        x_offset+=20
                    elif( font_number ==279  ):
                        y_offset+=35
                        x_offset+=16
                    elif( font_number ==278  ):
                        y_offset+=35
                        x_offset+=23
                    elif( font_number ==277  ):
                        y_offset+=35
                        x_offset+=10
                    elif( font_number ==244  ):
                        y_offset+=40
                        x_offset+=20
                    elif(font_number ==289  or font_number ==290):
                        y_offset+=35
                        x_offset+=22
                    elif(font_number ==280  or font_number ==273 or font_number ==271 or font_number ==274):
                        y_offset+=35
                        x_offset+=24
                    elif(245<=font_number <=247  ):
                        y_offset+=40
                        x_offset+=28
                    elif(208<=font_number <=216  ):
                        y_offset+=30
                        x_offset+=0
                    else:
                        y_offset+=40
                        x_offset+=24
                elif(301<= font_number <=333):
                    if(301<= font_number <= 302 or font_number == 304   ):
                        y_offset+=40
                        x_offset+=10
                    elif(font_number == 306 ):
                        y_offset+=40
                        x_offset+=13
                    elif(font_number == 314 or font_number == 326 ):
                        y_offset+=35
                        x_offset+=10
                    elif(font_number == 309   ):
                        y_offset+=40
                        x_offset+=13
                    elif( font_number == 310   ):
                        y_offset+=40
                        x_offset+=18
                    elif( font_number == 313   ):
                        y_offset+=35
                        x_offset+=15
                    elif( font_number == 315 ):
                        y_offset+=38
                        x_offset+=18
                    elif( font_number == 319 ):
                        y_offset+=38
                        x_offset+=15
                    elif( font_number == 324  ):
                        y_offset+=38
                        x_offset+=12
                    elif( font_number == 328 ):
                        y_offset+=38
                        x_offset+=12
                    elif(  font_number == 331   ):
                        y_offset+=38
                        x_offset+=14
                    elif(font_number == 332  ):
                        y_offset+=38
                        x_offset+=20
                    elif(font_number == 303 or font_number == 322 or font_number == 325 ):
                        y_offset+=40
                        x_offset+=22
                    elif( font_number == 317  or font_number == 321 ):
                        y_offset+=40
                        x_offset+=18
                    elif( font_number == 316  or font_number == 318  or font_number == 320):
                        y_offset+=40
                        x_offset+=28
                    elif( font_number == 311):
                        y_offset+=40
                        x_offset+=10
                    elif( font_number == 312):
                        y_offset+=35
                        x_offset+=22
                    elif( font_number == 323  or font_number == 333):
                        y_offset+=40
                        x_offset+=8
                    
                    else:
                        y_offset+=40
                        x_offset+=24
                   
            elif(char == "ั" ):
                if(1<=font_number<=8):
                    y_offset+=23
                    x_offset+=18
                elif(font_number==9):
                    y_offset+=20
                    x_offset+=23
                elif(10<=font_number<=14):
                    y_offset+=20
                    x_offset+=17
                elif(18<=font_number<=19 or font_number==16 or font_number==21 ):
                    y_offset+=25
                    x_offset+=18
                elif(font_number==17 or font_number==20 ):
                    y_offset+=25
                    x_offset+=20
                elif(font_number==23 ):
                    y_offset+=25
                    x_offset+=18
                elif(24<=font_number<=25 ):
                    y_offset+=25
                    x_offset+=22
                elif(font_number==26 ):
                    y_offset+=25
                    x_offset+=18
                elif(font_number==27):
                    y_offset+=22
                    x_offset+=23
                elif(font_number==28 or font_number==29 or font_number==31 or font_number==33 ):
                    y_offset+=22
                    x_offset+=18
                elif(font_number==27 or font_number==30 or font_number==32 or 34<= font_number<=36 ):
                    y_offset+=22
                    x_offset+=21
                elif(font_number==37 or font_number==38):
                    y_offset+=22
                    x_offset+=27
                elif(font_number==40):
                    y_offset+=25
                    x_offset+=21
                elif(font_number==41 or font_number == 42):
                    y_offset+=25
                    x_offset+=18
                elif(font_number==45 or font_number==48 ):
                    y_offset+=25
                    x_offset+=25
                elif(font_number==44 or font_number == 46):
                    y_offset+=25
                    x_offset+=18
                elif(font_number==50 ):
                    y_offset+=25
                    x_offset+=16
                elif( font_number==53 or font_number==55):
                    y_offset+=25
                    x_offset+=14
                elif( font_number==51 or font_number==52 or font_number==54 or font_number==56 ):
                    y_offset+=25
                    x_offset+=12
                elif(font_number==57 ):
                    y_offset+=25
                    x_offset+=30
                elif(font_number==59 or font_number==61 ):
                    y_offset+=25
                    x_offset+=25
                elif(font_number==60 or font_number==62 ):
                    y_offset+=25
                    x_offset+=28
                elif(font_number==64 ):
                    y_offset+=18
                    x_offset+=20
                elif(font_number==65 or font_number==67 ):
                    y_offset+=20
                    x_offset+=27
                elif(font_number==69 or font_number==71 ):
                    y_offset+=25
                    x_offset+=20
                elif(font_number==70 ):
                    y_offset+=25
                    x_offset+=14
                elif( font_number==73 ):
                    y_offset+=25
                    x_offset+=18
                elif( font_number==74 ):
                    y_offset+=25
                    x_offset+=25
                elif(font_number==75  ):
                    y_offset+=25
                    x_offset+=20
                elif(font_number==76 ):
                    y_offset+=25
                    x_offset+=24
                elif(font_number==77 ):
                    y_offset+=25
                    x_offset+=26
                elif(font_number==79 ):
                    y_offset+=25
                    x_offset+=19
                elif(font_number==80 ):
                    y_offset+=25
                    x_offset+=15
                elif(font_number==81 or font_number==83 or font_number== 85 or font_number==87 ):
                    y_offset+=20
                    x_offset+=22
                elif(font_number==90 or font_number==92 or font_number== 94 or font_number==95 or font_number==97 ):
                    y_offset+=20
                    x_offset+=22
                elif(font_number==82 or font_number==84 or font_number== 86 or font_number==93 or font_number== 96 ):
                    y_offset+=20
                    x_offset+=18
                elif( font_number==88 or font_number==89 or font_number==91 or font_number== 98):
                    y_offset+=20
                    x_offset+=15
                elif(font_number==100):
                    y_offset+=25
                    x_offset+=20
                elif(101<=font_number<=200):
                    if(144<=font_number<=145):
                        y_offset+=25
                        x_offset+=18
                    elif(font_number==147 or font_number==149 or font_number==152):
                        y_offset+=25
                        x_offset+=18
                    elif(102<=font_number<=103 or font_number==105 or font_number==107 ):
                        y_offset+=25
                        x_offset+=20
                    elif(font_number==108 ):
                        y_offset+=25
                        x_offset+=25
                    elif(font_number==110 ):
                        y_offset+=25
                        x_offset+=18
                    elif(118<=font_number<=122 ):
                        y_offset+=23
                        x_offset+=21
                    elif( font_number==126  ):
                        y_offset+=25
                        x_offset+=18
                    elif(font_number==124 or font_number==125 ):
                        y_offset+=25
                        x_offset+=21
                    elif(font_number==128 ):
                        y_offset+=25
                        x_offset+=21
                    elif(font_number==127 or font_number==129  ):
                        y_offset+=25
                        x_offset+=18
                    elif(font_number==131 or font_number==132 or font_number==134  ):
                        y_offset+=25
                        x_offset+=20
                    elif(font_number==136 or font_number==137   ):
                        y_offset+=25
                        x_offset+=18
                    elif(font_number==138 or font_number==139   ):
                        y_offset+=25
                        x_offset+=18
                    elif(font_number==140 or font_number==142  ):
                        y_offset+=25
                        x_offset+=19
                    elif(181<=font_number<=198):
                        y_offset+=25
                        x_offset+=18
                    elif(font_number==141):
                        y_offset+=25
                        x_offset+=25
                    elif(font_number==114):
                        y_offset+=20
                        x_offset+=15
                    elif(font_number==117):
                        y_offset+=20
                        x_offset+=18
                    elif(115<=font_number<=116 or font_number==113 ):
                        y_offset+=20
                        x_offset+=19
                    elif(153<=font_number<=158 ):
                        y_offset+=20
                        x_offset+=19                  
                    elif(font_number==170 or font_number==160 or font_number==167 or font_number==162 or font_number==163 or font_number==165 ):
                        y_offset+=20
                        x_offset+=19
                    elif(font_number==161 ):
                        y_offset+=20
                        x_offset+=20
                    elif(font_number==159  or font_number==169 ):
                        y_offset+=20
                        x_offset+=25
                    elif( font_number==164 or font_number==166 or font_number==168 ):
                        y_offset+=20
                        x_offset+=24
                    else:
                        y_offset+=25
                        x_offset+=23
                elif(201<=font_number<=300):
                    if(230<=font_number<=231 or 241<=font_number<=242 ):
                        y_offset+=25
                        x_offset+=16
                    elif(208<=font_number<=216 ):
                        y_offset+=20
                        x_offset+=0
                    elif(font_number==297 ):
                        y_offset+=25
                        x_offset+=16
                    elif(font_number==244 ):
                        y_offset+=25
                        x_offset+=14
                    elif(font_number==293 ):
                        y_offset+=25
                        x_offset+=13
                    elif(221<=font_number<=224):
                        y_offset+=25
                        x_offset+=19
                    elif(232<=font_number<=234 or font_number==226 ):
                        y_offset+=25
                        x_offset+=18
                    elif(248<=font_number<=251 or font_number==243 or font_number==253 ):
                        y_offset+=25
                        x_offset+=18
                    elif(font_number==252 ):
                        y_offset+=25
                        x_offset+=20
                    elif(font_number==261 or font_number==263 or font_number==265 ):
                        y_offset+=25
                        x_offset+=15
                    elif(font_number==275 or font_number==279 or font_number==288 ):
                        y_offset+=25
                        x_offset+=18
                    elif(font_number==283 or font_number==284 or font_number==286 ):
                        y_offset+=25
                        x_offset+=15
                    elif(font_number==291 or font_number==292 or font_number==295 or font_number==299 or  font_number==300 ):
                        y_offset+=25
                        x_offset+=18
                    elif(font_number==227 or font_number==219 ):
                        y_offset+=25
                        x_offset+=22
                    elif(font_number==218 or font_number==220 ):
                        y_offset+=25
                        x_offset+=25
                    elif(font_number==245 or font_number==247 or font_number==254 ):
                        y_offset+=25
                        x_offset+=23
                    elif(font_number==278 or font_number==280 or font_number==287 ):
                        y_offset+=25
                        x_offset+=23
                    elif(font_number==290 or font_number==294 or font_number==296 or font_number==298 ):
                        y_offset+=25
                        x_offset+=23
                    elif(266<=font_number<=270 or font_number==276 or font_number==272  ):
                        y_offset+=20
                        x_offset+=17
                    elif(font_number==273 or font_number==274 or font_number==271 ):
                        y_offset+=20
                        x_offset+=21
                    elif( font_number==277 ):
                        y_offset+=20
                        x_offset+=15
                    elif( font_number==235 or font_number==239 or font_number==240 ):
                        y_offset+=25
                        x_offset+=15
                    else:
                        y_offset+=25
                        x_offset+=21
                elif(301<=font_number<=333):
                    if(font_number==302 or font_number==304 or font_number==306  ):
                        y_offset+=25
                        x_offset+=12
                    elif(font_number==301):
                        y_offset+=25
                        x_offset+=10
                    elif(font_number==311  or font_number==323 ):
                        y_offset+=25
                        x_offset+=10
                    elif( font_number==314 ):
                        y_offset+=25
                        x_offset+=13
                    elif(font_number==324  or font_number==326 or font_number==333 ):
                        y_offset+=25
                        x_offset+=12
                    elif(font_number==316  or font_number==318 or font_number==320 ):
                        y_offset+=25
                        x_offset+=23
                    elif(font_number==303  or font_number==305 ):
                        y_offset+=25
                        x_offset+=20
                    elif( font_number==308 ):
                        y_offset+=25
                        x_offset+=23
                    elif( font_number==307 ):
                        y_offset+=25
                        x_offset+=20
                    elif(  font_number==312  or font_number==317):
                        y_offset+=25
                        x_offset+=18
                    elif( font_number==310 ):
                        y_offset+=25
                        x_offset+=16
                    elif( font_number==322 or font_number==325  ):
                        y_offset+=25
                        x_offset+=18
                    elif(  font_number==327):
                        y_offset+=25
                        x_offset+=20
                    elif( font_number==315 ):
                        y_offset+=25
                        x_offset+=17
                    elif( font_number==329 or font_number==330 ):
                        y_offset+=25
                        x_offset+=22
                    elif( font_number==332  ):
                        y_offset+=25
                        x_offset+=17
                    else:
                        y_offset+=25
                        x_offset+=15
                else:
                    y_offset+=25
                    x_offset+=23
                    

            draw.text((x_offset, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            output_path = char_folder / f"{char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")

# %% [markdown]
# ## Thai Tones

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# ระบุโฟลเดอร์ที่ต้องการอ่านไฟล์ทั้งหมด
output_folder = Path("../data/raw_images/thai_tones")
folder_path = Path("../font/GoogleFont")


if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':

        for char in "่้๊๋์": # เอก โท ตรี จัตวา การัน
            try:
                if(char == "่"):
                    font = ImageFont.truetype(str(font_file), 100)
                elif(char == "้"):
                    font = ImageFont.truetype(str(font_file), 60)
                elif(char == "๊"):
                    font = ImageFont.truetype(str(font_file), 60)
                elif(char == "๋"):
                    font = ImageFont.truetype(str(font_file), 90)
                elif(char == "์"):
                    font = ImageFont.truetype(str(font_file), 90)
            except Exception as e:
                print(f"Skipping font {font_file}: {e}")
                continue

            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / f"{char}"
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y ทั่วไป
            y_offset = ascent - bbox[3]
            x_offset = 0

            # ปรับตำแหน่ง y_offset เฉพาะจุด
            # +ลง -ขึ้น



            if(char == "่"): # เอก 
                if(1<=font_number<=100):
                    if(font_number == 77 ):
                        y_offset+=37
                        x_offset+=20
                    elif(font_number == 37 ):
                        y_offset+=40
                        x_offset+=33
                    elif(font_number == 81 or font_number == 85 ):
                        y_offset+=33
                        x_offset+=30
                    elif(font_number == 26 or font_number == 36 or font_number == 100 ):
                        y_offset+=38
                        x_offset+=11
                    elif( font_number == 92 ):
                        y_offset+=35
                        x_offset+=25
                    elif(font_number == 64  ):
                        y_offset+=30
                        x_offset+=25
                    elif( font_number == 78 or font_number == 89  ):
                        y_offset+=37
                        x_offset+=10
                    elif(font_number == 17 or font_number ==40 or font_number ==69  ):
                        y_offset+=40
                        x_offset+=20
                    elif( font_number == 16 or font_number ==39 or font_number ==68 ):
                        y_offset+=37
                        x_offset+=13
                    elif( font_number == 49 or font_number ==28 or font_number ==66 ):
                        y_offset+=40
                        x_offset+=12
                    elif( font_number == 72 or font_number ==87 or font_number ==93 ):
                        y_offset+=37
                        x_offset+=13
                    elif(11<= font_number <= 14 or font_number ==20 or font_number ==22 ):
                        y_offset+=37
                        x_offset+=23
                    elif( font_number ==65 or font_number ==67):
                        y_offset+=37
                        x_offset+=23
                    elif( font_number ==74 or font_number ==76 ):
                        y_offset+=37
                        x_offset+=20
                    elif(  font_number ==84 ):
                        y_offset+=35
                        x_offset+=18
                    elif( font_number ==82  ):
                        y_offset+=35
                        x_offset+=21
                    elif( font_number ==86 or font_number ==90):
                        y_offset+=35
                        x_offset+=19
                    elif(font_number ==94  or font_number ==99):
                        y_offset+=37
                        x_offset+=19
                    elif( font_number ==96 ):
                        y_offset+=37
                        x_offset+=15
                    elif(34<=font_number <=35  or 47<= font_number <=48 or font_number == 30 or font_number == 32 or font_number == 38):
                        y_offset+=42
                        x_offset+=25
                    elif( font_number == 43 or font_number == 45 or font_number ==50):
                        y_offset+=44
                        x_offset+=25
                    elif( font_number == 57 or font_number == 55  or font_number ==62):
                        y_offset+=48
                        x_offset+=20
                    elif( font_number ==60 ):
                        y_offset+=48
                        x_offset+=17
                    elif(font_number ==19  or  font_number ==42 or 52<=font_number <=54  or 58<= font_number <=59):
                        y_offset+=45
                        x_offset+=10
                    elif(font_number ==18  or font_number ==41 or font_number ==51  ):
                        y_offset+=42
                        x_offset+=6
                    elif(font_number ==71 ):
                        y_offset+=40
                        x_offset+=7
                    elif(font_number ==70 ):
                        y_offset+=40
                        x_offset+=6
                    elif(font_number ==79  ):
                        y_offset+=40
                        x_offset+=10
                    elif(font_number ==80  ):
                        y_offset+=40
                        x_offset+=5
                    elif(  font_number ==97  ):
                        y_offset+=40
                        x_offset+=15
                    elif(font_number ==98  ):
                        y_offset+=38
                        x_offset+=4
                    elif(font_number ==29 or font_number ==31 or font_number ==33  ):
                        y_offset+=40
                        x_offset+=9
                    elif( font_number ==23 ):
                        y_offset+=40
                        x_offset+=11
                    elif(font_number ==8 or font_number ==10  ):
                        y_offset+=38
                        x_offset+=16
                    elif(font_number ==21  ):
                        y_offset+=38
                        x_offset+=7
                    elif(font_number ==44 ):
                        y_offset+=42
                        x_offset+=8
                    elif( font_number ==46 ):
                        y_offset+=42
                        x_offset+=10
                    elif(  font_number ==61 ):
                        y_offset+=45
                        x_offset+=16
                    elif( font_number ==88 ):
                        y_offset+=38
                        x_offset+=5
                    elif(font_number ==63 ):
                        y_offset+=45
                        x_offset+=8
                    elif( font_number ==56 ):
                        y_offset+=45
                        x_offset+=1
                    elif( font_number ==73 or font_number ==75 ):
                        y_offset+=38
                        x_offset+=8
                    elif(font_number ==91 ):
                        y_offset+=38
                        x_offset+=7
                    else:
                        y_offset+=37
                        x_offset+=25
                elif(101<=font_number<=200):
                    if(font_number == 167 ):
                        y_offset+=30
                        x_offset+=10
                    elif(font_number == 149 ):
                        y_offset+=43
                        x_offset+=10
                    elif(font_number == 125 or font_number == 128 or font_number == 136 ):
                        y_offset+=43
                        x_offset+=20
                    elif(font_number == 153 ):
                        y_offset+=35
                        x_offset+=30
                    elif(font_number == 107 ):
                        y_offset+=38
                        x_offset+=8
                    elif(font_number == 189 or font_number == 193  ):
                        y_offset+=45
                        x_offset+=15
                    elif(111 <=font_number <= 113 or 168 <=font_number <= 169  ):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number == 161 or font_number == 164 or font_number == 166  ):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number == 110 or font_number == 117 or font_number == 127  ):
                        y_offset+=40
                        x_offset+=12
                    elif(font_number == 142 or font_number == 152   ):
                        y_offset+=43
                        x_offset+=12
                    elif( font_number == 170  ):
                        y_offset+=33
                        x_offset+=12
                    elif(font_number == 115   ):
                        y_offset+=38
                        x_offset+=16
                    elif(font_number == 158   ):
                        y_offset+=35
                        x_offset+=25
                    elif(font_number == 160   ):
                        y_offset+=40
                        x_offset+=10
                    elif( font_number == 124 or font_number == 131 or font_number == 134   ):
                        y_offset+=45
                        x_offset+=16
                    elif(172 <= font_number <= 174 ):
                        y_offset+=43
                        x_offset+=28
                    elif( 181 <= font_number <= 183 or 190 <= font_number <= 192   ):
                        y_offset+=43
                        x_offset+=25
                    elif( font_number == 135 or font_number == 177 or font_number == 179 or 199<= font_number <= 200  ):
                        y_offset+=45
                        x_offset+=25
                    elif( 181 <= font_number <= 183 or 190 <= font_number <= 192   ):
                        y_offset+=43
                        x_offset+=25
                    elif( 150 <= font_number <= 151 or 175 <= font_number <= 176 or 181 <= font_number <= 188 or 194 <= font_number <= 197  ):
                        y_offset+=45
                        x_offset+=20
                    elif( font_number == 123 or font_number == 141 or  font_number == 148 ):
                        y_offset+=45
                        x_offset+=20
                    elif( font_number == 171 or font_number == 178 or  font_number == 180 ):
                        y_offset+=45
                        x_offset+=20
                    elif( 102 <= font_number <= 103 or  font_number == 144 ):
                        y_offset+=40
                        x_offset+=5
                    elif(162 <= font_number <= 163 ):
                        y_offset+=33
                        x_offset+=5
                    elif( font_number == 145  ):
                        y_offset+=40
                        x_offset+=10
                    elif( font_number == 105):
                        y_offset+=40
                        x_offset+=5
                    elif( font_number == 114 or font_number == 126 ):
                        y_offset+=40
                        x_offset+=10
                    elif( font_number == 147  ):
                        y_offset+=40
                        x_offset+=5
                    elif(  font_number == 165  ):
                        y_offset+=35
                        x_offset+=5
                    elif( font_number == 129  or font_number == 198 ):
                        y_offset+=40
                        x_offset+=10
                    else:
                        y_offset+=40
                        x_offset+=20
                elif(201<=font_number<=300):
                    if(font_number == 254 ):
                        y_offset+=35
                        x_offset+=25
                    elif(218 <=font_number <= 220 ):
                        y_offset+=48
                        x_offset+=25
                    elif(font_number ==201 ):
                        y_offset+=42
                        x_offset+=27
                    elif( font_number ==262 or font_number ==264 or font_number ==274 ):
                        y_offset+=38
                        x_offset+=25
                    elif(font_number ==294 or font_number ==296 or font_number ==298 ):
                        y_offset+=42
                        x_offset+=25
                    elif(font_number ==282 or font_number ==292 ):
                        y_offset+=42
                        x_offset+=15
                    elif(font_number ==281 ):
                        y_offset+=40
                        x_offset+=12
                    elif (font_number ==291):
                        y_offset+=40
                        x_offset+=11
                    elif (font_number ==260 ):
                        y_offset+=37
                        x_offset+=28
                    elif ( font_number ==268 ):
                        y_offset+=38
                        x_offset+=9
                    elif ( font_number ==263 ):
                        y_offset+=38
                        x_offset+=15
                    elif (font_number ==265  ):
                        y_offset+=38
                        x_offset+=17
                    elif(font_number ==272  or font_number ==279 or font_number ==288 ):
                        y_offset+=42
                        x_offset+=10
                    elif (font_number ==275  ):
                        y_offset+=38
                        x_offset+=13
                    elif (font_number ==295 or font_number ==297 or font_number ==299  ):
                        y_offset+=45
                        x_offset+=13
                    elif (202<=font_number <=207 ):
                        y_offset+=45
                        x_offset+=20
                    elif ( 255<=font_number <=259 or 289<=font_number <=290):
                        y_offset+=40
                        x_offset+=20
                    elif (font_number ==261 or font_number ==266 or font_number ==269):
                        y_offset+=38
                        x_offset+=20
                    elif (font_number ==271 or font_number ==273 or font_number ==276 or font_number == 278 ):
                        y_offset+=38
                        x_offset+=20
                    elif (font_number ==280 or font_number ==285 or font_number ==287 or font_number == 300 ):
                        y_offset+=40
                        x_offset+=20
                    elif (208<= font_number <=216 ):
                        y_offset+=31
                        x_offset-=1
                    elif ( 283<=font_number <=284 ):
                        y_offset+=40
                        x_offset+=1
                    elif ( font_number ==270 ):
                        y_offset+=38
                        x_offset+=6
                    elif (font_number ==267  or font_number ==277):
                        y_offset+=38
                        x_offset+=4
                    elif (font_number ==286  or font_number ==293):
                        y_offset+=38
                        x_offset+=4
                    else:
                        y_offset+=48
                        x_offset+=20
                elif(301<=font_number<=333):
                    if(font_number == 329 ):
                        y_offset+=45
                        x_offset+=18
                    elif(font_number == 319 ):
                        y_offset+=45
                        x_offset+=10
                    elif(font_number==317 ):
                        y_offset+=45
                        x_offset+=14
                    elif( font_number==321 ):
                        y_offset+=45
                        x_offset+=12
                    elif(font_number==316 or font_number==320 ):
                        y_offset+=45
                        x_offset+=25
                    elif(307<=font_number <=308  ):
                        y_offset+=43
                        x_offset+=22
                    elif(font_number ==303 or font_number ==305 or font_number ==325 or font_number ==327 ):
                        y_offset+=43
                        x_offset+=19
                    elif( font_number ==312 or font_number ==315 ):
                        y_offset+=39
                        x_offset+=18
                    elif(font_number ==309 ):
                        y_offset+=43
                        x_offset+=10
                    elif(  font_number ==331 ):
                        y_offset+=45
                        x_offset+=8
                    elif( font_number ==322  ):
                        y_offset+=45
                        x_offset+=15
                    elif(font_number ==302  ):
                        y_offset+=43
                        x_offset+=6
                    elif(font_number ==301  ):
                        y_offset+=43
                        x_offset+=2
                    elif(font_number ==311  ):
                        y_offset+=43
                        x_offset+=0
                    elif(font_number ==310  ):
                        y_offset+=43
                        x_offset+=13
                    elif(font_number ==314  ):
                        y_offset+=38
                        x_offset+=7
                    elif(font_number ==313  ):
                        y_offset+=40
                        x_offset+=10
                    elif(font_number ==323  ):
                        y_offset+=42
                        x_offset+=2
                    elif(font_number ==324  ):
                        y_offset+=42
                        x_offset+=5
                    elif(font_number ==332  ):
                        y_offset+=42
                        x_offset+=13
                    elif(font_number ==333  ):
                        y_offset+=42
                        x_offset+=0
                    elif(font_number ==304 or font_number ==326   ):
                        y_offset+=42
                        x_offset+=4
                    elif(font_number ==306 or font_number ==328  ):
                        y_offset+=42
                        x_offset+=6
                    else:
                        y_offset+=48
                        x_offset+=22
                
            elif(char == "้"):# โท
                if(1<=font_number<=100):
                    if(16<= font_number <=17 or  font_number ==19   ):
                        y_offset+=26
                        x_offset+=21
                    elif(font_number ==20   ):
                        y_offset+=26
                        x_offset+=23
                    elif(font_number ==31 or font_number ==29 or 41<= font_number <=42 ):
                        y_offset+=26
                        x_offset+=18
                    elif( font_number == 30):
                        y_offset+=26
                        x_offset+=19
                    elif( font_number ==21  ):
                        y_offset+=26
                        x_offset+=19
                    elif( font_number ==18  ):
                        y_offset+=26
                        x_offset+=17
                    elif(68<=font_number <=69  or  font_number ==71):
                        y_offset+=26
                        x_offset+=19
                    elif( font_number ==72  ):
                        y_offset+=26
                        x_offset+=21
                    elif( font_number ==23 or font_number ==26 or font_number ==33 or font_number ==39  ):
                        y_offset+=26
                        x_offset+=19
                    elif(  font_number ==46 or font_number ==49 or font_number ==58  ):
                        y_offset+=26
                        x_offset+=19
                    elif( font_number ==44  ):
                        y_offset+=26
                        x_offset+=17
                    elif(font_number ==66 or font_number ==63  or font_number ==78  ):
                        y_offset+=26
                        x_offset+=19
                    elif(font_number ==75 ):
                        y_offset+=26
                        x_offset+=18
                    elif(font_number ==82 or font_number ==84  or font_number ==93 or font_number ==96  ):
                        y_offset+=26
                        x_offset+=19
                    elif(51<= font_number <=55  ):
                        y_offset+=26
                        x_offset+=12
                    elif(font_number ==50 or font_number ==70  or font_number ==73):
                        y_offset+=26
                        x_offset+=15
                    elif(font_number ==79 ):
                        y_offset+=26
                        x_offset+=17
                    elif( font_number ==80  ):
                        y_offset+=26
                        x_offset+=12
                    elif( font_number ==98):
                        y_offset+=26
                        x_offset+=15
                    elif( font_number ==37):
                        y_offset+=26
                        x_offset+=28
                    elif( font_number ==38 or font_number ==48  ):
                        y_offset+=26
                        x_offset+=25
                    elif( font_number ==60 ):
                        y_offset+=30
                        x_offset+=27
                    elif( font_number ==57 or font_number ==62 ):
                        y_offset+=30
                        x_offset+=30
                    elif(font_number ==67 ):
                        y_offset+=26
                        x_offset+=25
                    elif(font_number ==65 ):
                        y_offset+=26
                        x_offset+=24
                    elif( font_number ==81 ):
                        y_offset+=20
                        x_offset+=25
                    elif( font_number ==86 ):
                        y_offset+=20
                        x_offset+=22
                    elif( font_number ==77 ):
                        y_offset+=30
                        x_offset+=24
                    elif(font_number ==99 ):
                        y_offset+=30
                        x_offset+=28
                    elif(font_number ==64 ):
                        y_offset+=15
                        x_offset+=28
                    elif(font_number ==88 ):
                        y_offset+=26
                        x_offset+=14
                    elif(font_number ==89 ):
                        y_offset+=26
                        x_offset+=16
                    elif(font_number ==27 or font_number == 32 or font_number == 35 ):
                        y_offset+=26
                        x_offset+=25
                    elif( font_number == 36):
                        y_offset+=28
                        x_offset+=21
                    elif( font_number == 56):
                        y_offset+=28
                        x_offset+=8
                    else:
                        y_offset+=26
                        x_offset+=23
                elif(101<=font_number<=200):
                    if(113<= font_number <=120 or 136<= font_number <=139):
                        y_offset+=26
                        x_offset+=18
                    elif( font_number ==144 or  font_number ==147):
                        y_offset+=26
                        x_offset+=17
                    elif(111<=font_number <=112 or 121<=font_number <=122   ):
                        y_offset+=26
                        x_offset+=20
                    elif(162<=font_number <=163 or  font_number ==165 or 184<=font_number <=198   ):
                        y_offset+=26
                        x_offset+=20
                    elif(  font_number ==164    ):
                        y_offset+=26
                        x_offset+=23
                    elif( font_number ==124 or 126<= font_number <=127 or font_number ==129 or font_number ==131   ):
                        y_offset+=26
                        x_offset+=20
                    elif( font_number ==140 or font_number ==142 or font_number ==149 or font_number ==145 or font_number ==152 or font_number ==167   ):
                        y_offset+=26
                        x_offset+=19
                    elif(108<=font_number <=109 ):
                        y_offset+=26
                        x_offset+=27
                    elif(font_number ==101 or font_number == 104 or font_number == 106 or font_number == 141 ):
                        y_offset+=26
                        x_offset+=27
                    elif( font_number ==148 or 150<= font_number <=151   ):
                        y_offset+=26
                        x_offset+=27
                    elif( font_number ==159 or font_number ==166 ):
                        y_offset+=26
                        x_offset+=25
                    elif( font_number ==153 or font_number ==156 or font_number ==158 ):
                        y_offset+=20
                        x_offset+=25
                    else:
                        y_offset+=26
                        x_offset+=23
                elif(201<=font_number<=300):
                    if(208<= font_number <=210 ):
                        y_offset+=22
                        x_offset+=0
                    elif(230<= font_number <=233  ):
                        y_offset+=28
                        x_offset+=23
                    elif( 255<= font_number <=258 ):
                        y_offset+=25
                        x_offset+=20
                    elif( 239<= font_number <=240 ):
                        y_offset+=25
                        x_offset+=20
                    elif( 267<= font_number <=268 or 275<= font_number <=277 ):
                        y_offset+=25
                        x_offset+=15
                    elif( font_number ==235 or font_number ==244 or font_number ==300 ):
                        y_offset+=30
                        x_offset+=20
                    elif( font_number ==270 or font_number ==272 ):
                        y_offset+=25
                        x_offset+=15
                    elif( 241<= font_number <=242 or 278<= font_number <=293 ):
                        y_offset+=25
                        x_offset+=20
                    elif( 218<= font_number <=220 or 278<= font_number <=293 ):
                        y_offset+=30
                        x_offset+=30
                    elif( font_number ==225  ):
                        y_offset+=30
                        x_offset+=30
                    elif(  font_number ==294 or font_number ==298 ):
                        y_offset+=30
                        x_offset+=28
                    elif( font_number ==259 or font_number ==295 or font_number ==297 or font_number ==299 ):
                        y_offset+=25
                        x_offset+=21
                    elif( font_number ==261 or 245<= font_number <=247 ):
                        y_offset+=28
                        x_offset+=25
                    elif( font_number ==260 or font_number ==262 or font_number ==264  ):
                        y_offset+=20
                        x_offset+=25
                    elif(  font_number ==263 or font_number ==265 or font_number ==266  ):
                        y_offset+=20
                        x_offset+=20
                    elif(  font_number ==243 ):
                        y_offset+=28
                        x_offset+=23
                    elif(  font_number ==254 ):
                        y_offset+=25
                        x_offset+=22
                    elif(211<= font_number <=216 ):
                        y_offset+=20
                        x_offset+=0
                    else:
                        y_offset+=28
                        x_offset+=25
                elif(301<=font_number<=333):
                    if(font_number == 316 ):
                        y_offset+=28
                        x_offset+=28
                    elif(font_number == 305 or font_number == 307  ):
                        y_offset+=28
                        x_offset+=21
                    elif( font_number == 309 or font_number == 319 or font_number == 321 ):
                        y_offset+=28
                        x_offset+=18
                    elif(font_number == 317   ):
                        y_offset+=28
                        x_offset+=21
                    elif( font_number == 322 or font_number == 325 ):
                        y_offset+=28
                        x_offset+=18
                    elif(  font_number == 327 or font_number == 329 ):
                        y_offset+=28
                        x_offset+=20
                    elif( 331<=font_number<=332 ):
                        y_offset+=28
                        x_offset+=18
                    elif(font_number==313 or font_number==315 ):
                        y_offset+=26
                        x_offset+=16
                    elif(font_number==312 ):
                        y_offset+=28
                        x_offset+=21
                    elif(font_number==303 or font_number==306):
                        y_offset+=28
                        x_offset+=18
                    elif( font_number==324 or font_number==326 ):
                        y_offset+=28
                        x_offset+=13
                    elif( font_number==328 or font_number==310  ):
                        y_offset+=28
                        x_offset+=15
                    elif(font_number==311 or font_number==301  ):
                        y_offset+=28
                        x_offset+=10
                    elif( font_number==302 or font_number==304  ):
                        y_offset+=28
                        x_offset+=14
                    elif(font_number==314 ):
                        y_offset+=26
                        x_offset+=12
                    elif(font_number==323 or font_number==333 ):
                        y_offset+=26
                        x_offset+=12
                    else:
                        y_offset+=28
                        x_offset+=25
                
            elif(char == "๊"): # ตรี
                if(1<= font_number<=100):
                    if( font_number == 17 or  font_number==23 or  font_number==28):
                        y_offset+=25
                        x_offset+=26
                    elif(font_number ==15 ):
                        y_offset+=25
                        x_offset+=30
                    elif(font_number ==16 or font_number==24 or font_number ==100 ):
                        y_offset+=25
                        x_offset+=27
                    elif(font_number ==27 or 39<= font_number<=40 or 42<= font_number<=43 ):
                        y_offset+=25
                        x_offset+=31
                    elif(font_number ==38 ):
                        y_offset+=25
                        x_offset+=33
                    elif( 47<= font_number<=48 ):
                        y_offset+=25
                        x_offset+=33
                    elif( 94<= font_number<=95 or  font_number==99):
                        y_offset+=25
                        x_offset+=30
                    elif(font_number ==9  or font_number ==22 ):
                        y_offset+=25
                        x_offset+=30
                    elif( font_number==14 or font_number ==20 ):
                        y_offset+=25
                        x_offset+=27
                    elif(font_number ==30  or font_number ==32 or font_number==34 or font_number ==35 ):
                        y_offset+=25
                        x_offset+=27
                    elif(font_number ==45  or font_number ==59 or font_number==61 or font_number ==65 ):
                        y_offset+=27
                        x_offset+=30
                    elif(font_number ==67  or font_number ==69 or font_number==72 or font_number ==81 ):
                        y_offset+=25
                        x_offset+=30
                    elif(font_number ==83 or font_number ==85 or font_number==87 or font_number ==90 ):
                        y_offset+=25
                        x_offset+=30
                    elif( font_number==92 or font_number ==97 ):
                        y_offset+=25
                        x_offset+=30
                    elif( font_number==8 ):
                        y_offset+=25
                        x_offset+=20
                    elif(font_number ==98 ):
                        y_offset+=25
                        x_offset+=18
                    elif(88<=font_number <=89 or 51<=font_number <=54  ):
                        y_offset+=25
                        x_offset+=21
                    elif(font_number ==18 or font_number ==21 or font_number ==29 or font_number ==31  ):
                        y_offset+=25
                        x_offset+=23
                    elif(font_number ==73 or font_number ==91   ):
                        y_offset+=25
                        x_offset+=23
                    elif(font_number ==56 ):
                        y_offset+=25
                        x_offset+=18
                    elif(font_number ==60 ):
                        y_offset+=25
                        x_offset+=34
                    elif(font_number ==62):
                        y_offset+=28
                        x_offset+=36
                    elif(font_number ==57 or font_number ==37 ):
                        y_offset+=25
                        x_offset+=38
                    elif(font_number ==64 ):
                        y_offset+=18
                        x_offset+=27
                    elif(font_number ==58 or font_number ==63  ):
                        y_offset+=30
                        x_offset+=26
                    elif(font_number ==44 ):
                        y_offset+=30
                        x_offset+=26
                    elif(font_number ==25 ):
                        y_offset+=25
                        x_offset+=29
                    elif(font_number ==46 or font_number ==49  ):
                        y_offset+=30
                        x_offset+=28
                    elif(font_number ==74 or font_number ==76 or font_number ==77 ):
                        y_offset+=25
                        x_offset+=30
                    else:
                        y_offset+=25
                        x_offset+=26
                elif(101<= font_number<=200):
                    if(108<= font_number <= 109 or 132<= font_number <= 135 ):
                        y_offset+=25
                        x_offset+=29
                    elif(150<= font_number <= 151 ):
                        y_offset+=28
                        x_offset+=28
                    elif(156<= font_number <= 161 or 168<= font_number <= 169 or 172<= font_number <= 174 ):
                        y_offset+=25
                        x_offset+=29
                    elif(font_number == 101 or font_number == 104 or font_number == 106 ):
                        y_offset+=25
                        x_offset+=29
                    elif(123<=font_number <=124  or font_number == 130 ):
                        y_offset+=25
                        x_offset+=29
                    elif(font_number ==125  or font_number == 128 ):
                        y_offset+=25
                        x_offset+=27
                    elif(font_number ==141  or font_number == 148 ):
                        y_offset+=30
                        x_offset+=29
                    elif( font_number == 153 or font_number == 164 or font_number == 166 ):
                        y_offset+=25
                        x_offset+=30
                    elif(113<=font_number <=114  or 116<=font_number <=117 ):
                        y_offset+=25
                        x_offset+=22
                    elif(120<=font_number <=121  or 184<=font_number <=189 ):
                        y_offset+=25
                        x_offset+=24
                    elif( font_number == 145 or font_number == 147 ):
                        y_offset+=28
                        x_offset+=21
                    elif( font_number == 140 ):
                        y_offset+=27
                        x_offset+=27
                    elif( font_number == 149 or font_number == 152 or font_number == 162 or font_number == 196 ):
                        y_offset+=28
                        x_offset+=19
                    elif(  font_number == 198 ):
                        y_offset+=28
                        x_offset+=23
                    elif( font_number == 144 ):
                        y_offset+=28
                        x_offset+=18
                    elif( font_number == 193 or font_number == 194 ):
                        y_offset+=28
                        x_offset+=23
                    elif( font_number == 142 ):
                        y_offset+=28
                        x_offset+=25
                    else:
                        y_offset+=25
                        x_offset+=25
                elif(201<= font_number<=300):
                    if(208<= font_number <= 216 ):
                        y_offset+=20
                        x_offset+=0
                    elif(218<= font_number <= 220 ):
                        y_offset+=28
                        x_offset+=33
                    elif( 223<= font_number <= 225 or font_number == 219 ):
                        y_offset+=28
                        x_offset+=30
                    elif( font_number == 227 or  font_number == 217 ):
                        y_offset+=28
                        x_offset+=30
                    elif( font_number == 264 or font_number == 271 ):
                        y_offset+=28
                        x_offset+=32
                    elif( font_number == 294 or font_number == 296 or font_number == 298  ):
                        y_offset+=28
                        x_offset+=32
                    elif( font_number == 231 or font_number == 242 or font_number == 253 or font_number == 256  ):
                        y_offset+=28
                        x_offset+=23
                    elif( font_number == 284 or font_number == 286 or font_number == 288 ):
                        y_offset+=28
                        x_offset+=23
                    elif(  font_number == 290  ):
                        y_offset+=28
                        x_offset+=28
                    elif( 239<= font_number <= 240 or font_number == 230 or font_number == 235 ):
                        y_offset+=28
                        x_offset+=22
                    elif( font_number == 267 or font_number == 270 ):
                        y_offset+=28
                        x_offset+=22
                    elif(font_number == 244 ):
                        y_offset+=28
                        x_offset+=20
                    elif( font_number == 255 ):
                        y_offset+=25
                        x_offset+=20
                    elif( font_number == 277 or font_number == 283 or  font_number == 293 ):
                        y_offset+=25
                        x_offset+=22
                    elif(221<= font_number <= 222 or 228<= font_number <= 229 ):
                        y_offset+=30
                        x_offset+=27
                    elif(261<= font_number <= 262 or 273<= font_number <= 274 ):
                        y_offset+=25
                        x_offset+=30
                    elif(font_number == 260  ):
                        y_offset+=25
                        x_offset+=33
                    elif(font_number == 234 or font_number == 236 or font_number == 257  ):
                        y_offset+=28
                        x_offset+=27
                    elif( font_number == 252 or font_number == 254  or font_number == 259 ):
                        y_offset+=25
                        x_offset+=30
                    elif( font_number == 278 or font_number == 280   ):
                        y_offset+=25
                        x_offset+=30
                    elif(  font_number == 282 or font_number == 285 ):
                        y_offset+=25
                        x_offset+=27
                    elif(  font_number == 287 or font_number == 289 or font_number == 292 ):
                        y_offset+=25
                        x_offset+=27
                    else:
                        y_offset+=25
                        x_offset+=25
                elif(301<= font_number<=333):
                    if( font_number == 315 ):
                        y_offset+=25
                        x_offset+=20
                    elif(font_number == 314 ):
                        y_offset+=25
                        x_offset+=16
                    elif(font_number == 301 or font_number == 304 or font_number == 311  ):
                        y_offset+=30
                        x_offset+=18
                    elif(font_number == 323 or font_number == 324 or font_number == 326 or font_number == 333  ):
                        y_offset+=30
                        x_offset+=18
                    elif(font_number == 303  or font_number == 310 or font_number == 312):
                        y_offset+=25
                        x_offset+=25
                    elif(font_number == 305 or font_number == 327 ):
                        y_offset+=25
                        x_offset+=27
                    elif(font_number == 322   or font_number == 332):
                        y_offset+=25
                        x_offset+=25
                    elif(font_number == 329 or font_number == 307 or font_number == 317):
                        y_offset+=25
                        x_offset+=27
                    elif(font_number == 308 or font_number == 318 or font_number == 330):
                        y_offset+=25
                        x_offset+=29
                    elif(font_number == 316):
                        y_offset+=28
                        x_offset+=32
                    elif(font_number == 321 or font_number == 325):
                        y_offset+=25
                        x_offset+=24
                    elif(font_number == 320):
                        y_offset+=25
                        x_offset+=32
                    elif(font_number == 313):
                        y_offset+=23
                        x_offset+=20
                    else:
                        y_offset+=25
                        x_offset+=22                   
            elif(char == "๋"): # จัตวา 
                if(1<= font_number<=100):
                    if(9<= font_number <= 14   ):
                        y_offset+=33
                        x_offset+=33
                    elif(font_number == 37 ):
                        y_offset+=38
                        x_offset+=32
                    elif(font_number == 38 ):
                        y_offset+=40
                        x_offset+=25
                    elif( font_number == 65  ):
                        y_offset+=38
                        x_offset+=27
                    elif(font_number == 50 ):
                        y_offset+=45
                        x_offset+=22
                    elif(font_number == 57 ):
                        y_offset+=45
                        x_offset+=30
                    elif(font_number == 2 ):
                        y_offset+=38
                        x_offset+=25
                    elif(font_number == 53 or font_number == 54 ):
                        y_offset+=45
                        x_offset+=15
                    elif(font_number == 51 or font_number == 52 or font_number == 56   ):
                        y_offset+=45
                        x_offset+=10
                    elif( font_number == 67):
                        y_offset+=35
                        x_offset+=28
                    elif( font_number == 88 ):
                        y_offset+=35
                        x_offset+=10
                    elif( font_number == 64 ):
                        y_offset+=28
                        x_offset+=28
                    elif( font_number == 72 or font_number == 74):
                        y_offset+=35
                        x_offset+=25
                    elif( font_number == 76 or font_number == 77):
                        y_offset+=35
                        x_offset+=25
                    elif( font_number == 94 or font_number == 95):
                        y_offset+=35
                        x_offset+=30
                    elif( font_number == 92 or font_number == 90 or font_number == 87):
                        y_offset+=35
                        x_offset+=30
                    elif( font_number == 81 or font_number == 83 ):
                        y_offset+=32
                        x_offset+=32
                    elif(font_number == 85):
                        y_offset+=32
                        x_offset+=28
                    elif(78<=font_number <= 79):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number == 80):
                        y_offset+=35
                        x_offset+=15
                    elif(font_number == 1 or font_number == 3 or font_number == 4 ):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number == 82 or font_number == 84 or font_number == 86 ):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number == 91 or font_number == 93 or font_number == 96 or font_number == 98 ):
                        y_offset+=35
                        x_offset+=15
                    elif(18<=font_number <= 19 or 41<=font_number <= 42 or 70<=font_number <= 71):
                        y_offset+=37
                        x_offset+=15
                    elif(font_number == 29 or font_number == 31 or font_number == 44 ):
                        y_offset+=37
                        x_offset+=15
                    elif(font_number == 46 or  font_number == 73 ):
                        y_offset+=37
                        x_offset+=17
                    elif( font_number == 55 ):
                        y_offset+=45
                        x_offset+=17
                    elif(font_number == 69 ):
                        y_offset+=35
                        x_offset+=23
                    elif(font_number == 68 ):
                        y_offset+=35
                        x_offset+=21
                    elif(font_number == 75 or font_number == 89 or font_number == 100 ):
                        y_offset+=38
                        x_offset+=18
                    elif( font_number == 8 or font_number == 16 or font_number == 17 ):
                        y_offset+=35
                        x_offset+=18
                    elif( font_number == 6 or font_number == 34 ):
                        y_offset+=35
                        x_offset+=22
                    elif( font_number == 23 or font_number == 26 ):
                        y_offset+=35
                        x_offset+=18
                    elif( font_number == 20 ):
                        y_offset+=40
                        x_offset+=23
                    elif( font_number == 21):
                        y_offset+=35
                        x_offset+=15
                    elif( font_number == 28 or font_number == 36 or font_number == 33  ):
                        y_offset+=35
                        x_offset+=18
                    elif( font_number == 39 or font_number == 49 or font_number == 66  ):
                        y_offset+=37
                        x_offset+=20
                    elif( font_number == 97):
                        y_offset+=35
                        x_offset+=25
                    else:
                        y_offset+=38
                        x_offset+=25
                elif(101<= font_number<=200):
                    if(123<= font_number <= 124   ):
                        y_offset+=40
                        x_offset+=23
                    elif(font_number == 142 or font_number == 149 or font_number == 152):
                        y_offset+=43
                        x_offset+=20
                    elif(font_number == 136):
                        y_offset+=38
                        x_offset+=19
                    elif(font_number == 109):
                        y_offset+=38
                        x_offset+=25
                    elif(139<=font_number <= 141):
                        y_offset+=40
                        x_offset+=28
                    elif(181<=font_number <= 183 or 199<=font_number <= 200):
                        y_offset+=38
                        x_offset+=28
                    elif(111<=font_number <= 112 or 121<=font_number <= 122):
                        y_offset+=35
                        x_offset+=23
                    elif(font_number == 155 or font_number == 166 or 168<= font_number <= 169):
                        y_offset+=32
                        x_offset+=23
                    elif(114<=font_number <= 115 or font_number == 117):
                        y_offset+=32
                        x_offset+=15
                    elif(font_number == 113 or font_number == 116  ):
                        y_offset+=32
                        x_offset+=20
                    elif(162<=font_number <= 163 or font_number == 165 or font_number == 160 ):
                        y_offset+=32
                        x_offset+=15
                    elif(font_number == 161 or  font_number == 164):
                        y_offset+=30
                        x_offset+=21
                    elif(font_number == 167 or  font_number == 170):
                        y_offset+=30
                        x_offset+=19
                    elif(  font_number == 138 or font_number == 148 ):
                        y_offset+=43
                        x_offset+=26
                    elif(font_number == 135):
                        y_offset+=43
                        x_offset+=33
                    elif(font_number == 151):
                        y_offset+=43
                        x_offset+=28
                    elif(171<=font_number <= 179 ):
                        y_offset+=40
                        x_offset+=33
                    elif(153<=font_number <= 154 or  157<=font_number <= 158 ):
                        y_offset+=33
                        x_offset+=28
                    elif(font_number == 159):
                        y_offset+=33
                        x_offset+=26
                    elif(font_number == 156):
                        y_offset+=33
                        x_offset+=26
                    elif(119<=font_number <= 120 ):
                        y_offset+=32
                        x_offset+=20
                    elif(  126<=font_number <= 127 ):
                        y_offset+=38
                        x_offset+=16
                    elif(font_number == 125 ):
                        y_offset+=38
                        x_offset+=20
                    elif(  144<=font_number <= 145  ):
                        y_offset+=40
                        x_offset+=15
                    elif(102<=font_number <= 103 or font_number == 105 or font_number == 107  ):
                        y_offset+=38
                        x_offset+=16
                    elif(font_number == 110 or font_number == 126 or font_number == 129 or font_number == 147  ):
                        y_offset+=38
                        x_offset+=16
                    elif(font_number == 180 or 184<= font_number <= 188  ):
                        y_offset+=38
                        x_offset+=28
                    else:
                        y_offset+=38
                        x_offset+=23
                elif(201<= font_number<=300):
                    if(201<= font_number <= 207):
                        y_offset+=40
                        x_offset+=30
                    elif(254<= font_number <= 260):
                        y_offset+=35
                        x_offset+=30
                    elif( font_number== 295 or font_number== 297 or font_number== 299):
                        y_offset+=39
                        x_offset+=22
                    elif( font_number== 294 or font_number== 296 or font_number== 298):
                        y_offset+=40
                        x_offset+=33
                    elif( font_number== 300 ):
                        y_offset+=40
                        x_offset+=25
                    elif( font_number== 262 ):
                        y_offset+=35
                        x_offset+=25
                    elif(font_number == 263 or font_number == 261):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number == 264 or font_number == 271):
                        y_offset+=35
                        x_offset+=29
                    elif(font_number == 265 or font_number == 272 or font_number == 279):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number == 266 or font_number == 273 ):
                        y_offset+=35
                        x_offset+=25
                    elif(font_number == 267 or font_number == 283 or font_number == 286 or font_number == 293 ):
                        y_offset+=35
                        x_offset+=13
                    elif(font_number == 269 or font_number == 276 or  font_number == 280 ):
                        y_offset+=35
                        x_offset+=25
                    elif(font_number == 268 or font_number == 275 ):
                        y_offset+=35
                        x_offset+=18
                    elif(font_number == 282 or  font_number == 285 ):
                        y_offset+=35
                        x_offset+=20
                    elif( font_number == 292 ):
                        y_offset+=35
                        x_offset+=20
                    elif(289<= font_number <= 290 ):
                        y_offset+=35
                        x_offset+=23
                    elif( font_number == 288 or font_number == 291 ):
                        y_offset+=35
                        x_offset+=15
                    elif( font_number == 281 ):
                        y_offset+=35
                        x_offset+=18
                    elif( font_number == 274 or font_number == 287 ):
                        y_offset+=35
                        x_offset+=22
                    elif( font_number == 270 or font_number == 284 ):
                        y_offset+=35
                        x_offset+=15
                    elif( font_number == 277 ):
                        y_offset+=35
                        x_offset+=14
                    elif( 208<= font_number <= 210 or 213<= font_number <= 215  ):
                        y_offset+=30
                        x_offset+=0
                    elif(211<= font_number <= 212 or font_number == 216  ):
                        y_offset+=28
                        x_offset+=0
                    else:
                        y_offset+=45
                        x_offset+=30
                elif(301<= font_number<=333):
                    if( font_number == 301 or font_number == 311   ):
                        y_offset+=40
                        x_offset+=13
                    elif( font_number == 315):
                        y_offset+=35
                        x_offset+=18
                    elif(font_number == 324 or font_number == 326 or font_number == 333 ):
                        y_offset+=40
                        x_offset+=15
                    elif(font_number == 302 or font_number == 304 or font_number == 306 ):
                        y_offset+=40
                        x_offset+=18
                    elif(font_number == 309  or font_number == 331 ):
                        y_offset+=40
                        x_offset+=18
                    elif( font_number == 328  ):
                        y_offset+=40
                        x_offset+=15
                    elif( font_number == 303 or font_number == 317 or font_number == 325 ):
                        y_offset+=40
                        x_offset+=25
                    elif(font_number == 319 or font_number == 321  ):
                        y_offset+=40
                        x_offset+=20
                    elif(font_number == 305 or font_number == 316  ):
                        y_offset+=40
                        x_offset+=35
                    elif(font_number == 313 or font_number == 323  ):
                        y_offset+=37
                        x_offset+=15
                    elif( font_number == 314  ):
                        y_offset+=35
                        x_offset+=12
                    elif( font_number == 310 or font_number == 332  ):
                        y_offset+=40
                        x_offset+=25
                    elif( font_number == 312  ):
                        y_offset+=35
                        x_offset+=20
                    else:
                        y_offset+=45
                        x_offset+=30
            elif(char == "์"): # การัน
                if(1<= font_number<=100):
                    if(10<= font_number <= 14   ):
                        y_offset+=33
                        x_offset+=25
                    elif(font_number == 37 ):
                        y_offset+=38
                        x_offset+=30
                    elif(font_number == 31 ):
                        y_offset+=40
                        x_offset+=20
                    elif(51<= font_number <= 52  ):
                        y_offset+=40
                        x_offset+=8
                    elif(53<= font_number <= 55  ):
                        y_offset+=40
                        x_offset+=20
                    elif(70<= font_number <= 71  ):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number == 73 or font_number == 75 or font_number == 78  ):
                        y_offset+=40
                        x_offset+=20
                    elif(font_number == 80 or font_number == 88 or font_number == 91  ):
                        y_offset+=38
                        x_offset+=20
                    elif(font_number == 93 or font_number == 98 or font_number == 96  ):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number == 56):
                        y_offset+=43
                        x_offset+=5
                    elif(font_number == 57  ):
                        y_offset+=45
                        x_offset+=45
                    elif(font_number == 50 ):
                        y_offset+=35
                        x_offset+=27
                    elif(font_number == 15 or font_number == 17 or font_number == 20 ):
                        y_offset+=35
                        x_offset+=35
                    elif(font_number == 18 or font_number == 19 ):
                        y_offset+=35
                        x_offset+=27
                    elif(font_number == 16 ):
                        y_offset+=35
                        x_offset+=30
                    elif(font_number == 22):
                        y_offset+=35
                        x_offset+=35
                    elif(24<= font_number <= 25 or font_number == 27  ):
                        y_offset+=35
                        x_offset+=35
                    elif(font_number == 26 ):
                        y_offset+=35
                        x_offset+=30
                    elif(font_number == 23 ):
                        y_offset+=35
                        x_offset+=30
                    elif(font_number == 30 or font_number == 32  ):
                        y_offset+=40
                        x_offset+=30
                    elif(font_number == 40 or font_number == 43 or font_number == 45   ):
                        y_offset+=40
                        x_offset+=30
                    elif(font_number == 47 or font_number == 48  ):
                        y_offset+=40
                        x_offset+=30
                    elif(font_number == 58 or font_number == 63 ):
                        y_offset+=40
                        x_offset+=32
                    elif(font_number == 59 or font_number == 61 ):
                        y_offset+=40
                        x_offset+=35
                    elif(font_number == 60 or font_number == 62 ):
                        y_offset+=43
                        x_offset+=40
                    elif(font_number == 65 or font_number == 67 ):
                        y_offset+=36
                        x_offset+=30
                    elif(font_number == 74 or font_number == 77 ):
                        y_offset+=38
                        x_offset+=30
                    elif(font_number == 92 or font_number == 94 or font_number == 95  ):
                        y_offset+=34
                        x_offset+=30
                    elif(font_number == 33 or font_number == 36 or font_number == 39  ):
                        y_offset+=40
                        x_offset+=25
                    elif(font_number == 41 or font_number == 42 ):
                        y_offset+=40
                        x_offset+=20
                    elif(font_number == 44 or font_number == 46 or font_number == 49  ):
                        y_offset+=40
                        x_offset+=25
                    elif(font_number == 82 or font_number == 84 or font_number == 86  ):
                        y_offset+=30
                        x_offset+=25
                    elif(font_number == 34 or font_number == 35 ):
                        y_offset+=40
                        x_offset+=30
                    elif(font_number == 64 ):
                        y_offset+=28
                        x_offset+=32
                    elif(font_number == 81 or font_number == 83 or font_number == 85 ):
                        y_offset+=30
                        x_offset+=32
                    elif(font_number ==99 ):
                        y_offset+=35
                        x_offset+=35
                    elif(font_number ==100 ):
                        y_offset+=35
                        x_offset+=30
                    else:
                        y_offset+=35
                        x_offset+=25
                elif(101<= font_number<=200):
                    if(108<= font_number <= 109 or  font_number ==104 or font_number == 106   ):
                        y_offset+=35
                        x_offset+=35
                    elif(font_number == 101 ):
                        y_offset+=35
                        x_offset+=32
                    elif(font_number == 103 or font_number == 105 or font_number == 107 or font_number == 110  ):
                        y_offset+=35
                        x_offset+=30
                    elif(113<=font_number <= 122):
                        y_offset+=35
                        x_offset+=22
                    elif(font_number == 123 ):
                        y_offset+=40
                        x_offset+=29
                    elif(font_number == 124 ):
                        y_offset+=40
                        x_offset+=25
                    elif(font_number == 127 or font_number == 129 ):
                        y_offset+=38
                        x_offset+=20
                    elif(font_number == 130 ):
                        y_offset+=40
                        x_offset+=25
                    elif(font_number == 131 ):
                        y_offset+=40
                        x_offset+=21
                    elif(132<=font_number <= 134):
                        y_offset+=40
                        x_offset+=25
                    elif(font_number == 135 ):
                        y_offset+=40
                        x_offset+=33
                    elif(136<=font_number <= 137):
                        y_offset+=35
                        x_offset+=23
                    elif(font_number == 138 or font_number == 140  ):
                        y_offset+=36
                        x_offset+=28
                    elif(font_number == 141 ):
                        y_offset+=40
                        x_offset+=32
                    elif(font_number == 142):
                        y_offset+=40
                        x_offset+=24
                    elif(font_number == 143 or font_number == 148 ):
                        y_offset+=40
                        x_offset+=28
                    elif(font_number == 146):
                        y_offset+=40
                        x_offset+=28
                    elif(font_number == 144 or font_number == 145 or font_number == 147):
                        y_offset+=40
                        x_offset+=19
                    elif(font_number == 149 or font_number == 152 ):
                        y_offset+=40
                        x_offset+=22
                    elif(font_number == 151 or font_number == 150):
                        y_offset+=40
                        x_offset+=28
                    elif(font_number == 153 or font_number == 158):
                        y_offset+=32
                        x_offset+=32
                    elif(154<=font_number <= 157):
                        y_offset+=32
                        x_offset+=30
                    elif(font_number == 159):
                        y_offset+=32
                        x_offset+=35
                    elif(160<=font_number <= 161):
                        y_offset+=32
                        x_offset+=28
                    elif(162<=font_number <= 163):
                        y_offset+=32
                        x_offset+=22
                    elif(font_number == 164):
                        y_offset+=32
                        x_offset+=30
                    elif(font_number == 165 or font_number == 167 ):
                        y_offset+=30
                        x_offset+=25
                    elif(font_number == 166 or 168<= font_number <= 169 ):
                        y_offset+=30
                        x_offset+=31
                    elif(font_number == 170 ):
                        y_offset+=30
                        x_offset+=25
                    elif(184<= font_number <= 200 ):
                        y_offset+=35
                        x_offset+=22
                    else:
                        y_offset+=35
                        x_offset+=25
                elif(201<= font_number<=300):
                    if(font_number ==279 or font_number == 281   ):
                        y_offset+=40
                        x_offset+=22
                    elif(font_number == 270 or font_number == 272 or font_number == 277 ):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number == 283 or font_number == 284 ):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number == 286 or font_number == 288 ):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number == 291 or font_number == 293 ):
                        y_offset+=35
                        x_offset+=20
                    elif(font_number == 271 or font_number == 273 or font_number == 274 ):
                        y_offset+=35
                        x_offset+=30
                    elif(254 <= font_number <= 260):
                        y_offset+=35
                        x_offset+=30
                    elif(font_number == 262 or font_number == 264  ):
                        y_offset+=35
                        x_offset+=30
                    elif(font_number == 282 or font_number == 285 or font_number == 287  ):
                        y_offset+=35
                        x_offset+=28
                    elif(font_number == 289 or font_number == 290 or  font_number == 292 ):
                        y_offset+=35
                        x_offset+=28
                    elif(235<= font_number <= 244):
                        y_offset+=45
                        x_offset+=23
                    elif(font_number == 295 or font_number == 297 or font_number == 299 ):
                        y_offset+=45
                        x_offset+=25
                    elif( font_number == 300 ):
                        y_offset+=45
                        x_offset+=20
                    elif(217<= font_number <= 227):
                        y_offset+=45
                        x_offset+=30
                    elif(228<= font_number <= 234):
                        y_offset+=45
                        x_offset+=25
                    elif(245<= font_number <= 253):
                        y_offset+=45
                        x_offset+=28
                    elif(font_number == 278 or font_number == 280):
                        y_offset+=40
                        x_offset+=30
                    elif(font_number == 294 or font_number == 296 or font_number == 298):
                        y_offset+=45
                        x_offset+=35
                    elif(208<= font_number <= 216):
                        y_offset+=33
                        x_offset+=0
                    else:
                        y_offset+=35
                        x_offset+=25
                elif(301<= font_number<=333):
                    if(font_number ==301 or  font_number == 304 ):
                        y_offset+=40
                        x_offset+=10
                    elif(font_number == 302) :
                        y_offset+=40
                        x_offset+=12
                    elif(font_number == 303) :
                        y_offset+=40
                        x_offset+=22
                    elif(font_number == 305 or font_number ==  325 ) :
                        y_offset+=45
                        x_offset+=25
                    elif(font_number == 307) :
                        y_offset+=45
                        x_offset+=23
                    elif(font_number == 306) :
                        y_offset+=40
                        x_offset+=15
                    elif(font_number == 308) :
                        y_offset+=45
                        x_offset+=30
                    elif(font_number == 309) :
                        y_offset+=40
                        x_offset+=20
                    elif(font_number == 310) :
                        y_offset+=40
                        x_offset+=18
                    elif(font_number == 311) :
                        y_offset+=42
                        x_offset+=10
                    elif(313<=font_number <= 314) :
                        y_offset+=35
                        x_offset+=19
                    elif(font_number == 316) :
                        y_offset+=45
                        x_offset+=35
                    elif(font_number == 317) :
                        y_offset+=45
                        x_offset+=25
                    elif(font_number == 318 or font_number == 320 ) :
                        y_offset+=42
                        x_offset+=32
                    elif(font_number == 319 or font_number == 321 ) :
                        y_offset+=40
                        x_offset+=23
                    elif(font_number == 322) :
                        y_offset+=40
                        x_offset+=20
                    elif(font_number == 323) :
                        y_offset+=40
                        x_offset+=10
                    elif(font_number == 324) :
                        y_offset+=40
                        x_offset+=15
                    elif(font_number == 326) :
                        y_offset+=40
                        x_offset+=12
                    elif(font_number == 327) :
                        y_offset+=40
                        x_offset+=28
                    elif(font_number == 328) :
                        y_offset+=40
                        x_offset+=15
                    elif(font_number == 329 ):
                        y_offset+=43
                        x_offset+=25
                    elif(font_number == 330 ):
                        y_offset+=40
                        x_offset+=30
                    elif(font_number == 331 or font_number == 332 ):
                        y_offset+=40
                        x_offset+=20
                    elif(font_number == 333 ):
                        y_offset+=40
                        x_offset+=8
                    else:
                        y_offset+=35
                        x_offset+=25
                      
            

            

            draw.text((x_offset, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            output_path = char_folder / f"{char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")
# Out:
# Saved: ..\data\raw_images\thai_tones\่\่_1.png
# Saved: ..\data\raw_images\thai_tones\้\้_1.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_1.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_1.png
# Saved: ..\data\raw_images\thai_tones\์\์_1.png
# Saved: ..\data\raw_images\thai_tones\่\่_2.png
# Saved: ..\data\raw_images\thai_tones\้\้_2.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_2.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_2.png
# Saved: ..\data\raw_images\thai_tones\์\์_2.png
# Saved: ..\data\raw_images\thai_tones\่\่_3.png
# Saved: ..\data\raw_images\thai_tones\้\้_3.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_3.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_3.png
# Saved: ..\data\raw_images\thai_tones\์\์_3.png
# Saved: ..\data\raw_images\thai_tones\่\่_4.png
# Saved: ..\data\raw_images\thai_tones\้\้_4.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_4.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_4.png
# Saved: ..\data\raw_images\thai_tones\์\์_4.png
# Saved: ..\data\raw_images\thai_tones\่\่_5.png
# Saved: ..\data\raw_images\thai_tones\้\้_5.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_5.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_5.png
# Saved: ..\data\raw_images\thai_tones\์\์_5.png
# Saved: ..\data\raw_images\thai_tones\่\่_6.png
# Saved: ..\data\raw_images\thai_tones\้\้_6.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_6.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_6.png
# Saved: ..\data\raw_images\thai_tones\์\์_6.png
# Saved: ..\data\raw_images\thai_tones\่\่_7.png
# Saved: ..\data\raw_images\thai_tones\้\้_7.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_7.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_7.png
# Saved: ..\data\raw_images\thai_tones\์\์_7.png
# Saved: ..\data\raw_images\thai_tones\่\่_8.png
# Saved: ..\data\raw_images\thai_tones\้\้_8.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_8.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_8.png
# Saved: ..\data\raw_images\thai_tones\์\์_8.png
# Saved: ..\data\raw_images\thai_tones\่\่_9.png
# Saved: ..\data\raw_images\thai_tones\้\้_9.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_9.png
# Saved: ..\data\raw_images\thai_tones\๋\๋
png
# Saved: ..\data\raw_images\thai_tones\๊\๊_172.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_172.png
# Saved: ..\data\raw_images\thai_tones\์\์_172.png
# Saved: ..\data\raw_images\thai_tones\่\่_173.png
# Saved: ..\data\raw_images\thai_tones\้\้_173.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_173.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_173.png
# Saved: ..\data\raw_images\thai_tones\์\์_173.png
# Saved: ..\data\raw_images\thai_tones\่\่_174.png
# Saved: ..\data\raw_images\thai_tones\้\้_174.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_174.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_174.png
# Saved: ..\data\raw_images\thai_tones\์\์_174.png
# Saved: ..\data\raw_images\thai_tones\่\่_175.png
# Saved: ..\data\raw_images\thai_tones\้\้_175.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_175.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_175.png
# Saved: ..\data\raw_images\thai_tones\์\์_175.png
# Saved: ..\data\raw_images\thai_tones\่\่_176.png
# Saved: ..\data\raw_images\thai_tones\้\้_176.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_176.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_176.png
# Saved: ..\data\raw_images\thai_tones\์\์_176.png
# Saved: ..\data\raw_images\thai_tones\่\่_177.png
# Saved: ..\data\raw_images\thai_tones\้\้_177.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_177.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_177.png
# Saved: ..\data\raw_images\thai_tones\์\์_177.png
# Saved: ..\data\raw_images\thai_tones\่\่_178.png
# Saved: ..\data\raw_images\thai_tones\้\้_178.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_178.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_178.png
# Saved: ..\data\raw_images\thai_tones\์\์_178.png
# Saved: ..\data\raw_images\thai_tones\่\่_179.png
# Saved: ..\data\raw_images\thai_tones\้\้_179.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_179.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_179.png
# Saved: ..\data\raw_images\thai_tones\์\์_179.png
# Saved: ..\data\raw_images\thai_tones\่\่_180.png
# Saved: ..\data\raw_images\thai_tones\้\้_180.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_180.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_180.png
# Saved: ..\data\raw_images\thai_tones\์\์_180.png
# Saved: ..\data\raw_images\thai_tones\่\่_181.png
# Saved: ..\data\raw_images\thai_tones\้\้_181.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_181.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_181.png
# Saved: ..\data\raw_images\thai_tones\์\์_181.png
# Saved: ..\data\raw_images\thai_tones\่\่_182.png
# Saved: ..\data\raw_images\thai_tones\้\้_182.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_182.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_182.png
# Saved: ..\data\raw_images\thai_tones\์\์_182.png
# Saved: ..\data\raw_images\thai_tones\่\่_183.png
# Saved: ..\data\raw_images\thai_tones\้\้_183.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_183.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_183.png
# Saved: ..\data\raw_images\thai_tones\์\์_183.png
# Saved: ..\data\raw_images\thai_tones\่\่_184.png
# Saved: ..\data\raw_images\thai_tones\้\้_184.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_184.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_184.png
# Saved: ..\data\raw_images\thai_tones\์\์_184.png
# Saved: ..\data\raw_images\thai_tones\่\่_185.png
# Saved: ..\data\raw_images\thai_tones\้\้_185.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_185.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_185.png
# Saved: ..\data\raw_images\thai_tones\์\์_185.png
# Saved: ..\data\raw_images\thai_tones\่\่_186.png
# Saved: ..\data\raw_images\thai_tones\้\้_186.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_186.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_186.png
# Saved: ..\data\raw_images\thai_tones\์\์_186.png
# Saved: ..\data\raw_images\thai_tones\่\่_187.png
# Saved: ..\data\raw_images\thai_tones\้\้_187.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_187.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_187.png
# Saved: ..\data\raw_images\thai_tones\์\์_187.png
# Saved: ..\data\raw_images\thai_tones\่\่_188.png
# Saved: ..\data\raw_images\thai_tones\้\้_188.png
# Saved: ..\data\raw_images\thai_tones\๊\๊
png
# Saved: ..\data\raw_images\thai_tones\๊\๊_274.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_274.png
# Saved: ..\data\raw_images\thai_tones\์\์_274.png
# Saved: ..\data\raw_images\thai_tones\่\่_275.png
# Saved: ..\data\raw_images\thai_tones\้\้_275.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_275.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_275.png
# Saved: ..\data\raw_images\thai_tones\์\์_275.png
# Saved: ..\data\raw_images\thai_tones\่\่_276.png
# Saved: ..\data\raw_images\thai_tones\้\้_276.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_276.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_276.png
# Saved: ..\data\raw_images\thai_tones\์\์_276.png
# Saved: ..\data\raw_images\thai_tones\่\่_277.png
# Saved: ..\data\raw_images\thai_tones\้\้_277.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_277.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_277.png
# Saved: ..\data\raw_images\thai_tones\์\์_277.png
# Saved: ..\data\raw_images\thai_tones\่\่_278.png
# Saved: ..\data\raw_images\thai_tones\้\้_278.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_278.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_278.png
# Saved: ..\data\raw_images\thai_tones\์\์_278.png
# Saved: ..\data\raw_images\thai_tones\่\่_279.png
# Saved: ..\data\raw_images\thai_tones\้\้_279.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_279.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_279.png
# Saved: ..\data\raw_images\thai_tones\์\์_279.png
# Saved: ..\data\raw_images\thai_tones\่\่_280.png
# Saved: ..\data\raw_images\thai_tones\้\้_280.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_280.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_280.png
# Saved: ..\data\raw_images\thai_tones\์\์_280.png
# Saved: ..\data\raw_images\thai_tones\่\่_281.png
# Saved: ..\data\raw_images\thai_tones\้\้_281.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_281.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_281.png
# Saved: ..\data\raw_images\thai_tones\์\์_281.png
# Saved: ..\data\raw_images\thai_tones\่\่_282.png
# Saved: ..\data\raw_images\thai_tones\้\้_282.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_282.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_282.png
# Saved: ..\data\raw_images\thai_tones\์\์_282.png
# Saved: ..\data\raw_images\thai_tones\่\่_283.png
# Saved: ..\data\raw_images\thai_tones\้\้_283.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_283.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_283.png
# Saved: ..\data\raw_images\thai_tones\์\์_283.png
# Saved: ..\data\raw_images\thai_tones\่\่_284.png
# Saved: ..\data\raw_images\thai_tones\้\้_284.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_284.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_284.png
# Saved: ..\data\raw_images\thai_tones\์\์_284.png
# Saved: ..\data\raw_images\thai_tones\่\่_285.png
# Saved: ..\data\raw_images\thai_tones\้\้_285.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_285.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_285.png
# Saved: ..\data\raw_images\thai_tones\์\์_285.png
# Saved: ..\data\raw_images\thai_tones\่\่_286.png
# Saved: ..\data\raw_images\thai_tones\้\้_286.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_286.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_286.png
# Saved: ..\data\raw_images\thai_tones\์\์_286.png
# Saved: ..\data\raw_images\thai_tones\่\่_287.png
# Saved: ..\data\raw_images\thai_tones\้\้_287.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_287.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_287.png
# Saved: ..\data\raw_images\thai_tones\์\์_287.png
# Saved: ..\data\raw_images\thai_tones\่\่_288.png
# Saved: ..\data\raw_images\thai_tones\้\้_288.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_288.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_288.png
# Saved: ..\data\raw_images\thai_tones\์\์_288.png
# Saved: ..\data\raw_images\thai_tones\่\่_289.png
# Saved: ..\data\raw_images\thai_tones\้\้_289.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_289.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_289.png
# Saved: ..\data\raw_images\thai_tones\์\์_289.png
# Saved: ..\data\raw_images\thai_tones\่\่_290.png
# Saved: ..\data\raw_images\thai_tones\้\้_290.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_290.png
# Saved: ..\data\raw_images\thai_tones\๋\๋
png
# Saved: ..\data\raw_images\thai_tones\๊\๊_323.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_323.png
# Saved: ..\data\raw_images\thai_tones\์\์_323.png
# Saved: ..\data\raw_images\thai_tones\่\่_324.png
# Saved: ..\data\raw_images\thai_tones\้\้_324.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_324.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_324.png
# Saved: ..\data\raw_images\thai_tones\์\์_324.png
# Saved: ..\data\raw_images\thai_tones\่\่_325.png
# Saved: ..\data\raw_images\thai_tones\้\้_325.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_325.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_325.png
# Saved: ..\data\raw_images\thai_tones\์\์_325.png
# Saved: ..\data\raw_images\thai_tones\่\่_326.png
# Saved: ..\data\raw_images\thai_tones\้\้_326.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_326.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_326.png
# Saved: ..\data\raw_images\thai_tones\์\์_326.png
# Saved: ..\data\raw_images\thai_tones\่\่_327.png
# Saved: ..\data\raw_images\thai_tones\้\้_327.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_327.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_327.png
# Saved: ..\data\raw_images\thai_tones\์\์_327.png
# Saved: ..\data\raw_images\thai_tones\่\่_328.png
# Saved: ..\data\raw_images\thai_tones\้\้_328.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_328.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_328.png
# Saved: ..\data\raw_images\thai_tones\์\์_328.png
# Saved: ..\data\raw_images\thai_tones\่\่_329.png
# Saved: ..\data\raw_images\thai_tones\้\้_329.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_329.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_329.png
# Saved: ..\data\raw_images\thai_tones\์\์_329.png
# Saved: ..\data\raw_images\thai_tones\่\่_330.png
# Saved: ..\data\raw_images\thai_tones\้\้_330.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_330.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_330.png
# Saved: ..\data\raw_images\thai_tones\์\์_330.png
# Saved: ..\data\raw_images\thai_tones\่\่_331.png
# Saved: ..\data\raw_images\thai_tones\้\้_331.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_331.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_331.png
# Saved: ..\data\raw_images\thai_tones\์\์_331.png
# Saved: ..\data\raw_images\thai_tones\่\่_332.png
# Saved: ..\data\raw_images\thai_tones\้\้_332.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_332.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_332.png
# Saved: ..\data\raw_images\thai_tones\์\์_332.png
# Saved: ..\data\raw_images\thai_tones\่\่_333.png
# Saved: ..\data\raw_images\thai_tones\้\้_333.png
# Saved: ..\data\raw_images\thai_tones\๊\๊_333.png
# Saved: ..\data\raw_images\thai_tones\๋\๋_333.png
# Saved: ..\data\raw_images\thai_tones\์\์_333.png

# %% [markdown]
# ## Arabic numerals

# %% [markdown]
# ### Classic method

# %%
output_folder = Path("../data/raw_images/arabic_numerals")
folder_path = Path("../font/GoogleFont")
font_number = 1

for font_file in folder_path.rglob("*.ttf"):  # ลูปภายในโฟลเดอร์ font
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':  # ตรวจสอบเฉพาะไฟล์ฟอนต์
            font = ImageFont.truetype(str(font_file), 28)  # โหลดฟอนต์
            for char in "0123456789":
                # สร้างโฟลเดอร์สำหรับตัวอักษร
                char_folder = output_folder / char
                char_folder.mkdir(parents=True, exist_ok=True)  # ถ้าโฟลเดอร์มีอยู่แล้ว จะไม่เกิดข้อผิดพลาด

                img = Image.new("L", (32, 32), "white")
                draw = ImageDraw.Draw(img)

                # คำนวณขนาดของตัวอักษรด้วย font.getbbox()
                # (left, top, right, bottom)
                bbox = font.getbbox(char)
                text_width = bbox[2] - bbox[0]
                text_height = bbox[3] - bbox[1]

                # คำนวณตำแหน่งตรงกลางของภาพ
                x = (img.width - text_width) / 2
                y = (img.height - text_height*2) / 2

                y_manual_adjustment = -5

                #if(char == "8") : y_manual_adjustment = y
                
                # วาดตัวอักษรตรงกลาง
                draw.text((x, y_manual_adjustment), char, font=font, fill="black")
                img.save(char_folder / f"{char}_{font_number}.png")  # บันทึกภาพ
                print(f"Saved: {char_folder / f'{char}_{font_number}.png'}")
            font_number+=1

# %% [markdown]
# ### Padding method

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# กำหนดโฟลเดอร์
output_folder = Path("../data/raw_images/arabic_numerals")
folder_path = Path("../font/GoogleFont")

if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':
        try:
            font = ImageFont.truetype(str(font_file), 36)  # โหลดฟอนต์
        except Exception as e:
            print(f"Skipping font {font_file}: {e}")
            continue

        for char in "0123456789":
            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / char
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y
            y_offset = ascent - bbox[3]

            if(159 <= font_number <= 170):
                y_offset-=2
            elif(171 <= font_number <= 207):
                y_offset+=3
            elif(217 <= font_number <= 253):
                y_offset+=4
            elif(278 <= font_number <= 293):
                y_offset-=2
            elif(294 <= font_number <= 311):
                y_offset+=2

            draw.text((0, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            output_path = char_folder / f"{char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")
# Out:
# Saved: ..\data\raw_images\arabic_numerals\0\0_1.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_1.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_1.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_1.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_1.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_1.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_1.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_1.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_1.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_1.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_2.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_2.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_2.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_2.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_2.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_2.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_2.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_2.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_2.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_2.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_3.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_3.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_3.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_3.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_3.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_3.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_3.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_3.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_3.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_3.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_4.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_4.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_4.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_4.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_4.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_4.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_4.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_4.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_4.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_4.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_5.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_5.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_5.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_5.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_5.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_5.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_5.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_5.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_5.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_5.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_6.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_6.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_6.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_6.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_6.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_6.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_6.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_6.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_6.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_6.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_7.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_7.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_7.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_7.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_7.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_7.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_7.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_7.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_7.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_7.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_8.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_8.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_8.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_8.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_8.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_8.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_8.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_8.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_8.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_8.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_9.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_9.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_9.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_9.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_9.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_9.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_9.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_9.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_9.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_9.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_10.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_10.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_10.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_10.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_10.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_10.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_10.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_10.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_10.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_10.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_11.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_11.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_11.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_11.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_11.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_11.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_11.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_11.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_11.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_11.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_12.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_12.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_12.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_12.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_12.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_12.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_12.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_12.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_12.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_12.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_13.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_13.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_13.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_13.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_13.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_13.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_13.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_13.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_13.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_13.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_14.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_14.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_14.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_14.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_14.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_14.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_14.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_14.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_14.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_14.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_15.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_15.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_15.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_15.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_15.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_15.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_15.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_15.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_15.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_15.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_16.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_16.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_16.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_16.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_16.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_16.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_16.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_16.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_16.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_16.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_17.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_17.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_17.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_17.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_17.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_17.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_17.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_17.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_17.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_17.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_18.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_18.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_18.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_18.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_18.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_18.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_18.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_18.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_18.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_18.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_19.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_19.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_19.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_19.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_19.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_19.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_19.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_19.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_19.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_19.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_20.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_20.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_20.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_20.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_20.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_20.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_20.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_20.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_20.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_20.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_21.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_21.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_21.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_21.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_21.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_21.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_21.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_21.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_21.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_21.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_22.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_22.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_22.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_22.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_22.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_22.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_22.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_22.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_22.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_22.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_23.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_23.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_23.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_23.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_23.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_23.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_23.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_23.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_23.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_23.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_24.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_24.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_24.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_24.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_24.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_24.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_24.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_24.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_24.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_24.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_25.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_25.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_25.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_25.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_25.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_25.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_25.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_25.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_25.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_25.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_26.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_26.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_26.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_26.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_26.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_26.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_26.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_26.png
# Saved: ..\data\raw_images\arabic_numerals\8\8
png
# Saved: ..\data\raw_images\arabic_numerals\0\0_316.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_316.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_316.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_316.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_316.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_316.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_316.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_316.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_316.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_316.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_317.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_317.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_317.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_317.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_317.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_317.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_317.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_317.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_317.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_317.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_318.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_318.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_318.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_318.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_318.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_318.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_318.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_318.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_318.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_318.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_319.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_319.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_319.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_319.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_319.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_319.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_319.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_319.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_319.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_319.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_320.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_320.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_320.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_320.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_320.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_320.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_320.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_320.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_320.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_320.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_321.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_321.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_321.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_321.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_321.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_321.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_321.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_321.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_321.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_321.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_322.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_322.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_322.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_322.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_322.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_322.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_322.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_322.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_322.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_322.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_323.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_323.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_323.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_323.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_323.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_323.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_323.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_323.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_323.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_323.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_324.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_324.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_324.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_324.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_324.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_324.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_324.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_324.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_324.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_324.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_325.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_325.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_325.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_325.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_325.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_325.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_325.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_325.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_325.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_325.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_326.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_326.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_326.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_326.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_326.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_326.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_326.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_326.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_326.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_326.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_327.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_327.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_327.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_327.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_327.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_327.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_327.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_327.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_327.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_327.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_328.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_328.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_328.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_328.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_328.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_328.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_328.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_328.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_328.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_328.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_329.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_329.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_329.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_329.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_329.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_329.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_329.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_329.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_329.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_329.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_330.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_330.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_330.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_330.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_330.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_330.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_330.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_330.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_330.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_330.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_331.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_331.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_331.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_331.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_331.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_331.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_331.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_331.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_331.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_331.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_332.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_332.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_332.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_332.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_332.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_332.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_332.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_332.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_332.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_332.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_333.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_333.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_333.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_333.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_333.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_333.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_333.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_333.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_333.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_333.png

# %%
import PIL

print(PIL.__version__)
# Out:
# 11.0.0

# %% [markdown]
# ## Special

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# ระบุโฟลเดอร์ที่ต้องการอ่านไฟล์ทั้งหมด
output_folder = Path("../data/raw_images/special")
folder_path = Path("../font/GoogleFont")


if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':
        for char in "+-*().=/\|":#ขีดกะลบตัวเดียวกัน(-) ทับกะหารตัวเดียวกัน(/)
            try:
                if(char == "-" ):
                    font = ImageFont.truetype(str(font_file), 66)
                elif(char == "*" ):
                    font = ImageFont.truetype(str(font_file), 66)
                elif(char == "+" ):
                    font = ImageFont.truetype(str(font_file), 60)
                elif(char == "=" ):
                    font = ImageFont.truetype(str(font_file), 60)
                elif(char == "(" or char == ")" ):
                    font = ImageFont.truetype(str(font_file), 32)
                elif(char == "."  ):
                    font = ImageFont.truetype(str(font_file), 105)
                elif(char == "/"  or char == "|" or char == "\\" ):
                    font = ImageFont.truetype(str(font_file), 32)
                else:
                    font = ImageFont.truetype(str(font_file), 46)
            except Exception as e:
                print(f"Skipping font {font_file}: {e}")
                continue

            # สร้างโฟลเดอร์สำหรับตัวเลข
            if char == "*":
                char_folder = output_folder / "multiply"
            elif char == ".":
                char_folder = output_folder / "dot"
            elif char == "/":
                char_folder = output_folder / "slash"
            elif char == "\\":
                char_folder = output_folder / "backslash"
            elif char == "|":
                char_folder = output_folder / "pipe"
            else:
                char_folder = output_folder / f"{char}"
            
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y ทั่วไป
            y_offset = ascent - bbox[3]
            x_offset = 0

            # ปรับตำแหน่ง y_offset เฉพาะจุด
            # +ลง -ขึ้น
            if(char == "-"):
                if(1 <= font_number <= 26):
                    y_offset+=15
                elif(27 <= font_number <= 36):
                    y_offset-=4
                elif(37 <= font_number <= 49):
                    y_offset-=6
                elif(51 <= font_number <= 63):
                    y_offset+=3
                elif(font_number == 64):
                    y_offset-=8
                elif(65 <= font_number <= 80):
                    y_offset-=5
                elif(81 <= font_number <= 96):
                    y_offset-=3
                elif(67 <= font_number <= 110):
                    y_offset-=6
                elif(111 <= font_number <= 122):
                    y_offset-=8
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(135 <= font_number <= 140):
                    y_offset-=0
                elif(141 <= font_number <= 152):
                    y_offset-=2
                elif(153 <= font_number <= 158):
                    y_offset-=4
                elif(159 <= font_number <= 170):
                    y_offset-=10
                elif(171 <= font_number <= 207):
                    y_offset-=1
                elif(208 <= font_number <= 216):
                    y_offset-=10
                elif(217 <= font_number <= 253):
                    y_offset+=2
                elif(254 <= font_number <= 259):
                    y_offset-=0
                elif(260 <= font_number <= 277):
                    y_offset-=3
                elif(278 <= font_number <= 293):
                    y_offset-=8
                elif(294 <= font_number <= 311):
                    y_offset-=1
                elif(312 <= font_number <= 315):
                    y_offset-=2
                elif(316 <= font_number <= 333):
                    y_offset-=2
            
            if(char == "*"):
                if(1 <= font_number <= 2 or 9<= font_number <= 14 or font_number ==7):
                    y_offset+=27
                elif(3<= font_number <= 6 or font_number ==8 or 15<= font_number <= 26 ):
                    y_offset+=32
                elif(27 <= font_number <= 36):
                    y_offset+=15
                elif(37 <= font_number <= 49):
                    y_offset+=9
                elif(font_number == 50 or font_number == 57 or font_number == 55 or font_number == 62 ):
                    y_offset+=12
                elif(51 <= font_number <= 54 or font_number == 56 or font_number == 63 or 58 <= font_number <= 61 ):
                    y_offset+=18
                elif(64 <= font_number <= 80):
                    y_offset+=8
                elif(81 <= font_number <= 110):
                    y_offset+=8
                elif(111 <= font_number <= 122):
                    y_offset+=12
                elif(123 <= font_number <= 134):
                    y_offset+=22
                elif(135 <= font_number <= 140):
                    y_offset+=15
                elif(141 <= font_number <= 152):
                    y_offset+=6
                elif(153 <= font_number <= 158):
                    y_offset+=12
                elif(159 <= font_number <= 170):
                    y_offset+=6
                elif(171 <= font_number <= 207):
                    y_offset+=15
                elif(208 <= font_number <= 216):
                    y_offset+=7
                elif(217 <= font_number <= 253):
                    y_offset+=20
                elif(254 <= font_number <= 259):
                    y_offset+=15
                elif(260 <= font_number <= 277):
                    y_offset+=15
                elif(278 <= font_number <= 293):
                    y_offset+=8
                elif(294 <= font_number <= 311):
                    y_offset+=12
                elif(312 <= font_number <= 315):
                    y_offset+=15
                elif(316 <= font_number <= 333):
                    y_offset+=12
            if(char == "(" or char == ")"):
                if(1 <= font_number <= 26):
                    y_offset+=22
                elif(27 <= font_number <= 36):
                    y_offset+=6
                elif(37 <= font_number <= 49 or font_number == 64):
                    y_offset+=3
                elif(50 <= font_number <= 63):
                    y_offset+=5
                elif(65 <= font_number <= 80):
                    y_offset+=2
                elif(81 <= font_number <= 110):
                    y_offset+=2
                elif(111 <= font_number <= 122):
                    y_offset+=4
                elif(123 <= font_number <= 134):
                    y_offset+=4
                elif(135 <= font_number <= 140):
                    y_offset+=4
                elif(141 <= font_number <= 152):
                    y_offset+=3
                elif(153 <= font_number <= 158):
                    y_offset+=4
                elif(159 <= font_number <= 170):
                    y_offset-=0
                elif(171 <= font_number <= 207):
                    y_offset+=6
                elif(208 <= font_number <= 216):
                    y_offset-=0
                elif(217 <= font_number <= 253):
                    y_offset+=6
                elif(254 <= font_number <= 259):
                    y_offset+=3
                elif(260 <= font_number <= 277):
                    y_offset+=5
                elif(278 <= font_number <= 293):
                    y_offset-=0
                elif(294 <= font_number <= 311):
                    y_offset+=5
                elif(312 <= font_number <= 315):
                    y_offset+=2
                elif(316 <= font_number <= 333):
                    y_offset+=2
            if(char == "."):
                if(1 <= font_number <= 26):
                    y_offset-=15
                    x_offset+=2
                elif(27 <= font_number <= 36):
                    y_offset-=30
                    x_offset+=2
                elif(37 <= font_number <= 49):
                    y_offset-=30
                    x_offset+=2
                elif(50 <= font_number <= 63):
                    y_offset-=20
                elif(64 <= font_number <= 80):
                    y_offset-=33
                    x_offset+=2
                elif(97<= font_number <= 110 or 94<= font_number <= 95 or 90 <= font_number <= 92 or 87 <= font_number <= 88 or font_number == 81 or font_number == 83 or  font_number == 85 ):
                    y_offset-=30
                    x_offset+=2
                elif( font_number == 82 or font_number == 84 or font_number == 86 or font_number == 89 or font_number == 93 or font_number == 96 ):
                    y_offset-=30
                    x_offset+=7
                elif(111 <= font_number <= 122):
                    y_offset-=35
                    x_offset+=2
                elif(123 <= font_number <= 134):
                    y_offset-=30
                    x_offset+=2
                elif(135 <= font_number <= 140):
                    y_offset-=25
                    x_offset+=0
                elif(141 <= font_number <= 152):
                    y_offset-=35
                    x_offset+=2
                elif(153 <= font_number <= 158):
                    y_offset-=30
                    x_offset+=2
                elif(159 <= font_number <= 170):
                    y_offset-=40
                    x_offset+=2
                elif(171 <= font_number <= 207):
                    y_offset-=25
                    x_offset+=2
                elif(208 <= font_number <= 216):
                    y_offset-=37
                    x_offset+=2
                elif(217 <= font_number <= 253):
                    y_offset-=20
                    x_offset+=2
                elif(254 <= font_number <= 259):
                    y_offset-=30
                    x_offset+=2
                elif(260 <= font_number <= 277):
                    y_offset-=30
                    x_offset+=2
                elif(278 <= font_number <= 291):
                    y_offset-=35
                    x_offset+=2
                elif(292 <= font_number <= 293):
                    y_offset-=40
                    x_offset+=2
                elif(294 <= font_number <= 311):
                    y_offset-=25
                    x_offset+=2
                elif(312 <= font_number <= 315):
                    y_offset-=30
                    x_offset+=2
                elif(316 <= font_number <= 321):
                    y_offset-=27
                    x_offset+=2
                elif(322 <= font_number <= 333):
                    y_offset-=30
                    x_offset+=2
            if(char == "="):
                if(1 <= font_number <= 26):
                    y_offset+=15
                elif(27 <= font_number <= 36):
                    y_offset-=2
                elif(37 <= font_number <= 49):
                    y_offset-=3
                elif(64 <= font_number <= 80):
                    y_offset-=4
                elif(81 <= font_number <= 110):
                    y_offset-=5
                elif(111 <= font_number <= 122):
                    y_offset-=5
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(135 <= font_number <= 140):
                    y_offset-=2
                elif(141 <= font_number <= 152):
                    y_offset-=4
                elif(153 <= font_number <= 158):
                    y_offset-=4
                elif(159 <= font_number <= 170):
                    y_offset-=7
                elif(171 <= font_number <= 207):
                    y_offset-=1
                elif(208 <= font_number <= 216):
                    y_offset-=7
                elif(217 <= font_number <= 253):
                    y_offset+=2
                elif(254 <= font_number <= 259):
                    y_offset-=3
                elif(260 <= font_number <= 277):
                    y_offset-=3
                elif(278 <= font_number <= 293):
                    y_offset-=5
                elif(294 <= font_number <= 311):
                    y_offset-=1
                elif(312 <= font_number <= 315):
                    y_offset-=2
                elif(316 <= font_number <= 333):
                    y_offset-=2
            if(char == "+"):
                if(1 <= font_number <= 26):
                    y_offset+=15
                elif(27 <= font_number <= 36):
                    y_offset-=2
                elif(37 <= font_number <= 49):
                    y_offset-=3
                elif(64 <= font_number <= 80):
                    y_offset-=8
                elif(81 <= font_number <= 86):
                    y_offset-=3
                elif(87 <= font_number <= 110):
                    y_offset-=5
                elif(111 <= font_number <= 122):
                    y_offset-=5
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(135 <= font_number <= 140):
                    y_offset-=2
                elif(141 <= font_number <= 152):
                    y_offset-=4
                elif(153 <= font_number <= 158):
                    y_offset-=4
                elif(159 <= font_number <= 170):
                    y_offset-=8
                elif(171 <= font_number <= 207):
                    y_offset+=3
                elif(208 <= font_number <= 216):
                    y_offset-=7
                elif(217 <= font_number <= 253):
                    y_offset+=2
                elif(254 <= font_number <= 259):
                    y_offset-=3
                elif(260 <= font_number <= 277):
                    y_offset-=3
                elif(278 <= font_number <= 293):
                    y_offset-=5
                elif(294 <= font_number <= 311):
                    y_offset-=1
                elif(312 <= font_number <= 315):
                    y_offset-=2
                elif(316 <= font_number <= 333):
                    y_offset-=2
            if(char == "/"  or char == "|" or char == "\\"):
                if(1 <= font_number <= 26):
                    y_offset+=1
                elif(27 <= font_number <= 36):
                    y_offset-=1
                elif(37 <= font_number <= 49):
                    y_offset+=1
                elif(50<= font_number <= 63):
                    y_offset+=4
                elif(64 <= font_number <= 80):
                    y_offset-=1
                elif(81 <= font_number <= 110):
                    y_offset+=1
                elif(111 <= font_number <= 122):
                    y_offset+=2
                elif(123 <= font_number <= 134):
                    y_offset+=2
                elif(135 <= font_number <= 140):
                    y_offset+=4
                elif(141 <= font_number <= 152):
                    y_offset+=2
                elif(153 <= font_number <= 158):
                    y_offset+=2
                elif(159 <= font_number <= 170):
                    y_offset-=2
                elif(171 <= font_number <= 207):
                    y_offset+=3
                elif(208 <= font_number <= 216):
                    y_offset-=1
                elif(217 <= font_number <= 253):
                    y_offset+=6
                elif(254 <= font_number <= 259):
                    y_offset+=1
                elif(260 <= font_number <= 277):
                    y_offset+=2
                elif(278 <= font_number <= 293):
                    y_offset+=0
                elif(294 <= font_number <= 311):
                    y_offset-=0
                elif(312 <= font_number <= 315):
                    y_offset+=3
                elif(316 <= font_number <= 333):
                    y_offset+=1
            
            else:
                if(1 <= font_number <= 26):
                    y_offset-=19
                elif(27 <= font_number <= 36):
                    y_offset-=2
                elif(37 <= font_number <= 49):
                    y_offset-=3
                elif(64 <= font_number <= 80):
                    y_offset-=4
                elif(81 <= font_number <= 110):
                    y_offset-=3
                elif(111 <= font_number <= 122):
                    y_offset-=5
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(135 <= font_number <= 140):
                    y_offset-=2
                elif(141 <= font_number <= 152):
                    y_offset-=4
                elif(153 <= font_number <= 158):
                    y_offset-=4
                elif(159 <= font_number <= 170):
                    y_offset-=7
                elif(171 <= font_number <= 207):
                    y_offset-=1
                elif(208 <= font_number <= 216):
                    y_offset-=7
                elif(217 <= font_number <= 253):
                    y_offset+=2
                elif(254 <= font_number <= 259):
                    y_offset-=3
                elif(260 <= font_number <= 277):
                    y_offset-=3
                elif(278 <= font_number <= 293):
                    y_offset-=5
                elif(294 <= font_number <= 311):
                    y_offset-=1
                elif(312 <= font_number <= 315):
                    y_offset-=2
                elif(316 <= font_number <= 333):
                    y_offset-=2

            
            draw.text((x_offset, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            sanitized_char = char.replace("*", "multiply").replace(".", "dot").replace("/", "slash").replace("\\", "backslash").replace("|", "pipe")
            output_path = char_folder / f"{sanitized_char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")
# Out:
# Saved: ..\data\raw_images\special\+\+_1.png
# Saved: ..\data\raw_images\special\-\-_1.png
# Saved: ..\data\raw_images\special\multiply\multiply_1.png
# Saved: ..\data\raw_images\special\(\(_1.png
# Saved: ..\data\raw_images\special\)\)_1.png
# Saved: ..\data\raw_images\special\dot\dot_1.png
# Saved: ..\data\raw_images\special\=\=_1.png
# Saved: ..\data\raw_images\special\slash\slash_1.png
# Saved: ..\data\raw_images\special\backslash\backslash_1.png
# Saved: ..\data\raw_images\special\pipe\pipe_1.png
# Saved: ..\data\raw_images\special\+\+_2.png
# Saved: ..\data\raw_images\special\-\-_2.png
# Saved: ..\data\raw_images\special\multiply\multiply_2.png
# Saved: ..\data\raw_images\special\(\(_2.png
# Saved: ..\data\raw_images\special\)\)_2.png
# Saved: ..\data\raw_images\special\dot\dot_2.png
# Saved: ..\data\raw_images\special\=\=_2.png
# Saved: ..\data\raw_images\special\slash\slash_2.png
# Saved: ..\data\raw_images\special\backslash\backslash_2.png
# Saved: ..\data\raw_images\special\pipe\pipe_2.png
# Saved: ..\data\raw_images\special\+\+_3.png
# Saved: ..\data\raw_images\special\-\-_3.png
# Saved: ..\data\raw_images\special\multiply\multiply_3.png
# Saved: ..\data\raw_images\special\(\(_3.png
# Saved: ..\data\raw_images\special\)\)_3.png
# Saved: ..\data\raw_images\special\dot\dot_3.png
# Saved: ..\data\raw_images\special\=\=_3.png
# Saved: ..\data\raw_images\special\slash\slash_3.png
# Saved: ..\data\raw_images\special\backslash\backslash_3.png
# Saved: ..\data\raw_images\special\pipe\pipe_3.png
# Saved: ..\data\raw_images\special\+\+_4.png
# Saved: ..\data\raw_images\special\-\-_4.png
# Saved: ..\data\raw_images\special\multiply\multiply_4.png
# Saved: ..\data\raw_images\special\(\(_4.png
# Saved: ..\data\raw_images\special\)\)_4.png
# Saved: ..\data\raw_images\special\dot\dot_4.png
# Saved: ..\data\raw_images\special\=\=_4.png
# Saved: ..\data\raw_images\special\slash\slash_4.png
# Saved: ..\data\raw_images\special\backslash\backslash_4.png
# Saved: ..\data\raw_images\special\pipe\pipe_4.png
# Saved: ..\data\raw_images\special\+\+_5.png
# Saved: ..\data\raw_images\special\-\-_5.png
# Saved: ..\data\raw_images\special\multiply\multiply_5.png
# Saved: ..\data\raw_images\special\(\(_5.png
# Saved: ..\data\raw_images\special\)\)_5.png
# Saved: ..\data\raw_images\special\dot\dot_5.png
# Saved: ..\data\raw_images\special\=\=_5.png
# Saved: ..\data\raw_images\special\slash\slash_5.png
# Saved: ..\data\raw_images\special\backslash\backslash_5.png
# Saved: ..\data\raw_images\special\pipe\pipe_5.png
# Saved: ..\data\raw_images\special\+\+_6.png
# Saved: ..\data\raw_images\special\-\-_6.png
# Saved: ..\data\raw_images\special\multiply\multiply_6.png
# Saved: ..\data\raw_images\special\(\(_6.png
# Saved: ..\data\raw_images\special\)\)_6.png
# Saved: ..\data\raw_images\special\dot\dot_6.png
# Saved: ..\data\raw_images\special\=\=_6.png
# Saved: ..\data\raw_images\special\slash\slash_6.png
# Saved: ..\data\raw_images\special\backslash\backslash_6.png
# Saved: ..\data\raw_images\special\pipe\pipe_6.png
# Saved: ..\data\raw_images\special\+\+_7.png
# Saved: ..\data\raw_images\special\-\-_7.png
# Saved: ..\data\raw_images\special\multiply\multiply_7.png
# Saved: ..\data\raw_images\special\(\(_7.png
# Saved: ..\data\raw_images\special\)\)_7.png
# Saved: ..\data\raw_images\special\dot\dot_7.png
# Saved: ..\data\raw_images\special\=\=_7.png
# Saved: ..\data\raw_images\special\slash\slash_7.png
# Saved: ..\data\raw_images\special\backslash\backslash_7.png
# Saved: ..\data\raw_images\special\pipe\pipe_7.png
# Saved: ..\data\raw_images\special\+\+_8.png
# Saved: ..\data\raw_images\special\-\-_8.png
# Saved: ..\data\raw_images\special\multiply\multiply_8.png
# Saved: ..\data\raw_images\special\(\(_8.png
# Saved: ..\data\raw_images\special\)\)_8.png
# Saved: ..\data\raw_images\special\dot\dot_8.png
# Saved: ..\data\raw_images\special\=\=_8.png
# Saved: ..\data\raw_images\special\slash\slash_8.png
# Saved: ..\data\raw_images\special\backslash\backslash_8.png
# Saved: ..\data\raw_images\special\pipe\pipe_8.png
# Saved: ..\data\raw_images\special\+\+_9.png
# Saved: ..\data\raw_images\special\-\-_9.png
# Saved: ..\data\raw_images\special\multiply\multiply_9.png
# Saved: ..\data\raw_images\special\(\(_9.png
# Saved: ..\data\raw_images\special\)\)_9.png
# Saved: ..\data\raw_images\special\dot\dot_9.png
# Saved: ..\data\raw_images\special\=\=_9.png
# Saved: ..\data\raw_images\special\slash\slash_9.png
# Saved: ..\data\raw_images\special\backslash\backslash_9.png
# Saved: ..\data\raw_images\special\pipe\pipe_9.png
# Saved: ..\data\raw_images\special\+\+_10.png
# Saved: ..\data\raw_images\special\-\-_10.png
# Saved: ..\data\raw_images\special\multiply\multiply_10.png
# Saved: ..\data\raw_images\special\(\(_10.png
# Saved: ..\data\raw_images\special\)\)_10.png
# Saved: ..\data\raw_images\special\dot\dot_10.png
# Saved: ..\data\raw_images\special\=\=_10.png
# Saved: ..\data\raw_images\special\slash\slash_10.png
# Saved: ..\data\raw_images\special\backslash\backslash_10.png
# Saved: ..\data\raw_images\special\pipe\pipe_10.png
# Saved: ..\data\raw_images\special\+\+_11.png
# Saved: ..\data\raw_images\special\-\-_11.png
# Saved: ..\data\raw_images\special\multiply\multiply_11.png
# Saved: ..\data\raw_images\special\(\(_11.png
# Saved: ..\data\raw_images\special\)\)_11.png
# Saved: ..\data\raw_images\special\dot\dot_11.png
# Saved: ..\data\raw_images\special\=\=_11.png
# Saved: ..\data\raw_images\special\slash\slash_11.png
# Saved: ..\data\raw_images\special\backslash\backslash_11.png
# Saved: ..\data\raw_images\special\pipe\pipe_11.png
# Saved: ..\data\raw_images\special\+\+_12.png
# Saved: ..\data\raw_images\special\-\-_12.png
# Saved: ..\data\raw_images\special\multiply\multiply_12.png
# Saved: ..\data\raw_images\special\(\(_12.png
# Saved: ..\data\raw_images\special\)\)_12.png
# Saved: ..\data\raw_images\special\dot\dot_12.png
# Saved: ..\data\raw_images\special\=\=_12.png
# Saved: ..\data\raw_images\special\slash\slash_12.png
# Saved: ..\data\raw_images\special\backslash\backslash_12.png
# Saved: ..\data\raw_images\special\pipe\pipe_12.png
# Saved: ..\data\raw_images\special\+\+_13.png
# Saved: ..\data\raw_images\special\-\-_13.png
# Saved: ..\data\raw_images\special\multiply\multiply_13.png
# Saved: ..\data\raw_images\special\(\(_13.png
# Saved: ..\data\raw_images\special\)\)_13.png
# Saved: ..\data\raw_images\special\dot\dot_13.png
# Saved: ..\data\raw_images\special\=\=_13.png
# Saved: ..\data\raw_images\special\slash\slash_13.png
# Saved: ..\data\raw_images\special\backslash\backslash_13.png
# Saved: ..\data\raw_images\special\pipe\pipe_13.png
# Saved: ..\data\raw_images\special\+\+_14.png
# Saved: ..\data\raw_images\special\-\-_14.png
# Saved: ..\data\raw_images\special\multiply\multiply_14.png
# Saved: ..\data\raw_images\special\(\(_14.png
# Saved: ..\data\raw_images\special\)\)_14.png
# Saved: ..\data\raw_images\special\dot\dot_14.png
# Saved: ..\data\raw_images\special\=\=_14.png
# Saved: ..\data\raw_images\special\slash\slash_14.png
# Saved: ..\data\raw_images\special\backslash\backslash_14.png
# Saved: ..\data\raw_images\special\pipe\pipe_14.png
# Saved: ..\data\raw_images\special\+\+_15.png
# Saved: ..\data\raw_images\special\-\-_15.png
# Saved: ..\data\raw_images\special\multiply\multiply_15.png
# Saved: ..\data\raw_images\special\(\(_15.png
# Saved: ..\data\raw_images\special\)\)_15.png
# Saved: ..\data\raw_images\special\dot\dot_15.png
# Saved: ..\data\raw_images\special\=\=_15.png
# Saved: ..\data\raw_images\special\slash\slash_15.png
# Saved: ..\data\raw_images\special\backslash\backslash_15.png
# Saved: ..\data\raw_images\special\pipe\pipe_15.png
# Saved: ..\data\raw_images\special\+\+_16.png
# Saved: ..\data\raw_images\special\-\-_16.png
# Saved: ..\data\raw_images\special\multiply\multiply_16.png
# Saved: ..\data\raw_images\special\(\(_16.png
# Saved: ..\data\raw_images\special\)\)_16.png
# Saved: ..\data\raw_images\special\dot\dot_16.png
# Saved: ..\data\raw_images\special\=\=_16.png
# Saved: ..\data\raw_images\special\slash\slash_16.png
# Saved: ..\data\raw_images\special\backslash\backslash_16.png
# Saved: ..\data\raw_images\special\pipe\pipe_16.png
# Saved: ..\data\raw_images\special\+\+_17.png
# Saved: ..\data\raw_images\special\-\-_17.png
# Saved: ..\data\raw_images\special\multiply\multiply_17.png
# Saved: ..\data\raw_images\special\(\(_17.png
# Saved: ..\data\raw_images\special\)\)_17.png
# Saved: ..\data\raw_images\special\dot\dot_17.png
# Saved: ..\data\raw_images\special\=\=_17.png
# Saved: ..\data\raw_images\special\slash\slash_17.png
# Saved: ..\data\raw_images\special\backslash\backslash_17.png
# Saved: ..\data\raw_images\special\pipe\pipe_17.png
# Saved: ..\data\raw_images\special\+\+_18.png
# Saved: ..\data\raw_images\special\-\-_18.png
# Saved: ..\data\raw_images\special\multiply\multiply_18.png
# Saved: ..\data\raw_images\special\(\(_18.png
# Saved: ..\data\raw_images\special\)\)_18.png
# Saved: ..\data\raw_images\special\dot\dot_18.png
# Saved: ..\data\raw_images\special\=\=_18.png
# Saved: ..\data\raw_images\special\slash\slash_18.png
# Saved: ..\data\raw_images\special\backslash\backslash_18.png
# Saved: ..\data\raw_images\special\pipe\pipe_18.png
# Saved: ..\data\raw_images\special\+\+_19.png
# Saved: ..\data\raw_images\special\-\-_19.png
# Saved: ..\data\raw_images\special\multiply\multiply_19.png
# Saved: ..\data\raw_images\special\(\(_19.png
# Saved: ..\data\raw_images\special\)\)_19.png
# Saved: ..\data\raw_images\special\dot\dot_19.png
# Saved: ..\data\raw_images\special\=\=_19.png
# Saved: ..\data\raw_images\special\slash\slash_19.png
# Saved: ..\data\raw_images\special\backslash\backslash_19.png
# Saved: ..\data\raw_images\special\pipe\pipe_19.png
# Saved: ..\data\raw_images\special\+\+_20.png
# Saved: ..\data\raw_images\special\-\-_20.png
# Saved: ..\data\raw_images\special\multiply\multiply_20.png
# Saved: ..\data\raw_images\special\(\(_20.png
# Saved: ..\data\raw_images\special\)\)_20.png
# Saved: ..\data\raw_images\special\dot\dot_20.png
# Saved: ..\data\raw_images\special\=\=_20.png
# Saved: ..\data\raw_images\special\slash\slash_20.png
# Saved: ..\data\raw_images\special\backslash\backslash_20.png
# Saved: ..\data\raw_images\special\pipe\pipe_20.png
# Saved: ..\data\raw_images\special\+\+_21.png
# Saved: ..\data\raw_images\special\-\-_21.png
# Saved: ..\data\raw_images\special\multiply\multiply_21.png
# Saved: ..\data\raw_images\special\(\(_21.png
# Saved: ..\data\raw_images\special\)\)_21.png
# Saved: ..\data\raw_images\special\dot\dot_21.png
# Saved: ..\data\raw_images\special\=\=_21.png
# Saved: ..\data\raw_images\special\slash\slash_21.png
# Saved: ..\data\raw_images\special\backslash\backslash_21.png
# Saved: ..\data\raw_images\special\pipe\pipe_21.png
# Saved: ..\data\raw_images\special\+\+_22.png
# Saved: ..\data\raw_images\special\-\-_22.png
# Saved: ..\data\raw_images\special\multiply\multiply_22.png
# Saved: ..\data\raw_images\special\(\(_22.png
# Saved: ..\data\raw_images\special\)\)_22.png
# Saved: ..\data\raw_images\special\dot\dot_22.png
# Saved: ..\data\raw_images\special\=\=_22.png
# Saved: ..\data\raw_images\special\slash\slash_22.png
# Saved: ..\data\raw_images\special\backslash\backslash_22.png
# Saved: ..\data\raw_images\special\pipe\pipe_22.png
# Saved: ..\data\raw_images\special\+\+_23.png
# Saved: ..\data\raw_images\special\-\-_23.png
# Saved: ..\data\raw_images\special\multiply\multiply_23.png
# Saved: ..\data\raw_images\special\(\(_23.png
# Saved: ..\data\raw_images\special\)\)_23.png
# Saved: ..\data\raw_images\special\dot\dot_23.png
# Saved: ..\data\raw_images\special\=\=_23.png
# Saved: ..\data\raw_images\special\slash\slash_23.png
# Saved: ..\data\raw_images\special\backslash\backslash_23.png
# Saved: ..\data\raw_images\special\pipe\pipe_23.png
# Saved: ..\data\raw_images\special\+\+_24.png
# Saved: ..\data\raw_images\special\-\-_24.png
# Saved: ..\data\raw_images\special\multiply\multiply_24.png
# Saved: ..\data\raw_images\special\(\(_24.png
# Saved: ..\data\raw_images\special\)\)_24.png
# Saved: ..\data\raw_images\special\dot\dot_24.png
# Saved: ..\data\raw_images\special\=\=_24.png
# Saved: ..\data\raw_images\special\slash\slash_24.png
# Saved: ..\data\raw_images\special\backslash\backslash_24.png
# Saved: ..\data\raw_images\special\pipe\pipe_24.png
# Saved: ..\data\raw_images\special\+\+_25.png
# Saved: ..\data\raw_images\special\-\-_25.png
# Saved: ..\data\raw_images\special\multiply\multiply_25.png
# Saved: ..\data\raw_images\special\(\(_25.png
# Saved: ..\data\raw_images\special\)\)_25.png
# Saved: ..\data\raw_images\special\dot\dot_25.png
# Saved: ..\data\raw_images\special\=\=_25.png
# Saved: ..\data\raw_images\special\slash\slash_25.png
# Saved: ..\data\raw_images\special\backslash\backslash_25.png
# Saved: ..\data\raw_images\special\pipe\pipe_25.png
# Saved: ..\data\raw_images\special\+\+_26.png
# Saved: ..\data\raw_images\special\-\-_26.png
# Saved: ..\data\raw_images\special\multiply\multiply_26.png
# Saved: ..\data\raw_images\special\(\(_26.png
# Saved: ..\data\raw_images\special\)\)_26.png
# Saved: ..\data\raw_images\special\dot\dot_26.png
# Saved: ..\data\raw_images\special\=\=_26.png
# Saved: ..\data\raw_images\special\slash\slash_26.png
# Saved: ..\data\raw_images\special\backslash\backslash_26.png
# Saved: ..\data\raw_images\special\pipe\pipe_26.png
# Saved: ..\data\raw_images\special\+\+_27.png
# Saved: ..\data\raw_images\special\-\-_27.png
# Saved: ..\data\raw_images\special\multiply\multiply_27.png
# Saved: ..\data\raw_images\special\(\(_27.png
# Saved: ..\data\raw_images\special\)\)_27.png
# Saved: ..\data\raw_images\special\dot\dot_27.png
# Saved: ..\data\raw_images\special\=\=_27.png
# Saved: ..\data\raw_images\special\slash\slash_27.png
# Saved: ..\data\raw_images\special\backslash\backslash_27.png
# Saved: ..\data\raw_images\special\pipe\pipe_27.png
# Saved: ..\data\raw_images\special\+\+_28.png
# Saved: ..\data\raw_images\special\-\-_28.png
# Saved: ..\data\raw_images\special\multiply\multiply_28.png
# Saved: ..\data\raw_images\special\(\(_28.png
# Saved: ..\data\raw_images\special\)\)_28.png
# Saved: ..\data\raw_images\special\dot\dot_28.png
# Saved: ..\data\raw_images\special\=\=_28.png
# Saved: ..\data\raw_images\special\slash\slash_28.png
# Saved: ..\data\raw_images\special\backslash\backslash_28.png
# Saved: ..\data\raw_images\special\pipe\pipe_28.png
# Saved: ..\data\raw_images\special\+\+_29.png
# Saved: ..\data\raw_images\special\-\-_29.png
# Saved: ..\data\raw_images\special\multiply\multiply_29.png
# Saved: ..\data\raw_images\special\(\(_29.png
# Saved: ..\data\raw_images\special\)\)_29.png
# Saved: ..\data\raw_images\special\dot\dot_29.png
# Saved: ..\data\raw_images\special\=\=_29.png
# Saved: ..\data\raw_images\special\slash\slash_29.png
# Saved: ..\data\raw_images\special\backslash\backslash_29.png
# Saved: ..\data\raw_images\special\pipe\pipe_29.png
# Saved: ..\data\raw_images\special\+\+_30.png
# Saved: ..\data\raw_images\special\-\-_30.png
# Saved: ..\data\raw_images\special\multiply\multiply_30.png
# Saved: ..\data\raw_images\special\(\(_30.png
# Saved: ..\data\raw_images\special\)\)_30.png
# Saved: ..\data\raw_images\special\dot\dot_30.png
# Saved: ..\data\raw_images\special\=\=_30.png
# Saved: ..\data\raw_images\special\slash\slash_30.png
# Saved: ..\data\raw_images\special\backslash\backslash_30.png
# Saved: ..\data\raw_images\special\pipe\pipe_30.png
# Saved: ..\data\raw_images\special\+\+_31.png
# Saved: ..\data\raw_images\special\-\-_31.png
# Saved: ..\data\raw_images\special\multiply\multiply_31.png
# Saved: ..\data\raw_images\special\(\(_31.png
# Saved: ..\data\raw_images\special\)\)_31.png
# Saved: ..\data\raw_images\special\dot\dot_31.png
# Saved: ..\data\raw_images\special\=\=_31.png
# Saved: ..\data\raw_images\special\slash\slash_31.png
# Saved: ..\data\raw_images\special\backslash\backslash_31.png
# Saved: ..\data\raw_images\special\pipe\pipe_31.png
# Saved: ..\data\raw_images\special\+\+_32.png
# Saved: ..\data\raw_images\special\-\-_32.png
# Saved: ..\data\raw_images\special\multiply\multiply_32.png
# Saved: ..\data\raw_images\special\(\(_32.png
# Saved: ..\data\raw_images\special\)\)_32.png
# Saved: ..\data\raw_images\special\dot\dot_32.png
# Saved: ..\data\raw_images\special\=\=_32.png
# Saved: ..\data\raw_images\special\slash\slash_32.png
# Saved: ..\data\raw_images\special\backslash\backslash_32.png
# Saved: ..\data\raw_images\special\pipe\pipe_32.png
# Saved: ..\data\raw_images\special\+\+_33.png
# Saved: ..\data\raw_images\special\-\-_33.png
# Saved: ..\data\raw_images\special\multiply\multiply_33.png
# Saved: ..\data\raw_images\special\(\(_33.png
# Saved: ..\data\raw_images\special\)\)_33.png
# Saved: ..\data\raw_images\special\dot\dot_33.png
# Saved: ..\data\raw_images\special\=\=_33.png
# Saved: ..\data\raw_images\special\slash\slash_33.png
# Saved: ..\data\raw_images\special\backslash\backslash_33.png
# Saved: ..\data\raw_images\special\pipe\pipe_33.png
# Saved: ..\data\raw_images\special\+\+_34.png
# Saved: ..\data\raw_images\special\-\-_34.png
# Saved: ..\data\raw_images\special\multiply\multiply_34.png
# Saved: ..\data\raw_images\special\(\(_34.png
# Saved: ..\data\raw_images\special\)\)_34.png
# Saved: ..\data\raw_images\special\dot\dot_34.png
# Saved: ..\data\raw_images\special\=\=_34.png
# Saved: ..\data\raw_images\special\slash\slash_34.png
# Saved: ..\data\raw_images\special\backslash\backslash_34.png
# Saved: ..\data\raw_images\special\pipe\pipe_34.png
# Saved: ..\data\raw_images\special\+\+_35.png
# Saved: ..\data\raw_images\special\-\-_35.png
# Saved: ..\data\raw_images\special\multiply\multiply_35.png
# Saved: ..\data\raw_images\special\(\(_35.png
# Saved: ..\data\raw_images\special\)\)_35.png
# Saved: ..\data\raw_images\special\dot\dot_35.png
# Saved: ..\data\raw_images\special\=\=_35.png
# Saved: ..\data\raw_images\special\slash\slash_35.png
# Saved: ..\data\raw_images\special\backslash\backslash_35.png
# Saved: ..\data\raw_images\special\pipe\pipe_35.png
# Saved: ..\data\raw_images\special\+\+_36.png
# Saved: ..\data\raw_images\special\-\-_36.png
# Saved: ..\data\raw_images\special\multiply\multiply_36.png
# Saved: ..\data\raw_images\special\(\(_36.png
# Saved: ..\data\raw_images\special\)\)_36.png
# Saved: ..\data\raw_images\special\dot\dot_36.png
# Saved: ..\data\raw_images\special\=\=_36.png
# Saved: ..\data\raw_images\special\slash\slash_36.png
# Saved: ..\data\raw_images\special\backslash\backslash_36.png
# Saved: ..\data\raw_images\special\pipe\pipe_36.png
# Saved: ..\data\raw_images\special\+\+_37.png
# Saved: ..\data\raw_images\special\-\-_37.png
# Saved: ..\data\raw_images\special\multiply\multiply_37.png
# Saved: ..\data\raw_images\special\(\(_37.png
# Saved: ..\data\raw_images\special\)\)_37.png
# Saved: ..\data\raw_images\special\dot\dot_37.png
# Saved: ..\data\raw_images\special\=\=_37.png
# Saved: ..\data\raw_images\special\slash\slash_37.png
# Saved: ..\data\raw_images\special\backslash\backslash_37.png
# Saved: ..\data\raw_images\special\pipe\pipe_37.png
# Saved: ..\data\raw_images\special\+\+_38.png
# Saved: ..\data\raw_images\special\-\-_38.png
# Saved: ..\data\raw_images\special\multiply\multiply_38.png
# Saved: ..\data\raw_images\special\(\(_38.png
# Saved: ..\data\raw_images\special\)\)_38.png
# Saved: ..\data\raw_images\special\dot\dot_38.png
# Saved: ..\data\raw_images\special\=\=_38.png
# Saved: ..\data\raw_images\special\slash\slash_38.png
# Saved: ..\data\raw_images\special\backslash\backslash_38.png
# Saved: ..\data\raw_images\special\pipe\pipe_38.png
# Saved: ..\data\raw_images\special\+\+_39.png
# Saved: ..\data\raw_images\special\-\-_39.png
# Saved: ..\data\raw_images\special\multiply\multiply_39.png
# Saved: ..\data\raw_images\special\(\(_39.png
# Saved: ..\data\raw_images\special\)\)_39.png
# Saved: ..\data\raw_images\special\dot\dot_39.png
# Saved: ..\data\raw_images\special\=\=_39.png
# Saved: ..\data\raw_images\special\slash\slash_39.png
# Saved: ..\data\raw_images\special\backslash\backslash_39.png
# Saved: ..\data\raw_images\special\pipe\pipe_39.png
# Saved: ..\data\raw_images\special\+\+_40.png
# Saved: ..\data\raw_images\special\-\-_40.png
# Saved: ..\data\raw_images\special\multiply\multiply_40.png
# Saved: ..\data\raw_images\special\(\(_40.png
# Saved: ..\data\raw_images\special\)\)_40.png
# Saved: ..\data\raw_images\special\dot\dot_40.png
# Saved: ..\data\raw_images\special\=\=_40.png
# Saved: ..\data\raw_images\special\slash\slash_40.png
# Saved: ..\data\raw_images\special\backslash\backslash_40.png
# Saved: ..\data\raw_images\special\pipe\pipe_40.png
# Saved: ..\data\raw_images\special\+\+_41.png
# Saved: ..\data\raw_images\special\-\-_41.png
# Saved: ..\data\raw_images\special\multiply\multiply_41.png
# Saved: ..\data\raw_images\special\(\(_41.png
# Saved: ..\data\raw_images\special\)\)_41.png
# Saved: ..\data\raw_images\special\dot\dot_41.png
# Saved: ..\data\raw_images\special\=\=_41.png
# Saved: ..\data\raw_images\special\slash\slash_41.png
# Saved: ..\data\raw_images\special\backslash\backslash_41.png
# Saved: ..\data\raw_images\special\pipe\pipe_41.png
# Saved: ..\data\raw_images\special\+\+_42.png
# Saved: ..\data\raw_images\special\-\-_42.png
# Saved: ..\data\raw_images\special\multiply\multiply_42.png
# Saved: ..\data\raw_images\special\(\(_42.png
# Saved: ..\data\raw_images\special\)\)_42.png
# Saved: ..\data\raw_images\special\dot\dot_42.png
# Saved: ..\data\raw_images\special\=\=_42.png
# Saved: ..\data\raw_images\special\slash\slash_42.png
# Saved: ..\data\raw_images\special\backslash\backslash_42.png
# Saved: ..\data\raw_images\special\pipe\pipe_42.png
# Saved: ..\data\raw_images\special\+\+_43.png
# Saved: ..\data\raw_images\special\-\-_43.png
# Saved: ..\data\raw_images\special\multiply\multiply_43.png
# Saved: ..\data\raw_images\special\(\(_43.png
# Saved: ..\data\raw_images\special\)\)_43.png
# Saved: ..\data\raw_images\special\dot\dot_43.png
# Saved: ..\data\raw_images\special\=\=_43.png
# Saved: ..\data\raw_images\special\slash\slash_43.png
# Saved: ..\data\raw_images\special\backslash\backslash_43.png
# Saved: ..\data\raw_images\special\pipe\pipe_43.png
# Saved: ..\data\raw_images\special\+\+_44.png
# Saved: ..\data\raw_images\special\-\-_44.png
# Saved: ..\data\raw_images\special\multiply\multiply_44.png
# Saved: ..\data\raw_images\special\(\(_44.png
# Saved: ..\data\raw_images\special\)\)_44.png
# Saved: ..\data\raw_images\special\dot\dot_44.png
# Saved: ..\data\raw_images\special\=\=_44.png
# Saved: ..\data\raw_images\special\slash\slash_44.png
# Saved: ..\data\raw_images\special\backslash\backslash_44.png
# Saved: ..\data\raw_images\special\pipe\pipe_44.png
# Saved: ..\data\raw_images\special\+\+_45.png
# Saved: ..\data\raw_images\special\-\-_45.png
# Saved: ..\data\raw_images\special\multiply\multiply_45.png
# Saved: ..\data\raw_images\special\(\(_45.png
# Saved: ..\data\raw_images\special\)\)_45.png
# Saved: ..\data\raw_images\special\dot\dot_45.png
# Saved: ..\data\raw_images\special\=\=_45.png
# Saved: ..\data\raw_images\special\slash\slash_45.png
# Saved: ..\data\raw_images\special\backslash\backslash_45.png
# Saved: ..\data\raw_images\special\pipe\pipe_45.png
# Saved: ..\data\raw_images\special\+\+_46.png
# Saved: ..\data\raw_images\special\-\-_46.png
# Saved: ..\data\raw_images\special\multiply\multiply_46.png
# Saved: ..\data\raw_images\special\(\(_46.png
# Saved: ..\data\raw_images\special\)\)_46.png
# Saved: ..\data\raw_images\special\dot\dot_46.png
# Saved: ..\data\raw_images\special\=\=_46.png
# Saved: ..\data\raw_images\special\slash\slash_46.png
# Saved: ..\data\raw_images\special\backslash\backslash_46.png
# Saved: ..\data\raw_images\special\pipe\pipe_46.png
# Saved: ..\data\raw_images\special\+\+_47.png
# Saved: ..\data\raw_images\special\-\-_47.png
# Saved: ..\data\raw_images\special\multiply\multiply_47.png
# Saved: ..\data\raw_images\special\(\(_47.png
# Saved: ..\data\raw_images\special\)\)_47.png
# Saved: ..\data\raw_images\special\dot\dot_47.png
# Saved: ..\data\raw_images\special\=\=_47.png
# Saved: ..\data\raw_images\special\slash\slash_47.png
# Saved: ..\data\raw_images\special\backslash\backslash_47.png
# Saved: ..\data\raw_images\special\pipe\pipe_47.png
# Saved: ..\data\raw_images\special\+\+_48.png
# Saved: ..\data\raw_images\special\-\-_48.png
# Saved: ..\data\raw_images\special\multiply\multiply_48.png
# Saved: ..\data\raw_images\special\(\(_48.png
# Saved: ..\data\raw_images\special\)\)_48.png
# Saved: ..\data\raw_images\special\dot\dot_48.png
# Saved: ..\data\raw_images\special\=\=_48.png
# Saved: ..\data\raw_images\special\slash\slash_48.png
# Saved: ..\data\raw_images\special\backslash\backslash_48.png
# Saved: ..\data\raw_images\special\pipe\pipe_48.png
# Saved: ..\data\raw_images\special\+\+_49.png
# Saved: ..\data\raw_images\special\-\-_49.png
# Saved: ..\data\raw_images\special\multiply\multiply_49.png
# Saved: ..\data\raw_images\special\(\(_49.png
# Saved: ..\data\raw_images\special\)\)_49.png
# Saved: ..\data\raw_images\special\dot\dot_49.png
# Saved: ..\data\raw_images\special\=\=_49.png
# Saved: ..\data\raw_images\special\slash\slash_49.png
# Saved: ..\data\raw_images\special\backslash\backslash_49.png
# Saved: ..\data\raw_images\special\pipe\pipe_49.png
# Saved: ..\data\raw_images\special\+\+_50.png
# Saved: ..\data\raw_images\special\-\-_50.png
# Saved: ..\data\raw_images\special\multiply\multiply_50.png
# Saved: ..\data\raw_images\special\(\(_50.png
# Saved: ..\data\raw_images\special\)\)_50.png
# Saved: ..\data\raw_images\special\dot\dot_50.png
# Saved: ..\data\raw_images\special\=\=_50.png
# Saved: ..\data\raw_images\special\slash\slash_50.png
# Saved: ..\data\raw_images\special\backslash\backslash_50.png
# Saved: ..\data\raw_images\special\pipe\pipe_50.png
# Saved: ..\data\raw_images\special\+\+_51.png
# Saved: ..\data\raw_images\special\-\-_51.png
# Saved: ..\data\raw_images\special\multiply\multiply_51.png
# Saved: ..\data\raw_images\special\(\(_51.png
# Saved: ..\data\raw_images\special\)\)_51.png
# Saved: ..\data\raw_images\special\dot\dot_51.png
# Saved: ..\data\raw_images\special\=\=_51.png
# Saved: ..\data\raw_images\special\slash\slash_51.png
# Saved: ..\data\raw_images\special\backslash\backslash_51.png
# Saved: ..\data\raw_images\special\pipe\pipe_51.png
# Saved: ..\data\raw_images\special\+\+_52.png
# Saved: ..\data\raw_images\special\-\-_52.png
# Saved: ..\data\raw_images\special\multiply\multiply_52.png
# Saved: ..\data\raw_images\special\(\(_52.png
# Saved: ..\data\raw_images\special\)\)_52.png
# Saved: ..\data\raw_images\special\dot\dot_52.png
# Saved: ..\data\raw_images\special\=\=_52.png
# Saved: ..\data\raw_images\special\slash\slash_52.png
# Saved: ..\data\raw_images\special\backslash\backslash_52.png
# Saved: ..\data\raw_images\special\pipe\pipe_52.png
# Saved: ..\data\raw_images\special\+\+_53.png
# Saved: ..\data\raw_images\special\-\-_53.png
# Saved: ..\data\raw_images\special\multiply\multiply_53.png
# Saved: ..\data\raw_images\special\(\(_53.png
# Saved: ..\data\raw_images\special\multiply\multiply_59.png
# Saved: ..\data\raw_images\special\(\(_59.png
# Saved: ..\data\raw_images\special\)\)_59.png
# Saved: ..\data\raw_images\special\dot\dot_59.png
# Saved: ..\data\raw_images\special\=\=_59.png
# Saved: ..\data\raw_images\special\slash\slash_59.png
# Saved: ..\data\raw_images\special\backslash\backslash_59.png
# Saved: ..\data\raw_images\special\pipe\pipe_59.png
# Saved: ..\data\raw_images\special\+\+_60.png
# Saved: ..\data\raw_images\special\-\-_60.png
# Saved: ..\data\raw_images\special\multiply\multiply_60.png
# Saved: ..\data\raw_images\special\(\(_60.png
# Saved: ..\data\raw_images\special\)\)_60.png
# Saved: ..\data\raw_images\special\dot\dot_60.png
# Saved: ..\data\raw_images\special\=\=_60.png
# Saved: ..\data\raw_images\special\slash\slash_60.png
# Saved: ..\data\raw_images\special\backslash\backslash_60.png
# Saved: ..\data\raw_images\special\pipe\pipe_60.png
# Saved: ..\data\raw_images\special\+\+_61.png
# Saved: ..\data\raw_images\special\-\-_61.png
# Saved: ..\data\raw_images\special\multiply\multiply_61.png
# Saved: ..\data\raw_images\special\(\(_61.png
# Saved: ..\data\raw_images\special\)\)_61.png
# Saved: ..\data\raw_images\special\dot\dot_61.png
# Saved: ..\data\raw_images\special\=\=_61.png
# Saved: ..\data\raw_images\special\slash\slash_61.png
# Saved: ..\data\raw_images\special\backslash\backslash_61.png
# Saved: ..\data\raw_images\special\pipe\pipe_61.png
# Saved: ..\data\raw_images\special\+\+_62.png
# Saved: ..\data\raw_images\special\-\-_62.png
# Saved: ..\data\raw_images\special\multiply\multiply_62.png
# Saved: ..\data\raw_images\special\(\(_62.png
# Saved: ..\data\raw_images\special\)\)_62.png
# Saved: ..\data\raw_images\special\dot\dot_62.png
# Saved: ..\data\raw_images\special\=\=_62.png
# Saved: ..\data\raw_images\special\slash\slash_62.png
# Saved: ..\data\raw_images\special\backslash\backslash_62.png
# Saved: ..\data\raw_images\special\pipe\pipe_62.png
# Saved: ..\data\raw_images\special\+\+_63.png
# Saved: ..\data\raw_images\special\-\-_63.png
# Saved: ..\data\raw_images\special\multiply\multiply_63.png
# Saved: ..\data\raw_images\special\(\(_63.png
# Saved: ..\data\raw_images\special\)\)_63.png
# Saved: ..\data\raw_images\special\dot\dot_63.png
# Saved: ..\data\raw_images\special\=\=_63.png
# Saved: ..\data\raw_images\special\slash\slash_63.png
# Saved: ..\data\raw_images\special\backslash\backslash_63.png
# Saved: ..\data\raw_images\special\pipe\pipe_63.png
# Saved: ..\data\raw_images\special\+\+_64.png
# Saved: ..\data\raw_images\special\-\-_64.png
# Saved: ..\data\raw_images\special\multiply\multiply_64.png
# Saved: ..\data\raw_images\special\(\(_64.png
# Saved: ..\data\raw_images\special\)\)_64.png
# Saved: ..\data\raw_images\special\dot\dot_64.png
# Saved: ..\data\raw_images\special\=\=_64.png
# Saved: ..\data\raw_images\special\slash\slash_64.png
# Saved: ..\data\raw_images\special\backslash\backslash_64.png
# Saved: ..\data\raw_images\special\pipe\pipe_64.png
# Saved: ..\data\raw_images\special\+\+_65.png
# Saved: ..\data\raw_images\special\-\-_65.png
# Saved: ..\data\raw_images\special\multiply\multiply_65.png
# Saved: ..\data\raw_images\special\(\(_65.png
# Saved: ..\data\raw_images\special\)\)_65.png
# Saved: ..\data\raw_images\special\dot\dot_65.png
# Saved: ..\data\raw_images\special\=\=_65.png
# Saved: ..\data\raw_images\special\slash\slash_65.png
# Saved: ..\data\raw_images\special\backslash\backslash_65.png
# Saved: ..\data\raw_images\special\pipe\pipe_65.png
# Saved: ..\data\raw_images\special\+\+_66.png
# Saved: ..\data\raw_images\special\-\-_66.png
# Saved: ..\data\raw_images\special\multiply\multiply_66.png
# Saved: ..\data\raw_images\special\(\(_66.png
# Saved: ..\data\raw_images\special\)\)_66.png
# Saved: ..\data\raw_images\special\dot\dot_66.png
# Saved: ..\data\raw_images\special\=\=_66.png
# Saved: ..\data\raw_images\special\slash\slash_66.png
# Saved: ..\data\raw_images\special\backslash\backslash_66.png
# Saved: ..\data\raw_images\special\pipe\pipe_66.png
# Saved: ..\data\raw_images\special\+\+_67.png
# Saved: ..\data\raw_images\special\-\-_67.png
# Saved: ..\data\raw_images\special\multiply\multiply_67.png
# Saved: ..\data\raw_images\special\(\(_67.png
# Saved: ..\data\raw_images\special\)\)_67.png
# Saved: ..\data\raw_images\special\dot\dot_67.png
# Saved: ..\data\raw_images\special\=\=_67.png
# Saved: ..\data\raw_images\special\slash\slash_67.png
# Saved: ..\data\raw_images\special\backslash\backslash_67.png
# Saved: ..\data\raw_images\special\pipe\pipe_67.png
# Saved: ..\data\raw_images\special\+\+_68.png
# Saved: ..\data\raw_images\special\-\-_68.png
# Saved: ..\data\raw_images\special\multiply\multiply_68.png
# Saved: ..\data\raw_images\special\(\(_68.png
# Saved: ..\data\raw_images\special\)\)_68.png
# Saved: ..\data\raw_images\special\dot\dot_68.png
# Saved: ..\data\raw_images\special\=\=_68.png
# Saved: ..\data\raw_images\special\slash\slash_68.png
# Saved: ..\data\raw_images\special\backslash\backslash_68.png
# Saved: ..\data\raw_images\special\pipe\pipe_68.png
# Saved: ..\data\raw_images\special\+\+_69.png
# Saved: ..\data\raw_images\special\-\-_69.png
# Saved: ..\data\raw_images\special\multiply\multiply_69.png
# Saved: ..\data\raw_images\special\(\(_69.png
# Saved: ..\data\raw_images\special\)\)_69.png
# Saved: ..\data\raw_images\special\dot\dot_69.png
# Saved: ..\data\raw_images\special\=\=_69.png
# Saved: ..\data\raw_images\special\slash\slash_69.png
# Saved: ..\data\raw_images\special\backslash\backslash_69.png
# Saved: ..\data\raw_images\special\pipe\pipe_69.png
# Saved: ..\data\raw_images\special\+\+_70.png
# Saved: ..\data\raw_images\special\-\-_70.png
# Saved: ..\data\raw_images\special\multiply\multiply_70.png
# Saved: ..\data\raw_images\special\(\(_70.png
# Saved: ..\data\raw_images\special\)\)_70.png
# Saved: ..\data\raw_images\special\dot\dot_70.png
# Saved: ..\data\raw_images\special\=\=_70.png
# Saved: ..\data\raw_images\special\slash\slash_70.png
# Saved: ..\data\raw_images\special\backslash\backslash_70.png
# Saved: ..\data\raw_images\special\pipe\pipe_70.png
# Saved: ..\data\raw_images\special\+\+_71.png
# Saved: ..\data\raw_images\special\-\-_71.png
# Saved: ..\data\raw_images\special\multiply\multiply_71.png
# Saved: ..\data\raw_images\special\(\(_71.png
# Saved: ..\data\raw_images\special\)\)_71.png
# Saved: ..\data\raw_images\special\dot\dot_71.png
# Saved: ..\data\raw_images\special\=\=_71.png
# Saved: ..\data\raw_images\special\slash\slash_71.png
# Saved: ..\data\raw_images\special\backslash\backslash_71.png
# Saved: ..\data\raw_images\special\pipe\pipe_71.png
# Saved: ..\data\raw_images\special\+\+_72.png
# Saved: ..\data\raw_images\special\-\-_72.png
# Saved: ..\data\raw_images\special\multiply\multiply_72.png
# Saved: ..\data\raw_images\special\(\(_72.png
# Saved: ..\data\raw_images\special\)\)_72.png
# Saved: ..\data\raw_images\special\dot\dot_72.png
# Saved: ..\data\raw_images\special\=\=_72.png
# Saved: ..\data\raw_images\special\slash\slash_72.png
# Saved: ..\data\raw_images\special\backslash\backslash_72.png
# Saved: ..\data\raw_images\special\pipe\pipe_72.png
# Saved: ..\data\raw_images\special\+\+_73.png
# Saved: ..\data\raw_images\special\-\-_73.png
# Saved: ..\data\raw_images\special\multiply\multiply_73.png
# Saved: ..\data\raw_images\special\(\(_73.png
# Saved: ..\data\raw_images\special\)\)_73.png
# Saved: ..\data\raw_images\special\dot\dot_73.png
# Saved: ..\data\raw_images\special\=\=_73.png
# Saved: ..\data\raw_images\special\slash\slash_73.png
# Saved: ..\data\raw_images\special\backslash\backslash_73.png
# Saved: ..\data\raw_images\special\pipe\pipe_73.png
# Saved: ..\data\raw_images\special\+\+_74.png
# Saved: ..\data\raw_images\special\-\-_74.png
# Saved: ..\data\raw_images\special\multiply\multiply_74.png
# Saved: ..\data\raw_images\special\(\(_74.png
# Saved: ..\data\raw_images\special\)\)_74.png
# Saved: ..\data\raw_images\special\dot\dot_74.png
# Saved: ..\data\raw_images\special\=\=_74.png
# Saved: ..\data\raw_images\special\slash\slash_74.png
# Saved: ..\data\raw_images\special\backslash\backslash_74.png
# Saved: ..\data\raw_images\special\pipe\pipe_74.png
# Saved: ..\data\raw_images\special\+\+_75.png
# Saved: ..\data\raw_images\special\-\-_75.png
# Saved: ..\data\raw_images\special\multiply\multiply_75.png
# Saved: ..\data\raw_images\special\(\(_75.png
# Saved: ..\data\raw_images\special\)\)_75.png
# Saved: ..\data\raw_images\special\dot\dot_75.png
# Saved: ..\data\raw_images\special\=\=_75.png
# Saved: ..\data\raw_images\special\slash\slash_75.png
# Saved: ..\data\raw_images\special\backslash\backslash_75.png
# Saved: ..\data\raw_images\special\pipe\pipe_75.png
# Saved: ..\data\raw_images\special\+\+_76.png
# Saved: ..\data\raw_images\special\-\-_76.png
# Saved: ..\data\raw_images\special\multiply\multiply_76.png
# Saved: ..\data\raw_images\special\(\(_76.png
# Saved: ..\data\raw_images\special\)\)_76.png
# Saved: ..\data\raw_images\special\dot\dot_76.png
# Saved: ..\data\raw_images\special\=\=_76.png
# Saved: ..\data\raw_images\special\slash\slash_76.png
# Saved: ..\data\raw_images\special\backslash\backslash_76.png
# Saved: ..\data\raw_images\special\pipe\pipe_76.png
# Saved: ..\data\raw_images\special\+\+_77.png
# Saved: ..\data\raw_images\special\-\-_77.png
# Saved: ..\data\raw_images\special\multiply\multiply_77.png
# Saved: ..\data\raw_images\special\(\(_77.png
# Saved: ..\data\raw_images\special\)\)_77.png
# Saved: ..\data\raw_images\special\dot\dot_77.png
# Saved: ..\data\raw_images\special\=\=_77.png
# Saved: ..\data\raw_images\special\slash\slash_77.png
# Saved: ..\data\raw_images\special\backslash\backslash_77.png
# Saved: ..\data\raw_images\special\pipe\pipe_77.png
# Saved: ..\data\raw_images\special\+\+_78.png
# Saved: ..\data\raw_images\special\-\-_78.png
# Saved: ..\data\raw_images\special\multiply\multiply_78.png
# Saved: ..\data\raw_images\special\(\(_78.png
# Saved: ..\data\raw_images\special\)\)_78.png
# Saved: ..\data\raw_images\special\dot\dot_78.png
# Saved: ..\data\raw_images\special\=\=_78.png
# Saved: ..\data\raw_images\special\slash\slash_78.png
# Saved: ..\data\raw_images\special\backslash\backslash_78.png
# Saved: ..\data\raw_images\special\pipe\pipe_78.png
# Saved: ..\data\raw_images\special\+\+_79.png
# Saved: ..\data\raw_images\special\-\-_79.png
# Saved: ..\data\raw_images\special\multiply\multiply_79.png
# Saved: ..\data\raw_images\special\(\(_79.png
# Saved: ..\data\raw_images\special\)\)_79.png
# Saved: ..\data\raw_images\special\dot\dot_79.png
# Saved: ..\data\raw_images\special\=\=_79.png
# Saved: ..\data\raw_images\special\slash\slash_79.png
# Saved: ..\data\raw_images\special\backslash\backslash_79.png
# Saved: ..\data\raw_images\special\pipe\pipe_79.png
# Saved: ..\data\raw_images\special\+\+_80.png
# Saved: ..\data\raw_images\special\-\-_80.png
# Saved: ..\data\raw_images\special\multiply\multiply_80.png
# Saved: ..\data\raw_images\special\(\(_80.png
# Saved: ..\data\raw_images\special\)\)_80.png
# Saved: ..\data\raw_images\special\dot\dot_80.png
# Saved: ..\data\raw_images\special\=\=_80.png
# Saved: ..\data\raw_images\special\slash\slash_80.png
# Saved: ..\data\raw_images\special\backslash\backslash_80.png
# Saved: ..\data\raw_images\special\pipe\pipe_80.png
# Saved: ..\data\raw_images\special\+\+_81.png
# Saved: ..\data\raw_images\special\-\-_81.png
# Saved: ..\data\raw_images\special\multiply\multiply_81.png
# Saved: ..\data\raw_images\special\(\(_81.png
# Saved: ..\data\raw_images\special\)\)_81.png
# Saved: ..\data\raw_images\special\dot\dot_81.png
# Saved: ..\data\raw_images\special\=\=_81.png
# Saved: ..\data\raw_images\special\slash\slash_81.png
# Saved: ..\data\raw_images\special\backslash\backslash_81.png
# Saved: ..\data\raw_images\special\pipe\pipe_81.png
# Saved: ..\data\raw_images\special\+\+_82.png
# Saved: ..\data\raw_images\special\-\-_82.png
# Saved: ..\data\raw_images\special\multiply\multiply_82.png
# Saved: ..\data\raw_images\special\(\(_82.png
# Saved: ..\data\raw_images\special\)\)_82.png
# Saved: ..\data\raw_images\special\dot\dot_82.png
# Saved: ..\data\raw_images\special\=\=_82.png
# Saved: ..\data\raw_images\special\slash\slash_82.png
# Saved: ..\data\raw_images\special\backslash\backslash_82.png
# Saved: ..\data\raw_images\special\pipe\pipe_82.png
# Saved: ..\data\raw_images\special\+\+_83.png
# Saved: ..\data\raw_images\special\-\-_83.png
# Saved: ..\data\raw_images\special\multiply\multiply_83.png
# Saved: ..\data\raw_images\special\(\(_83.png
# Saved: ..\data\raw_images\special\)\)_83.png
# Saved: ..\data\raw_images\special\dot\dot_83.png
# Saved: ..\data\raw_images\special\=\=_83.png
# Saved: ..\data\raw_images\special\slash\slash_83.png
# Saved: ..\data\raw_images\special\backslash\backslash_83.png
# Saved: ..\data\raw_images\special\pipe\pipe_83.png
# Saved: ..\data\raw_images\special\+\+_84.png
# Saved: ..\data\raw_images\special\-\-_84.png
# Saved: ..\data\raw_images\special\multiply\multiply_84.png
# Saved: ..\data\raw_images\special\(\(_84.png
# Saved: ..\data\raw_images\special\)\)_84.png
# Saved: ..\data\raw_images\special\dot\dot_84.png
# Saved: ..\data\raw_images\special\=\=_84.png
# Saved: ..\data\raw_images\special\slash\slash_84.png
# Saved: ..\data\raw_images\special\backslash\backslash_84.png
# Saved: ..\data\raw_images\special\pipe\pipe_84.png
# Saved: ..\data\raw_images\special\+\+_85.png
# Saved: ..\data\raw_images\special\-\-_85.png
# Saved: ..\data\raw_images\special\multiply\multiply_85.png
# Saved: ..\data\raw_images\special\(\(_85.png
# Saved: ..\data\raw_images\special\)\)_85.png
# Saved: ..\data\raw_images\special\dot\dot_85.png
# Saved: ..\data\raw_images\special\=\=_85.png
# Saved: ..\data\raw_images\special\slash\slash_85.png
# Saved: ..\data\raw_images\special\backslash\backslash_85.png
# Saved: ..\data\raw_images\special\pipe\pipe_85.png
# Saved: ..\data\raw_images\special\+\+_86.png
# Saved: ..\data\raw_images\special\-\-_86.png
# Saved: ..\data\raw_images\special\multiply\multiply_86.png
# Saved: ..\data\raw_images\special\(\(_86.png
# Saved: ..\data\raw_images\special\)\)_86.png
# Saved: ..\data\raw_images\special\dot\dot_86.png
# Saved: ..\data\raw_images\special\=\=_86.png
# Saved: ..\data\raw_images\special\slash\slash_86.png
# Saved: ..\data\raw_images\special\backslash\backslash_86.png
# Saved: ..\data\raw_images\special\pipe\pipe_86.png
# Saved: ..\data\raw_images\special\+\+_87.png
# Saved: ..\data\raw_images\special\-\-_87.png
# Saved: ..\data\raw_images\special\multiply\multiply_87.png
# Saved: ..\data\raw_images\special\(\(_87.png
# Saved: ..\data\raw_images\special\)\)_87.png
# Saved: ..\data\raw_images\special\dot\dot_87.png
# Saved: ..\data\raw_images\special\=\=_87.png
# Saved: ..\data\raw_images\special\slash\slash_87.png
# Saved: ..\data\raw_images\special\backslash\backslash_87.png
# Saved: ..\data\raw_images\special\pipe\pipe_87.png
# Saved: ..\data\raw_images\special\+\+_88.png
# Saved: ..\data\raw_images\special\-\-_88.png
# Saved: ..\data\raw_images\special\multiply\multiply_88.png
# Saved: ..\data\raw_images\special\(\(_88.png
# Saved: ..\data\raw_images\special\)\)_88.png
# Saved: ..\data\raw_images\special\dot\dot_88.png
# Saved: ..\data\raw_images\special\=\=_88.png
# Saved: ..\data\raw_images\special\slash\slash_88.png
# Saved: ..\data\raw_images\special\backslash\backslash_88.png
# Saved: ..\data\raw_images\special\pipe\pipe_88.png
# Saved: ..\data\raw_images\special\+\+_89.png
# Saved: ..\data\raw_images\special\-\-_89.png
# Saved: ..\data\raw_images\special\multiply\multiply_89.png
# Saved: ..\data\raw_images\special\(\(_89.png
# Saved: ..\data\raw_images\special\)\)_89.png
# Saved: ..\data\raw_images\special\dot\dot_89.png
# Saved: ..\data\raw_images\special\=\=_89.png
# Saved: ..\data\raw_images\special\slash\slash_89.png
# Saved: ..\data\raw_images\special\backslash\backslash_89.png
# Saved: ..\data\raw_images\special\pipe\pipe_89.png
# Saved: ..\data\raw_images\special\+\+_90.png
# Saved: ..\data\raw_images\special\-\-_90.png
# Saved: ..\data\raw_images\special\multiply\multiply_90.png
# Saved: ..\data\raw_images\special\(\(_90.png
# Saved: ..\data\raw_images\special\)\)_90.png
# Saved: ..\data\raw_images\special\dot\dot_90.png
# Saved: ..\data\raw_images\special\=\=_90.png
# Saved: ..\data\raw_images\special\slash\slash_90.png
# Saved: ..\data\raw_images\special\backslash\backslash_90.png
# Saved: ..\data\raw_images\special\pipe\pipe_90.png
# Saved: ..\data\raw_images\special\+\+_91.png
# Saved: ..\data\raw_images\special\-\-_91.png
# Saved: ..\data\raw_images\special\multiply\multiply_91.png
# Saved: ..\data\raw_images\special\(\(_91.png
# Saved: ..\data\raw_images\special\)\)_91.png
# Saved: ..\data\raw_images\special\dot\dot_91.png
# Saved: ..\data\raw_images\special\=\=_91.png
# Saved: ..\data\raw_images\special\slash\slash_91.png
# Saved: ..\data\raw_images\special\backslash\backslash_91.png
# Saved: ..\data\raw_images\special\pipe\pipe_91.png
# Saved: ..\data\raw_images\special\+\+_92.png
# Saved: ..\data\raw_images\special\-\-_92.png
# Saved: ..\data\raw_images\special\multiply\multiply_92.png
# Saved: ..\data\raw_images\special\(\(_92.png
# Saved: ..\data\raw_images\special\)\)_92.png
# Saved: ..\data\raw_images\special\dot\dot_92.png
# Saved: ..\data\raw_images\special\=\=_92.png
# Saved: ..\data\raw_images\special\slash\slash_92.png
# Saved: ..\data\raw_images\special\backslash\backslash_92.png
# Saved: ..\data\raw_images\special\pipe\pipe_92.png
# Saved: ..\data\raw_images\special\+\+_93.png
# Saved: ..\data\raw_images\special\-\-_93.png
# Saved: ..\data\raw_images\special\multiply\multiply_93.png
# Saved: ..\data\raw_images\special\(\(_93.png
# Saved: ..\data\raw_images\special\)\)_93.png
# Saved: ..\data\raw_images\special\dot\dot_93.png
# Saved: ..\data\raw_images\special\=\=_93.png
# Saved: ..\data\raw_images\special\slash\slash_93.png
# Saved: ..\data\raw_images\special\backslash\backslash_93.png
# Saved: ..\data\raw_images\special\pipe\pipe_93.png
# Saved: ..\data\raw_images\special\+\+_94.png
# Saved: ..\data\raw_images\special\-\-_94.png
# Saved: ..\data\raw_images\special\multiply\multiply_94.png
# Saved: ..\data\raw_images\special\(\(_94.png
# Saved: ..\data\raw_images\special\)\)_94.png
# Saved: ..\data\raw_images\special\dot\dot_94.png
# Saved: ..\data\raw_images\special\=\=_94.png
# Saved: ..\data\raw_images\special\slash\slash_94.png
# Saved: ..\data\raw_images\special\backslash\backslash_94.png
# Saved: ..\data\raw_images\special\pipe\pipe_94.png
# Saved: ..\data\raw_images\special\+\+_95.png
# Saved: ..\data\raw_images\special\-\-_95.png
# Saved: ..\data\raw_images\special\multiply\multiply_95.png
# Saved: ..\data\raw_images\special\(\(_95.png
# Saved: ..\data\raw_images\special\)\)_95.png
# Saved: ..\data\raw_images\special\dot\dot_95.png
# Saved: ..\data\raw_images\special\=\=_95.png
# Saved: ..\data\raw_images\special\slash\slash_95.png
# Saved: ..\data\raw_images\special\backslash\backslash_95.png
# Saved: ..\data\raw_images\special\pipe\pipe_95.png
# Saved: ..\data\raw_images\special\+\+_96.png
# Saved: ..\data\raw_images\special\-\-_96.png
# Saved: ..\data\raw_images\special\multiply\multiply_96.png
# Saved: ..\data\raw_images\special\(\(_96.png
# Saved: ..\data\raw_images\special\)\)_96.png
# Saved: ..\data\raw_images\special\dot\dot_96.png
# Saved: ..\data\raw_images\special\=\=_96.png
# Saved: ..\data\raw_images\special\slash\slash_96.png
# Saved: ..\data\raw_images\special\backslash\backslash_96.png
# Saved: ..\data\raw_images\special\pipe\pipe_96.png
# Saved: ..\data\raw_images\special\+\+_97.png
# Saved: ..\data\raw_images\special\-\-_97.png
# Saved: ..\data\raw_images\special\multiply\multiply_97.png
# Saved: ..\data\raw_images\special\(\(_97.png
# Saved: ..\data\raw_images\special\)\)_97.png
# ...
# Saved: ..\data\raw_images\special\=\=_302.png
# Saved: ..\data\raw_images\special\slash\slash_302.png
# Saved: ..\data\raw_images\special\backslash\backslash_302.png
# Saved: ..\data\raw_images\special\pipe\pipe_302.png
# Saved: ..\data\raw_images\special\+\+_303.png
# Saved: ..\data\raw_images\special\-\-_303.png
# Saved: ..\data\raw_images\special\multiply\multiply_303.png
# Saved: ..\data\raw_images\special\(\(_303.png
# Saved: ..\data\raw_images\special\)\)_303.png
# Saved: ..\data\raw_images\special\dot\dot_303.png
# Saved: ..\data\raw_images\special\=\=_303.png
# Saved: ..\data\raw_images\special\slash\slash_303.png
# Saved: ..\data\raw_images\special\backslash\backslash_303.png
# Saved: ..\data\raw_images\special\pipe\pipe_303.png
# Saved: ..\data\raw_images\special\+\+_304.png
# Saved: ..\data\raw_images\special\-\-_304.png
# Saved: ..\data\raw_images\special\multiply\multiply_304.png
# Saved: ..\data\raw_images\special\(\(_304.png
# Saved: ..\data\raw_images\special\)\)_304.png
# Saved: ..\data\raw_images\special\dot\dot_304.png
# Saved: ..\data\raw_images\special\=\=_304.png
# Saved: ..\data\raw_images\special\slash\slash_304.png
# Saved: ..\data\raw_images\special\backslash\backslash_304.png
# Saved: ..\data\raw_images\special\pipe\pipe_304.png
# Saved: ..\data\raw_images\special\+\+_305.png
# Saved: ..\data\raw_images\special\-\-_305.png
# Saved: ..\data\raw_images\special\multiply\multiply_305.png
# Saved: ..\data\raw_images\special\(\(_305.png
# Saved: ..\data\raw_images\special\)\)_305.png
# Saved: ..\data\raw_images\special\dot\dot_305.png
# Saved: ..\data\raw_images\special\=\=_305.png
# Saved: ..\data\raw_images\special\slash\slash_305.png
# Saved: ..\data\raw_images\special\backslash\backslash_305.png
# Saved: ..\data\raw_images\special\pipe\pipe_305.png
# Saved: ..\data\raw_images\special\+\+_306.png
# Saved: ..\data\raw_images\special\-\-_306.png
# Saved: ..\data\raw_images\special\multiply\multiply_306.png
# Saved: ..\data\raw_images\special\(\(_306.png
# Saved: ..\data\raw_images\special\)\)_306.png
# Saved: ..\data\raw_images\special\dot\dot_306.png
# Saved: ..\data\raw_images\special\=\=_306.png
# Saved: ..\data\raw_images\special\slash\slash_306.png
# Saved: ..\data\raw_images\special\backslash\backslash_306.png
# Saved: ..\data\raw_images\special\pipe\pipe_306.png
# Saved: ..\data\raw_images\special\+\+_307.png
# Saved: ..\data\raw_images\special\-\-_307.png
# Saved: ..\data\raw_images\special\multiply\multiply_307.png
# Saved: ..\data\raw_images\special\(\(_307.png
# Saved: ..\data\raw_images\special\)\)_307.png
# Saved: ..\data\raw_images\special\dot\dot_307.png
# Saved: ..\data\raw_images\special\=\=_307.png
# Saved: ..\data\raw_images\special\slash\slash_307.png
# Saved: ..\data\raw_images\special\backslash\backslash_307.png
# Saved: ..\data\raw_images\special\pipe\pipe_307.png
# Saved: ..\data\raw_images\special\+\+_308.png
# Saved: ..\data\raw_images\special\-\-_308.png
# Saved: ..\data\raw_images\special\multiply\multiply_308.png
# Saved: ..\data\raw_images\special\(\(_308.png
# Saved: ..\data\raw_images\special\)\)_308.png
# Saved: ..\data\raw_images\special\dot\dot_308.png
# Saved: ..\data\raw_images\special\=\=_308.png
# Saved: ..\data\raw_images\special\slash\slash_308.png
# Saved: ..\data\raw_images\special\backslash\backslash_308.png
# Saved: ..\data\raw_images\special\pipe\pipe_308.png
# Saved: ..\data\raw_images\special\+\+_309.png
# Saved: ..\data\raw_images\special\-\-_309.png
# Saved: ..\data\raw_images\special\multiply\multiply_309.png
# Saved: ..\data\raw_images\special\(\(_309.png
# Saved: ..\data\raw_images\special\)\)_309.png
# Saved: ..\data\raw_images\special\dot\dot_309.png
# Saved: ..\data\raw_images\special\=\=_309.png
# Saved: ..\data\raw_images\special\slash\slash_309.png
# Saved: ..\data\raw_images\special\backslash\backslash_309.png
# Saved: ..\data\raw_images\special\pipe\pipe_309.png
# Saved: ..\data\raw_images\special\+\+_310.png
# Saved: ..\data\raw_images\special\-\-_310.png
# Saved: ..\data\raw_images\special\multiply\multiply_310.png
# Saved: ..\data\raw_images\special\(\(_310.png
# Saved: ..\data\raw_images\special\)\)_310.png
# Saved: ..\data\raw_images\special\dot\dot_310.png
# Saved: ..\data\raw_images\special\=\=_310.png
# Saved: ..\data\raw_images\special\slash\slash_310.png
# Saved: ..\data\raw_images\special\backslash\backslash_310.png
# Saved: ..\data\raw_images\special\pipe\pipe_310.png
# Saved: ..\data\raw_images\special\+\+_311.png
# Saved: ..\data\raw_images\special\-\-_311.png
# Saved: ..\data\raw_images\special\multiply\multiply_311.png
# Saved: ..\data\raw_images\special\(\(_311.png
# Saved: ..\data\raw_images\special\)\)_311.png
# Saved: ..\data\raw_images\special\dot\dot_311.png
# Saved: ..\data\raw_images\special\=\=_311.png
# Saved: ..\data\raw_images\special\slash\slash_311.png
# Saved: ..\data\raw_images\special\backslash\backslash_311.png
# Saved: ..\data\raw_images\special\pipe\pipe_311.png
# Saved: ..\data\raw_images\special\+\+_312.png
# Saved: ..\data\raw_images\special\-\-_312.png
# Saved: ..\data\raw_images\special\multiply\multiply_312.png
# Saved: ..\data\raw_images\special\(\(_312.png
# Saved: ..\data\raw_images\special\)\)_312.png
# Saved: ..\data\raw_images\special\dot\dot_312.png
# Saved: ..\data\raw_images\special\=\=_312.png
# Saved: ..\data\raw_images\special\slash\slash_312.png
# Saved: ..\data\raw_images\special\backslash\backslash_312.png
# Saved: ..\data\raw_images\special\pipe\pipe_312.png
# Saved: ..\data\raw_images\special\+\+_313.png
# Saved: ..\data\raw_images\special\-\-_313.png
# Saved: ..\data\raw_images\special\multiply\multiply_313.png
# Saved: ..\data\raw_images\special\(\(_313.png
# Saved: ..\data\raw_images\special\)\)_313.png
# Saved: ..\data\raw_images\special\dot\dot_313.png
# Saved: ..\data\raw_images\special\=\=_313.png
# Saved: ..\data\raw_images\special\slash\slash_313.png
# Saved: ..\data\raw_images\special\backslash\backslash_313.png
# Saved: ..\data\raw_images\special\pipe\pipe_313.png
# Saved: ..\data\raw_images\special\+\+_314.png
# Saved: ..\data\raw_images\special\-\-_314.png
# Saved: ..\data\raw_images\special\multiply\multiply_314.png
# Saved: ..\data\raw_images\special\(\(_314.png
# Saved: ..\data\raw_images\special\)\)_314.png
# Saved: ..\data\raw_images\special\dot\dot_314.png
# Saved: ..\data\raw_images\special\=\=_314.png
# Saved: ..\data\raw_images\special\slash\slash_314.png
# Saved: ..\data\raw_images\special\backslash\backslash_314.png
# Saved: ..\data\raw_images\special\pipe\pipe_314.png
# Saved: ..\data\raw_images\special\+\+_315.png
# Saved: ..\data\raw_images\special\-\-_315.png
# Saved: ..\data\raw_images\special\multiply\multiply_315.png
# Saved: ..\data\raw_images\special\(\(_315.png
# Saved: ..\data\raw_images\special\)\)_315.png
# Saved: ..\data\raw_images\special\dot\dot_315.png
# Saved: ..\data\raw_images\special\=\=_315.png
# Saved: ..\data\raw_images\special\slash\slash_315.png
# Saved: ..\data\raw_images\special\backslash\backslash_315.png
# Saved: ..\data\raw_images\special\pipe\pipe_315.png
# Saved: ..\data\raw_images\special\+\+_316.png
# Saved: ..\data\raw_images\special\-\-_316.png
# Saved: ..\data\raw_images\special\multiply\multiply_316.png
# Saved: ..\data\raw_images\special\(\(_316.png
# Saved: ..\data\raw_images\special\)\)_316.png
# Saved: ..\data\raw_images\special\dot\dot_316.png
# Saved: ..\data\raw_images\special\=\=_316.png
# Saved: ..\data\raw_images\special\slash\slash_316.png
# Saved: ..\data\raw_images\special\backslash\backslash_316.png
# Saved: ..\data\raw_images\special\pipe\pipe_316.png
# Saved: ..\data\raw_images\special\+\+_317.png
# Saved: ..\data\raw_images\special\-\-_317.png
# Saved: ..\data\raw_images\special\multiply\multiply_317.png
# Saved: ..\data\raw_images\special\(\(_317.png
# Saved: ..\data\raw_images\special\)\)_317.png
# Saved: ..\data\raw_images\special\dot\dot_317.png
# Saved: ..\data\raw_images\special\=\=_317.png
# Saved: ..\data\raw_images\special\slash\slash_317.png
# Saved: ..\data\raw_images\special\backslash\backslash_317.png
# Saved: ..\data\raw_images\special\pipe\pipe_317.png
# Saved: ..\data\raw_images\special\+\+_318.png
# Saved: ..\data\raw_images\special\-\-_318.png
# Saved: ..\data\raw_images\special\multiply\multiply_318.png
# Saved: ..\data\raw_images\special\(\(_318.png
# Saved: ..\data\raw_images\special\)\)_318.png
# Saved: ..\data\raw_images\special\dot\dot_318.png
# Saved: ..\data\raw_images\special\=\=_318.png
# Saved: ..\data\raw_images\special\slash\slash_318.png
# Saved: ..\data\raw_images\special\backslash\backslash_318.png
# Saved: ..\data\raw_images\special\pipe\pipe_318.png
# Saved: ..\data\raw_images\special\+\+_319.png
# Saved: ..\data\raw_images\special\-\-_319.png
# Saved: ..\data\raw_images\special\multiply\multiply_319.png
# Saved: ..\data\raw_images\special\(\(_319.png
# Saved: ..\data\raw_images\special\)\)_319.png
# Saved: ..\data\raw_images\special\dot\dot_319.png
# Saved: ..\data\raw_images\special\=\=_319.png
# Saved: ..\data\raw_images\special\slash\slash_319.png
# Saved: ..\data\raw_images\special\backslash\backslash_319.png
# Saved: ..\data\raw_images\special\pipe\pipe_319.png
# Saved: ..\data\raw_images\special\+\+_320.png
# Saved: ..\data\raw_images\special\-\-_320.png
# Saved: ..\data\raw_images\special\multiply\multiply_320.png
# Saved: ..\data\raw_images\special\(\(_320.png
# Saved: ..\data\raw_images\special\)\)_320.png
# Saved: ..\data\raw_images\special\dot\dot_320.png
# Saved: ..\data\raw_images\special\=\=_320.png
# Saved: ..\data\raw_images\special\slash\slash_320.png
# Saved: ..\data\raw_images\special\backslash\backslash_320.png
# Saved: ..\data\raw_images\special\pipe\pipe_320.png
# Saved: ..\data\raw_images\special\+\+_321.png
# Saved: ..\data\raw_images\special\-\-_321.png
# Saved: ..\data\raw_images\special\multiply\multiply_321.png
# Saved: ..\data\raw_images\special\(\(_321.png
# Saved: ..\data\raw_images\special\)\)_321.png
# Saved: ..\data\raw_images\special\dot\dot_321.png
# Saved: ..\data\raw_images\special\=\=_321.png
# Saved: ..\data\raw_images\special\slash\slash_321.png
# Saved: ..\data\raw_images\special\backslash\backslash_321.png
# Saved: ..\data\raw_images\special\pipe\pipe_321.png
# Saved: ..\data\raw_images\special\+\+_322.png
# Saved: ..\data\raw_images\special\-\-_322.png
# Saved: ..\data\raw_images\special\multiply\multiply_322.png
# Saved: ..\data\raw_images\special\(\(_322.png
# Saved: ..\data\raw_images\special\)\)_322.png
# Saved: ..\data\raw_images\special\dot\dot_322.png
# Saved: ..\data\raw_images\special\=\=_322.png
# Saved: ..\data\raw_images\special\slash\slash_322.png
# Saved: ..\data\raw_images\special\backslash\backslash_322.png
# Saved: ..\data\raw_images\special\pipe\pipe_322.png
# Saved: ..\data\raw_images\special\+\+_323.png
# Saved: ..\data\raw_images\special\-\-_323.png
# Saved: ..\data\raw_images\special\multiply\multiply_323.png
# Saved: ..\data\raw_images\special\(\(_323.png
# Saved: ..\data\raw_images\special\)\)_323.png
# Saved: ..\data\raw_images\special\dot\dot_323.png
# Saved: ..\data\raw_images\special\=\=_323.png
# Saved: ..\data\raw_images\special\slash\slash_323.png
# Saved: ..\data\raw_images\special\backslash\backslash_323.png
# Saved: ..\data\raw_images\special\pipe\pipe_323.png
# Saved: ..\data\raw_images\special\+\+_324.png
# Saved: ..\data\raw_images\special\-\-_324.png
# Saved: ..\data\raw_images\special\multiply\multiply_324.png
# Saved: ..\data\raw_images\special\(\(_324.png
# Saved: ..\data\raw_images\special\)\)_324.png
# Saved: ..\data\raw_images\special\dot\dot_324.png
# Saved: ..\data\raw_images\special\=\=_324.png
# Saved: ..\data\raw_images\special\slash\slash_324.png
# Saved: ..\data\raw_images\special\backslash\backslash_324.png
# Saved: ..\data\raw_images\special\pipe\pipe_324.png
# Saved: ..\data\raw_images\special\+\+_325.png
# Saved: ..\data\raw_images\special\-\-_325.png
# Saved: ..\data\raw_images\special\multiply\multiply_325.png
# Saved: ..\data\raw_images\special\(\(_325.png
# Saved: ..\data\raw_images\special\)\)_325.png
# Saved: ..\data\raw_images\special\dot\dot_325.png
# Saved: ..\data\raw_images\special\=\=_325.png
# Saved: ..\data\raw_images\special\slash\slash_325.png
# Saved: ..\data\raw_images\special\backslash\backslash_325.png
# Saved: ..\data\raw_images\special\pipe\pipe_325.png
# Saved: ..\data\raw_images\special\+\+_326.png
# Saved: ..\data\raw_images\special\-\-_326.png
# Saved: ..\data\raw_images\special\multiply\multiply_326.png
# Saved: ..\data\raw_images\special\(\(_326.png
# Saved: ..\data\raw_images\special\)\)_326.png
# Saved: ..\data\raw_images\special\dot\dot_326.png
# Saved: ..\data\raw_images\special\=\=_326.png
# Saved: ..\data\raw_images\special\slash\slash_326.png
# Saved: ..\data\raw_images\special\backslash\backslash_326.png
# Saved: ..\data\raw_images\special\pipe\pipe_326.png
# Saved: ..\data\raw_images\special\+\+_327.png
# Saved: ..\data\raw_images\special\-\-_327.png
# Saved: ..\data\raw_images\special\multiply\multiply_327.png
# Saved: ..\data\raw_images\special\(\(_327.png
# Saved: ..\data\raw_images\special\)\)_327.png
# Saved: ..\data\raw_images\special\dot\dot_327.png
# Saved: ..\data\raw_images\special\=\=_327.png
# Saved: ..\data\raw_images\special\slash\slash_327.png
# Saved: ..\data\raw_images\special\backslash\backslash_327.png
# Saved: ..\data\raw_images\special\pipe\pipe_327.png
# Saved: ..\data\raw_images\special\+\+_328.png
# Saved: ..\data\raw_images\special\-\-_328.png
# Saved: ..\data\raw_images\special\multiply\multiply_328.png
# Saved: ..\data\raw_images\special\(\(_328.png
# Saved: ..\data\raw_images\special\)\)_328.png
# Saved: ..\data\raw_images\special\dot\dot_328.png
# Saved: ..\data\raw_images\special\=\=_328.png
# Saved: ..\data\raw_images\special\slash\slash_328.png
# Saved: ..\data\raw_images\special\backslash\backslash_328.png
# Saved: ..\data\raw_images\special\pipe\pipe_328.png
# Saved: ..\data\raw_images\special\+\+_329.png
# Saved: ..\data\raw_images\special\-\-_329.png
# Saved: ..\data\raw_images\special\multiply\multiply_329.png
# Saved: ..\data\raw_images\special\(\(_329.png
# Saved: ..\data\raw_images\special\)\)_329.png
# Saved: ..\data\raw_images\special\dot\dot_329.png
# Saved: ..\data\raw_images\special\=\=_329.png
# Saved: ..\data\raw_images\special\slash\slash_329.png
# Saved: ..\data\raw_images\special\backslash\backslash_329.png
# Saved: ..\data\raw_images\special\pipe\pipe_329.png
# Saved: ..\data\raw_images\special\+\+_330.png
# Saved: ..\data\raw_images\special\-\-_330.png
# Saved: ..\data\raw_images\special\multiply\multiply_330.png
# Saved: ..\data\raw_images\special\(\(_330.png
# Saved: ..\data\raw_images\special\)\)_330.png
# Saved: ..\data\raw_images\special\dot\dot_330.png
# Saved: ..\data\raw_images\special\=\=_330.png
# Saved: ..\data\raw_images\special\slash\slash_330.png
# Saved: ..\data\raw_images\special\backslash\backslash_330.png
# Saved: ..\data\raw_images\special\pipe\pipe_330.png
# Saved: ..\data\raw_images\special\+\+_331.png
# Saved: ..\data\raw_images\special\-\-_331.png
# Saved: ..\data\raw_images\special\multiply\multiply_331.png
# Saved: ..\data\raw_images\special\(\(_331.png
# Saved: ..\data\raw_images\special\)\)_331.png
# Saved: ..\data\raw_images\special\dot\dot_331.png
# Saved: ..\data\raw_images\special\=\=_331.png
# Saved: ..\data\raw_images\special\slash\slash_331.png
# Saved: ..\data\raw_images\special\backslash\backslash_331.png
# Saved: ..\data\raw_images\special\pipe\pipe_331.png
# Saved: ..\data\raw_images\special\+\+_332.png
# Saved: ..\data\raw_images\special\-\-_332.png
# Saved: ..\data\raw_images\special\multiply\multiply_332.png
# Saved: ..\data\raw_images\special\(\(_332.png
# Saved: ..\data\raw_images\special\)\)_332.png
# Saved: ..\data\raw_images\special\dot\dot_332.png
# Saved: ..\data\raw_images\special\=\=_332.png
# Saved: ..\data\raw_images\special\slash\slash_332.png
# Saved: ..\data\raw_images\special\backslash\backslash_332.png
# Saved: ..\data\raw_images\special\pipe\pipe_332.png
# Saved: ..\data\raw_images\special\+\+_333.png
# Saved: ..\data\raw_images\special\-\-_333.png
# Saved: ..\data\raw_images\special\multiply\multiply_333.png
# Saved: ..\data\raw_images\special\(\(_333.png
# Saved: ..\data\raw_images\special\)\)_333.png
# Saved: ..\data\raw_images\special\dot\dot_333.png
# Saved: ..\data\raw_images\special\=\=_333.png
# Saved: ..\data\raw_images\special\slash\slash_333.png
# Saved: ..\data\raw_images\special\backslash\backslash_333.png
# Saved: ..\data\raw_images\special\pipe\pipe_333.png
