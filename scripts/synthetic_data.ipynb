# %%
from PIL import Image, ImageDraw, ImageFont
from pathlib import Path

# %% [markdown]
# ## English Uppercase

# %% [markdown]
# ### Classic method

# %%
# ระบุโฟลเดอร์ที่ต้องการอ่านไฟล์ทั้งหมด
output_folder = Path("dataset/eng_uppercase")
folder_path = Path("font/GoogleFont")
font_number = 1

# อ่านเฉพาะไฟล์ .ttf ในโฟลเดอร์และโฟลเดอร์ย่อย
for font_file in folder_path.rglob("*.ttf"):  # ลูปภายในโฟลเดอร์ font
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':  # ตรวจสอบเฉพาะไฟล์ฟอนต์
            font = ImageFont.truetype(str(font_file), 28)  # โหลดฟอนต์
            for char in "ABCDEFGHIJKLMNOPQRSTUVWXYZ":
                # สร้างโฟลเดอร์สำหรับตัวอักษร
                char_folder = output_folder / char
                char_folder.mkdir(parents=True, exist_ok=True)  # ถ้าโฟลเดอร์มีอยู่แล้ว จะไม่เกิดข้อผิดพลาด

                img = Image.new("RGB", (32, 32), "white")
                draw = ImageDraw.Draw(img)

                # คำนวณขนาดของตัวอักษรด้วย font.getbbox()
                # (left, top, right, bottom)
                bbox = font.getbbox(char)
                text_width = bbox[2] - bbox[0]
                text_height = bbox[3] - bbox[1]

                # คำนวณตำแหน่งตรงกลางของภาพ
                x = (img.width - text_width) / 2
                #y = (text_height - img.height) / 4
                #y = (img.height - text_height) / 2
    
                # วาดตัวอักษรตรงกลาง
                draw.text((x, -5), char, font=font, fill="black")
                img.save(char_folder / f"{char}_{font_number}.png")  # บันทึกภาพ
                print(f"Saved: {char_folder / f'{char}_{font_number}.png'}")
            font_number+=1

# %% [markdown]
# ### Padding method

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# กำหนดโฟลเดอร์
output_folder = Path("../data/raw_images/eng_uppercase")
folder_path = Path("../font/GoogleFont")

if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':
        try:
            font = ImageFont.truetype(str(font_file), 28)  # โหลดฟอนต์
        except Exception as e:
            print(f"Skipping font {font_file}: {e}")
            continue

        for char in "ABCDEFGHIJKLMNOPQRSTUVWXYZ":
            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / char
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y
            y_offset = ascent - bbox[3] + 1

            if(char == "Q"):
                y_offset+=1
                if(171 <= font_number <= 207):
                    y_offset+=3
                elif(217 <= font_number <= 253):
                    y_offset+=4
                elif(294 <= font_number <= 311):
                    y_offset+=3

            if(char == "J"):
                y_offset+=1
                if(171 <= font_number <= 207):
                    y_offset+=3
                elif(217 <= font_number <= 253):
                    y_offset+=4
                elif(294 <= font_number <= 311):
                    y_offset+=3
                    
            draw.text((0, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            output_path = char_folder / f"{char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")

# %% [markdown]
# ### Padding method with new font size

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# กำหนดโฟลเดอร์
output_folder = Path("../data/raw_images/eng_uppercase")
folder_path = Path("../font/GoogleFont")

if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':

        for char in "ABCDEFGHIJKLMNOPQRSTUVWXYZ":
            try:
                if(char == "Q"):
                    font = ImageFont.truetype(str(font_file), 30)
                if(char == "M" or char == "W"):
                    font = ImageFont.truetype(str(font_file), 30)
                else:
                    font = ImageFont.truetype(str(font_file), 36)
            except Exception as e:
                print(f"Skipping font {font_file}: {e}")
                continue

            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / f"{char}_U"
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y
            y_offset = ascent - bbox[3] + 1

            if(char == "J"):
                y_offset+=2
                if(1 <= font_number <= 14):
                    y_offset-=2
                elif(15 <= font_number <= 26):
                    y_offset-=2
                elif(27 <= font_number <= 49):
                    y_offset-=3
                elif(50 <= font_number <= 63):
                    y_offset+=0
                elif(64 <= font_number <= 80):
                    y_offset-=4
                elif(81 <= font_number <= 110):
                    y_offset-=3
                elif(111 <= font_number <= 122):
                    y_offset-=4
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(135 <= font_number <= 140):
                    y_offset-=1
                elif(141 <= font_number <= 158):
                    y_offset-=4
                elif(159 <= font_number <= 170):
                    y_offset-=6
                elif(171 <= font_number <= 207):
                    y_offset+=1
                elif(208 <= font_number <= 216):
                    y_offset-=4
                elif(217 <= font_number <= 253):
                    y_offset+=3
                elif(278 <= font_number <= 293):
                    y_offset-=4
                elif(294 <= font_number <= 315):
                    y_offset+=1
                elif(322 <= font_number <= 333):
                    y_offset-=2
            elif(char == "Q"):
                y_offset+=4
                if(1 <= font_number <= 14):
                    y_offset-=2
                elif(15 <= font_number <= 26):
                    y_offset-=2
                elif(27 <= font_number <= 49):
                    y_offset-=3
                elif(50 <= font_number <= 63):
                    y_offset+=0
                elif(64 <= font_number <= 80):
                    y_offset-=4
                elif(81 <= font_number <= 110):
                    y_offset-=3
                elif(111 <= font_number <= 122):
                    y_offset-=4
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(135 <= font_number <= 140):
                    y_offset-=1
                elif(141 <= font_number <= 158):
                    y_offset-=4
                elif(159 <= font_number <= 170):
                    y_offset-=6
                elif(171 <= font_number <= 207):
                    y_offset+=1
                elif(208 <= font_number <= 216):
                    y_offset-=4
                elif(217 <= font_number <= 253):
                    y_offset+=3
                elif(260 <= font_number <= 277):
                    y_offset-=4
                elif(278 <= font_number <= 293):
                    y_offset-=4
                elif(294 <= font_number <= 315):
                    y_offset+=1
                elif(322 <= font_number <= 333):
                    y_offset-=2
            else:
                if(1 <= font_number <= 14):
                    y_offset-=2
                elif(15 <= font_number <= 26):
                    y_offset-=2
                elif(27 <= font_number <= 49):
                    y_offset-=1
                elif(50 <= font_number <= 63):
                    y_offset+=1
                elif(64 <= font_number <= 80):
                    y_offset-=2
                elif(81 <= font_number <= 110):
                    y_offset-=1
                elif(111 <= font_number <= 122):
                    y_offset-=3
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(135 <= font_number <= 140):
                    y_offset-=1
                elif(141 <= font_number <= 158):
                    y_offset-=2
                elif(159 <= font_number <= 170):
                    y_offset-=4
                elif(171 <= font_number <= 207):
                    y_offset+=1
                elif(208 <= font_number <= 216):
                    y_offset-=4
                elif(217 <= font_number <= 253):
                    y_offset+=3
                elif(278 <= font_number <= 293):
                    y_offset-=4
                elif(294 <= font_number <= 315):
                    y_offset+=0
                elif(322 <= font_number <= 333):
                    y_offset-=1
                    
            draw.text((0, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            output_path = char_folder / f"{char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")
# Out:
# Saved: ..\data\raw_images\eng_uppercase\A_U\A_1.png
# Saved: ..\data\raw_images\eng_uppercase\B_U\B_1.png
# Saved: ..\data\raw_images\eng_uppercase\C_U\C_1.png
# Saved: ..\data\raw_images\eng_uppercase\D_U\D_1.png
# Saved: ..\data\raw_images\eng_uppercase\E_U\E_1.png
# Saved: ..\data\raw_images\eng_uppercase\F_U\F_1.png
# Saved: ..\data\raw_images\eng_uppercase\G_U\G_1.png
# Saved: ..\data\raw_images\eng_uppercase\H_U\H_1.png
# Saved: ..\data\raw_images\eng_uppercase\I_U\I_1.png
# Saved: ..\data\raw_images\eng_uppercase\J_U\J_1.png
# Saved: ..\data\raw_images\eng_uppercase\K_U\K_1.png
# Saved: ..\data\raw_images\eng_uppercase\L_U\L_1.png
# Saved: ..\data\raw_images\eng_uppercase\M_U\M_1.png
# Saved: ..\data\raw_images\eng_uppercase\N_U\N_1.png
# Saved: ..\data\raw_images\eng_uppercase\O_U\O_1.png
# Saved: ..\data\raw_images\eng_uppercase\P_U\P_1.png
# Saved: ..\data\raw_images\eng_uppercase\Q_U\Q_1.png
# Saved: ..\data\raw_images\eng_uppercase\R_U\R_1.png
# Saved: ..\data\raw_images\eng_uppercase\S_U\S_1.png
# Saved: ..\data\raw_images\eng_uppercase\T_U\T_1.png
# Saved: ..\data\raw_images\eng_uppercase\U_U\U_1.png
# Saved: ..\data\raw_images\eng_uppercase\V_U\V_1.png
# Saved: ..\data\raw_images\eng_uppercase\W_U\W_1.png
# Saved: ..\data\raw_images\eng_uppercase\X_U\X_1.png
# Saved: ..\data\raw_images\eng_uppercase\Y_U\Y_1.png
# Saved: ..\data\raw_images\eng_uppercase\Z_U\Z_1.png
# Saved: ..\data\raw_images\eng_uppercase\A_U\A_2.png
# Saved: ..\data\raw_images\eng_uppercase\B_U\B_2.png
# Saved: ..\data\raw_images\eng_uppercase\C_U\C_2.png
# Saved: ..\data\raw_images\eng_uppercase\D_U\D_2.png
# Saved: ..\data\raw_images\eng_uppercase\E_U\E_2.png
# Saved: ..\data\raw_images\eng_uppercase\F_U\F_2.png
# Saved: ..\data\raw_images\eng_uppercase\G_U\G_2.png
# Saved: ..\data\raw_images\eng_uppercase\H_U\H_2.png
# Saved: ..\data\raw_images\eng_uppercase\I_U\I_2.png
# Saved: ..\data\raw_images\eng_uppercase\J_U\J_2.png
# Saved: ..\data\raw_images\eng_uppercase\K_U\K_2.png
# Saved: ..\data\raw_images\eng_uppercase\L_U\L_2.png
# Saved: ..\data\raw_images\eng_uppercase\M_U\M_2.png
# Saved: ..\data\raw_images\eng_uppercase\N_U\N_2.png
# Saved: ..\data\raw_images\eng_uppercase\O_U\O_2.png
# Saved: ..\data\raw_images\eng_uppercase\P_U\P_2.png
# Saved: ..\data\raw_images\eng_uppercase\Q_U\Q_2.png
# Saved: ..\data\raw_images\eng_uppercase\R_U\R_2.png
# Saved: ..\data\raw_images\eng_uppercase\S_U\S_2.png
# Saved: ..\data\raw_images\eng_uppercase\T_U\T_2.png
# Saved: ..\data\raw_images\eng_uppercase\U_U\U_2.png
# Saved: ..\data\raw_images\eng_uppercase\V_U\V_2.png
# Saved: ..\data\raw_images\eng_uppercase\W_U\W_2.png
# Saved: ..\data\raw_images\eng_uppercase\X_U\X_2.png
# Saved: ..\data\raw_images\eng_uppercase\Y_U\Y_2.png
# Saved: ..\data\raw_images\eng_uppercase\Z_U\Z_2.png
# Saved: ..\data\raw_images\eng_uppercase\A_U\A_3.png
# Saved: ..\data\raw_images\eng_uppercase\B_U\B_3.png
# Saved: ..\data\raw_images\eng_uppercase\C_U\C_3.png
# Saved: ..\data\raw_images\eng_uppercase\D_U\D_3.png
# Saved: ..\data\raw_images\eng_uppercase\E_U\E_3.png
# Saved: ..\data\raw_images\eng_uppercase\F_U\F_3.png
# Saved: ..\data\raw_images\eng_uppercase\G_U\G_3.png
# Saved: ..\data\raw_images\eng_uppercase\H_U\H_3.png
# Saved: ..\data\raw_images\eng_uppercase\I_U\I_3.png
# Saved: ..\data\raw_images\eng_uppercase\J_U\J_3.png
# Saved: ..\data\raw_images\eng_uppercase\K_U\K_3.png
# Saved: ..\data\raw_images\eng_uppercase\L_U\L_3.png
# Saved: ..\data\raw_images\eng_uppercase\M_U\M_3.png
# Saved: ..\data\raw_images\eng_uppercase\N_U\N_3.png
# Saved: ..\data\raw_images\eng_uppercase\O_U\O_3.png
# Saved: ..\data\raw_images\eng_uppercase\P_U\P_3.png
# Saved: ..\data\raw_images\eng_uppercase\Q_U\Q_3.png
# Saved: ..\data\raw_images\eng_uppercase\R_U\R_3.png
# Saved: ..\data\raw_images\eng_uppercase\S_U\S_3.png
# Saved: ..\data\raw_images\eng_uppercase\T_U\T_3.png
# Saved: ..\data\raw_images\eng_uppercase\U_U\U_3.png
# Saved: ..\data\raw_images\eng_uppercase\V_U\V_3.png
# Saved: ..\data\raw_images\eng_uppercase\W_U\W_3.png
# Saved: ..\data\raw_images\eng_uppercase\X_U\X_3.png
# Saved: ..\data\raw_images\eng_uppercase\Y_U\Y_3.png
# Saved: ..\data\raw_images\eng_uppercase\Z_U\Z_3.png
# Saved: ..\data\raw_images\eng_uppercase\A_U\A_4.png
# Saved: ..\data\raw_images\eng_uppercase\B_U\B_4.png
# Saved: ..\data\raw_images\eng_uppercase\C_U\C_4.png
# Saved: ..\data\raw_images\eng_uppercase\D_U\D_4.png
# Saved: ..\data\raw_images\eng_uppercase\E_U\E_4.png
# Saved: ..\data\raw_images\eng_uppercase\F_U\F_4.png
# Saved: ..\data\raw_images\eng_uppercase\G_U\G_4.png
# Saved: ..\data\raw_images\eng_uppercase\H_U\H_4.png
# Saved: ..\data\raw_images\eng_uppercase\I_U\I_4.png
# Saved: ..\data\raw_images\eng_uppercase\J_U\J_4.png
# Saved: ..\data\raw_images\eng_uppercase\K_U\K_4.png
# Saved: ..\data\raw_images\eng_uppercase\L_U\L_4.png
# Saved: ..\data\raw_images\eng_uppercase\M_U\M_4.png
# Saved: ..\data\raw_images\eng_uppercase\N_U\N_4.png
# Saved: ..\data\raw_images\eng_uppercase\O_U\O_4.png
# Saved: ..\data\raw_images\eng_uppercase\P_U\P_4.png
# Saved: ..\data\raw_images\eng_uppercase\Q_U\Q_4.png
# Saved: ..\data\raw_images\eng_uppercase\R_U\R_4.png
# Saved: ..\data\raw_images\eng_uppercase\S_U\S_4.png
# Saved: ..\data\raw_images\eng_uppercase\T_U\T_4.png
# Saved: ..\data\raw_images\eng_uppercase\U_U\U_4.png
# Saved: ..\data\raw_images\eng_uppercase\V_U\V_4.png
# Saved: ..\data\raw_images\eng_uppercase\W_U\W_4.png
# Saved: ..\data\raw_images\eng_uppercase\X_U\X_4.png
# Saved: ..\data\raw_images\eng_uppercase\Y_U\Y_4.png
# Saved: ..\data\raw_images\eng_uppercase\Z_U\Z_4.png
# Saved: ..\data\raw_images\eng_uppercase\A_U\A_5.png
# Saved: ..\data\raw_images\eng_uppercase\B_U\B_5.png
# Saved: ..\data\raw_images\eng_uppercase\C_U\C_5.png
# Saved: ..\data\raw_images\eng_uppercase\D_U\D_5.png
# Saved: ..\data\raw_images\eng_uppercase\E_U\E_5.png
# Saved: ..\data\raw_images\eng_uppercase\F_U\F_5.png
# Saved: ..\data\raw_images\eng_uppercase\G_U\G_5.png
# Saved: ..\data\raw_images\eng_uppercase\H_U\H_5.png
# Saved: ..\data\raw_images\eng_uppercase\I_U\I_5.png
# Saved: ..\data\raw_images\eng_uppercase\J_U\J_5.png
# Saved: ..\data\raw_images\eng_uppercase\K_U\K_5.png
# Saved: ..\data\raw_images\eng_uppercase\L_U\L_5.png
# Saved: ..\data\raw_images\eng_uppercase\M_U\M_5.png
# Saved: ..\data\raw_images\eng_uppercase\N_U\N_5.png
# Saved: ..\data\raw_images\eng_uppercase\O_U\O_5.png
# Saved: ..\data\raw_images\eng_uppercase\P_U\P_5.png
# Saved: ..\data\raw_images\eng_uppercase\Q_U\Q_5.png
# Saved: ..\data\raw_images\eng_uppercase\R_U\R_5.png
# Saved: ..\data\raw_images\eng_uppercase\S_U\S_5.png
# Saved: ..\data\raw_images\eng_uppercase\T_U\T_5.png
# Saved: ..\data\raw_images\eng_uppercase\U_U\U_5.png
# Saved: ..\data\raw_images\eng_uppercase\V_U\V_5.png
# Saved: ..\data\raw_images\eng_uppercase\W_U\W_5.png
# Saved: ..\data\raw_images\eng_uppercase\X_U\X_5.png
# Saved: ..\data\raw_images\eng_uppercase\Y_U\Y_5.png
# Saved: ..\data\raw_images\eng_uppercase\Z_U\Z_5.png
# Saved: ..\data\raw_images\eng_uppercase\A_U\A_6.png
# Saved: ..\data\raw_images\eng_uppercase\B_U\B_6.png
# Saved: ..\data\raw_images\eng_uppercase\C_U\C_6.png
# Saved: ..\data\raw_images\eng_uppercase\D_U\D_6.png
# Saved: ..\data\raw_images\eng_uppercase\E_U\E_6.png
# Saved: ..\data\raw_images\eng_uppercase\F_U\F_6.png
# Saved: ..\data\raw_images\eng_uppercase\G_U\G_6.png
# Saved: ..\data\raw_images\eng_uppercase\H_U\H_6.png
# Saved: ..\data\raw_images\eng_uppercase\I_U\I_6.png
# Saved: ..\data\raw_images\eng_uppercase\J_U\J_6.png
# Saved: ..\data\raw_images\eng_uppercase\K_U\K_6.png
# Saved: ..\data\raw_images\eng_uppercase\L_U\L_6.png
# Saved: ..\data\raw_images\eng_uppercase\M_U\M_6.png
# Saved: ..\data\raw_images\eng_uppercase\N_U\N_6.png
# Saved: ..\data\raw_images\eng_uppercase\O_U\O_6.png
# Saved: ..\data\raw_images\eng_uppercase\P_U\P_6.png
# Saved: ..\data\raw_images\eng_uppercase\Q_U\Q_6.png
# Saved: ..\data\raw_images\eng_uppercase\R_U\R_6.png
# Saved: ..\data\raw_images\eng_uppercase\S_U\S_6.png
# Saved: ..\data\raw_images\eng_uppercase\T_U\T_6.png
# Saved: ..\data\raw_images\eng_uppercase\U_U\U_6.png
# Saved: ..\data\raw_images\eng_uppercase\V_U\V_6.png
# Saved: ..\data\raw_images\eng_uppercase\W_U\W_6.png
# Saved: ..\data\raw_images\eng_uppercase\X_U\X_6.png
# Saved: ..\data\raw_images\eng_uppercase\Y_U\Y_6.png
# Saved: ..\data\raw_images\eng_uppercase\Z_U\Z_6.png
# Saved: ..\data\raw_images\eng_uppercase\A_U\A_7.png
# Saved: ..\data\raw_images\eng_uppercase\B_U\B_7.png
# Saved: ..\data\raw_images\eng_uppercase\C_U\C_7.png
# Saved: ..\data\raw_images\eng_uppercase\D_U\D_7.png
# Saved: ..\data\raw_images\eng_uppercase\E_U\E_7.png
# Saved: ..\data\raw_images\eng_uppercase\F_U\F_7.png
# Saved: ..\data\raw_images\eng_uppercase\G_U\G_7.png
# Saved: ..\data\raw_images\eng_uppercase\H_U\H_7.png
# Saved: ..\data\raw_images\eng_uppercase\I_U\I_7.png
# Saved: ..\data\raw_images\eng_uppercase\J_U\J_7.png
# Saved: ..\data\raw_images\eng_uppercase\K_U\K_7.png
# Saved: ..\data\raw_images\eng_uppercase\L_U\L_7.png
# Saved: ..\data\raw_images\eng_uppercase\M_U\M
# Saved: ..\data\raw_images\eng_uppercase\O_U\O_333.png
# Saved: ..\data\raw_images\eng_uppercase\P_U\P_333.png
# Saved: ..\data\raw_images\eng_uppercase\Q_U\Q_333.png
# Saved: ..\data\raw_images\eng_uppercase\R_U\R_333.png
# Saved: ..\data\raw_images\eng_uppercase\S_U\S_333.png
# Saved: ..\data\raw_images\eng_uppercase\T_U\T_333.png
# Saved: ..\data\raw_images\eng_uppercase\U_U\U_333.png
# Saved: ..\data\raw_images\eng_uppercase\V_U\V_333.png
# Saved: ..\data\raw_images\eng_uppercase\W_U\W_333.png
# Saved: ..\data\raw_images\eng_uppercase\X_U\X_333.png
# Saved: ..\data\raw_images\eng_uppercase\Y_U\Y_333.png
# Saved: ..\data\raw_images\eng_uppercase\Z_U\Z_333.png

# %% [markdown]
# ## English Lowercase

# %% [markdown]
# ### Classic method

# %%
# ระบุโฟลเดอร์ที่ต้องการอ่านไฟล์ทั้งหมด
output_folder = Path("dataset/eng_lowercase")
folder_path = Path("font/GoogleFont")
font_number = 1

# อ่านเฉพาะไฟล์ .ttf ในโฟลเดอร์และโฟลเดอร์ย่อย
for font_file in folder_path.rglob("*.ttf"):  # ลูปภายในโฟลเดอร์ font
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':  # ตรวจสอบเฉพาะไฟล์ฟอนต์
            font = ImageFont.truetype(str(font_file), 28)  # โหลดฟอนต์
            for char in "abcdefghijklmnopqrstuvwxyz":
                # สร้างโฟลเดอร์สำหรับตัวอักษร
                char_folder = output_folder / char
                char_folder.mkdir(parents=True, exist_ok=True)  # ถ้าโฟลเดอร์มีอยู่แล้ว จะไม่เกิดข้อผิดพลาด

                img = Image.new("RGB", (32, 32), "white")
                draw = ImageDraw.Draw(img)

                # คำนวณขนาดของตัวอักษรด้วย font.getbbox()
                # (left, top, right, bottom)
                bbox = font.getbbox(char)
                text_width = bbox[2] - bbox[0]
                text_height = bbox[3] - bbox[1]

                # คำนวณตำแหน่งตรงกลางของภาพ
                x = (img.width - text_width) / 2
                #y = (text_height - img.height) / 4
                #y = (img.height - text_height) / 2
    
                # วาดตัวอักษรตรงกลาง
                draw.text((x, -5), char, font=font, fill="black")
                img.save(char_folder / f"{char}_{font_number}.png")  # บันทึกภาพ
                print(f"Saved: {char_folder / f'{char}_{font_number}.png'}")
            font_number+=1

# %% [markdown]
# ### Padding method

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# กำหนดโฟลเดอร์
output_folder = Path("../data/raw_images/eng_lowercase")
folder_path = Path("../font/GoogleFont")

if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':
        try:
            font = ImageFont.truetype(str(font_file), 30)  # โหลดฟอนต์
        except Exception as e:
            print(f"Skipping font {font_file}: {e}")
            continue

        for char in "abcdefghijklmnopqrstuvwxyz":
            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / char
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y ทั่วไป
            y_offset = ascent - bbox[3]

            # ปรับตำแหน่ง y_offset เฉพาะจุด

            if(char == "b" or char == "d" or char == "h" or char == "k" or char == "l" or char == "t"):
                if(171 <= font_number <= 207):
                    y_offset+=3
                elif(217 <= font_number <= 253):
                    y_offset+=4
                elif(294 <= font_number <= 311):
                    y_offset+=2

            if(char == "a" or char == "e" or char == "s" or char == "u" or char == "o" or char == "w" or char == "x" or char == "z"):
                y_offset-=2
                if(64 <= font_number <= 68):
                    y_offset-=3
                elif(69 <= font_number <= 80):
                    y_offset-=3
                elif(111 <= font_number <= 122):
                    y_offset-=3
                elif(141 <= font_number <= 170):
                    y_offset-=3
                elif(171 <= font_number <= 207):
                    y_offset+=2
                elif(208 <= font_number <= 216):
                    y_offset-=3
                elif(217 <= font_number <= 253):
                    y_offset+=4
                if(278 <= font_number <= 293):
                    y_offset-=3

        
            if(char == "f"):
                if(171 <= font_number <= 207):
                    y_offset+=4
                elif(217 <= font_number <= 253):
                    y_offset+=5
                elif(294 <= font_number <= 311):
                    y_offset+=3

            if(char == "g"):
                y_offset+=1
                if(171 <= font_number <= 207):
                    y_offset+=4
                elif(217 <= font_number <= 253):
                    y_offset+=5
                elif(278 <= font_number <= 293):
                    y_offset-=2
                elif(294 <= font_number <= 311):
                    y_offset+=3

            if(char == "j"):
                y_offset+=3
                if(50 <= font_number <= 62 and not font_number == 56):
                    y_offset+=3
                if(87 <= font_number <= 89):
                    y_offset+=2
                if(171 <= font_number <= 207):
                    y_offset+=3
                elif(217 <= font_number <= 253):
                    y_offset+=4
                elif(294 <= font_number <= 311):
                    y_offset+=2

            if(char == "p" or char == "q" or char == "y"):
                y_offset+=1
                if(171 <= font_number <= 207):
                    y_offset+=4
                elif(217 <= font_number <= 253):
                    y_offset+=5
                elif(294 <= font_number <= 311):
                    y_offset+=3
            
            
            #if(char == "f"):y_offset+=1
            #if(char == "j"):y_offset+=3
            #if(char == "p"):y_offset+=1
            #if(char == "q"):y_offset+=1
            #if(char == "y"):y_offset+=1


            draw.text((0, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            output_path = char_folder / f"{char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")

# %% [markdown]
# ### Padding method with new font size

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# กำหนดโฟลเดอร์
output_folder = Path("../data/raw_images/eng_lowercase")
folder_path = Path("../font/GoogleFont")

if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':
        for char in "abcdefghijklmnopqrstuvwxyz":
            try:
                if(char == "j"):
                    font = ImageFont.truetype(str(font_file), 28)
                elif(char == "g" or char == "m" or char == "w" or char == "f"):
                    font = ImageFont.truetype(str(font_file), 34)
                elif(char == "b" or char == "d" or char == "h" or char == "k" or char == "l" or 
                     char == "t" or char == "p" or char == "q" or char == "y" or char == "i" ):
                    font = ImageFont.truetype(str(font_file), 36)
                elif(char == "a" or char == "c" or char == "e" or char == "s" or char == "m" or 
                     char == "o" or char == "r" or char == "s" or char == "n" or char == "o" or 
                     char == "u" or char == "v" or char == "w" or char == "x" or char == "z"):
                    font = ImageFont.truetype(str(font_file), 44)
            except Exception as e:
                print(f"Skipping font {font_file}: {e}")
                continue

            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / f"{char}_L"
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y ทั่วไป
            y_offset = ascent - bbox[3]

            # ปรับตำแหน่ง y_offset เฉพาะจุด
            # +ลง -ขึ้น
            if(char == "b" or char == "d" or char == "h" or char == "i" or char == "k" or char == "l" or char == "t"):
                if(50 <= font_number <= 63):
                    y_offset+=3
                elif(65 <= font_number <= 80):
                    y_offset-=2
                elif(111 <= font_number <= 122):
                    y_offset-=2
                elif(141 <= font_number <= 152):
                    y_offset+=2
                elif(159 <= font_number <= 170):
                    y_offset-=2
                elif(171 <= font_number <= 207):
                    y_offset+=3
                elif(208 <= font_number <= 216):
                    y_offset-=2
                elif(217 <= font_number <= 253):
                    y_offset+=5
                elif(278 <= font_number <= 293):
                    y_offset-=3
                elif(278 <= font_number <= 293):
                    y_offset-=3
                elif(294 <= font_number <= 311):
                    y_offset+=2
                elif(322 <= font_number <= 333):
                    y_offset+=2

            if(char == "a" or char == "c" or char == "e" or char == "s" or char == "m" or char == "o" or 
               char == "r" or char == "s" or char == "n" or char == "o" or char == "u" or char == "v" or
               char == "w" or char == "x" or char == "z"):
                y_offset-=2
                if(1 <= font_number <= 14):
                    y_offset-=2
                elif(15 <= font_number <= 49):
                    y_offset-=3
                elif(50 <= font_number <= 63):
                    y_offset+=1
                elif(64 <= font_number <= 80):
                    y_offset-=3
                elif(81 <= font_number <= 110):
                    y_offset-=3
                elif(111 <= font_number <= 122):
                    y_offset-=3
                elif(123 <= font_number <= 134):
                    y_offset-=2
                elif(141 <= font_number <= 158):
                    y_offset-=4
                elif(159 <= font_number <= 170):
                    y_offset-=7
                elif(171 <= font_number <= 207):
                    y_offset+=2
                elif(208 <= font_number <= 216):
                    y_offset-=3
                elif(217 <= font_number <= 253):
                    y_offset+=4
                elif(278 <= font_number <= 293):
                    y_offset-=4
                elif(294 <= font_number <= 315):
                    y_offset-=3
                elif(322 <= font_number <= 333):
                    y_offset-=1

        
            if(char == "f"):
                if(50 <= font_number <= 63):
                    y_offset+=3
                elif(65 <= font_number <= 80):
                    y_offset-=2
                elif(111 <= font_number <= 122):
                    y_off
png
# Saved: ..\data\raw_images\eng_lowercase\b_L\b_326.png
# Saved: ..\data\raw_images\eng_lowercase\c_L\c_326.png
# Saved: ..\data\raw_images\eng_lowercase\d_L\d_326.png
# Saved: ..\data\raw_images\eng_lowercase\e_L\e_326.png
# Saved: ..\data\raw_images\eng_lowercase\f_L\f_326.png
# Saved: ..\data\raw_images\eng_lowercase\g_L\g_326.png
# Saved: ..\data\raw_images\eng_lowercase\h_L\h_326.png
# Saved: ..\data\raw_images\eng_lowercase\i_L\i_326.png
# Saved: ..\data\raw_images\eng_lowercase\j_L\j_326.png
# Saved: ..\data\raw_images\eng_lowercase\k_L\k_326.png
# Saved: ..\data\raw_images\eng_lowercase\l_L\l_326.png
# Saved: ..\data\raw_images\eng_lowercase\m_L\m_326.png
# Saved: ..\data\raw_images\eng_lowercase\n_L\n_326.png
# Saved: ..\data\raw_images\eng_lowercase\o_L\o_326.png
# Saved: ..\data\raw_images\eng_lowercase\p_L\p_326.png
# Saved: ..\data\raw_images\eng_lowercase\q_L\q_326.png
# Saved: ..\data\raw_images\eng_lowercase\r_L\r_326.png
# Saved: ..\data\raw_images\eng_lowercase\s_L\s_326.png
# Saved: ..\data\raw_images\eng_lowercase\t_L\t_326.png
# Saved: ..\data\raw_images\eng_lowercase\u_L\u_326.png
# Saved: ..\data\raw_images\eng_lowercase\v_L\v_326.png
# Saved: ..\data\raw_images\eng_lowercase\w_L\w_326.png
# Saved: ..\data\raw_images\eng_lowercase\x_L\x_326.png
# Saved: ..\data\raw_images\eng_lowercase\y_L\y_326.png
# Saved: ..\data\raw_images\eng_lowercase\z_L\z_326.png
# Saved: ..\data\raw_images\eng_lowercase\a_L\a_327.png
# Saved: ..\data\raw_images\eng_lowercase\b_L\b_327.png
# Saved: ..\data\raw_images\eng_lowercase\c_L\c_327.png
# Saved: ..\data\raw_images\eng_lowercase\d_L\d_327.png
# Saved: ..\data\raw_images\eng_lowercase\e_L\e_327.png
# Saved: ..\data\raw_images\eng_lowercase\f_L\f_327.png
# Saved: ..\data\raw_images\eng_lowercase\g_L\g_327.png
# Saved: ..\data\raw_images\eng_lowercase\h_L\h_327.png
# Saved: ..\data\raw_images\eng_lowercase\i_L\i_327.png
# Saved: ..\data\raw_images\eng_lowercase\j_L\j_327.png
# Saved: ..\data\raw_images\eng_lowercase\k_L\k_327.png
# Saved: ..\data\raw_images\eng_lowercase\l_L\l_327.png
# Saved: ..\data\raw_images\eng_lowercase\m_L\m_327.png
# Saved: ..\data\raw_images\eng_lowercase\n_L\n_327.png
# Saved: ..\data\raw_images\eng_lowercase\o_L\o_327.png
# Saved: ..\data\raw_images\eng_lowercase\p_L\p_327.png
# Saved: ..\data\raw_images\eng_lowercase\q_L\q_327.png
# Saved: ..\data\raw_images\eng_lowercase\r_L\r_327.png
# Saved: ..\data\raw_images\eng_lowercase\s_L\s_327.png
# Saved: ..\data\raw_images\eng_lowercase\t_L\t_327.png
# Saved: ..\data\raw_images\eng_lowercase\u_L\u_327.png
# Saved: ..\data\raw_images\eng_lowercase\v_L\v_327.png
# Saved: ..\data\raw_images\eng_lowercase\w_L\w_327.png
# Saved: ..\data\raw_images\eng_lowercase\x_L\x_327.png
# Saved: ..\data\raw_images\eng_lowercase\y_L\y_327.png
# Saved: ..\data\raw_images\eng_lowercase\z_L\z_327.png
# Saved: ..\data\raw_images\eng_lowercase\a_L\a_328.png
# Saved: ..\data\raw_images\eng_lowercase\b_L\b_328.png
# Saved: ..\data\raw_images\eng_lowercase\c_L\c_328.png
# Saved: ..\data\raw_images\eng_lowercase\d_L\d_328.png
# Saved: ..\data\raw_images\eng_lowercase\e_L\e_328.png
# Saved: ..\data\raw_images\eng_lowercase\f_L\f_328.png
# Saved: ..\data\raw_images\eng_lowercase\g_L\g_328.png
# Saved: ..\data\raw_images\eng_lowercase\h_L\h_328.png
# Saved: ..\data\raw_images\eng_lowercase\i_L\i_328.png
# Saved: ..\data\raw_images\eng_lowercase\j_L\j_328.png
# Saved: ..\data\raw_images\eng_lowercase\k_L\k_328.png
# Saved: ..\data\raw_images\eng_lowercase\l_L\l_328.png
# Saved: ..\data\raw_images\eng_lowercase\m_L\m_328.png
# Saved: ..\data\raw_images\eng_lowercase\n_L\n_328.png
# Saved: ..\data\raw_images\eng_lowercase\o_L\o_328.png
# Saved: ..\data\raw_images\eng_lowercase\p_L\p_328.png
# Saved: ..\data\raw_images\eng_lowercase\q_L\q_328.png
# Saved: ..\data\raw_images\eng_lowercase\r_L\r_328.png
# Saved: ..\data\raw_images\eng_lowercase\s_L\s_328.png
# Saved: ..\data\raw_images\eng_lowercase\t_L\t_328.png
# Saved: ..\data\raw_images\eng_lowercase\u_L\u_328.png
# Saved: ..\data\raw_images\eng_lowercase\v_L\v_328.png
# Saved: ..\data\raw_images\eng_lowercase\w_L\w_328.png
# Saved: ..\data\raw_images\eng_lowercase\x_L\x_328.png
# Saved: ..\data\raw_images\eng_lowercase\y_L\y_328.png
# Saved: ..\data\raw_images\eng_lowercase\z_L\z_328.png
# Saved: ..\data\raw_images\eng_lowercase\a_L\a_329.png
# Saved: ..\data\raw_images\eng_lowercase\b_L\b_329.png
# Saved: ..\data\raw_images\eng_lowercase\c_L\c_329.png
# Saved: ..\data\raw_images\eng_lowercase\d_L\d_329.png
# Saved: ..\data\raw_images\eng_lowercase\e_L\e_329.png
# Saved: ..\data\raw_images\eng_lowercase\f_L\f_329.png
# Saved: ..\data\raw_images\eng_lowercase\g_L\g_329.png
# Saved: ..\data\raw_images\eng_lowercase\h_L\h_329.png
# Saved: ..\data\raw_images\eng_lowercase\i_L\i_329.png
# Saved: ..\data\raw_images\eng_lowercase\j_L\j_329.png
# Saved: ..\data\raw_images\eng_lowercase\k_L\k_329.png
# Saved: ..\data\raw_images\eng_lowercase\l_L\l_329.png
# Saved: ..\data\raw_images\eng_lowercase\m_L\m_329.png
# Saved: ..\data\raw_images\eng_lowercase\n_L\n_329.png
# Saved: ..\data\raw_images\eng_lowercase\o_L\o_329.png
# Saved: ..\data\raw_images\eng_lowercase\p_L\p_329.png
# Saved: ..\data\raw_images\eng_lowercase\q_L\q_329.png
# Saved: ..\data\raw_images\eng_lowercase\r_L\r_329.png
# Saved: ..\data\raw_images\eng_lowercase\s_L\s_329.png
# Saved: ..\data\raw_images\eng_lowercase\t_L\t_329.png
# Saved: ..\data\raw_images\eng_lowercase\u_L\u_329.png
# Saved: ..\data\raw_images\eng_lowercase\v_L\v_329.png
# Saved: ..\data\raw_images\eng_lowercase\w_L\w_329.png
# Saved: ..\data\raw_images\eng_lowercase\x_L\x_329.png
# Saved: ..\data\raw_images\eng_lowercase\y_L\y_329.png
# Saved: ..\data\raw_images\eng_lowercase\z_L\z_329.png
# Saved: ..\data\raw_images\eng_lowercase\a_L\a_330.png
# Saved: ..\data\raw_images\eng_lowercase\b_L\b_330.png
# Saved: ..\data\raw_images\eng_lowercase\c_L\c_330.png
# Saved: ..\data\raw_images\eng_lowercase\d_L\d_330.png
# Saved: ..\data\raw_images\eng_lowercase\e_L\e_330.png
# Saved: ..\data\raw_images\eng_lowercase\f_L\f_330.png
# Saved: ..\data\raw_images\eng_lowercase\g_L\g_330.png
# Saved: ..\data\raw_images\eng_lowercase\h_L\h_330.png
# Saved: ..\data\raw_images\eng_lowercase\i_L\i_330.png
# Saved: ..\data\raw_images\eng_lowercase\j_L\j_330.png
# Saved: ..\data\raw_images\eng_lowercase\k_L\k_330.png
# Saved: ..\data\raw_images\eng_lowercase\l_L\l_330.png
# Saved: ..\data\raw_images\eng_lowercase\m_L\m_330.png
# Saved: ..\data\raw_images\eng_lowercase\n_L\n_330.png
# Saved: ..\data\raw_images\eng_lowercase\o_L\o_330.png
# Saved: ..\data\raw_images\eng_lowercase\p_L\p_330.png
# Saved: ..\data\raw_images\eng_lowercase\q_L\q_330.png
# Saved: ..\data\raw_images\eng_lowercase\r_L\r_330.png
# Saved: ..\data\raw_images\eng_lowercase\s_L\s_330.png
# Saved: ..\data\raw_images\eng_lowercase\t_L\t_330.png
# Saved: ..\data\raw_images\eng_lowercase\u_L\u_330.png
# Saved: ..\data\raw_images\eng_lowercase\v_L\v_330.png
# Saved: ..\data\raw_images\eng_lowercase\w_L\w_330.png
# Saved: ..\data\raw_images\eng_lowercase\x_L\x_330.png
# Saved: ..\data\raw_images\eng_lowercase\y_L\y_330.png
# Saved: ..\data\raw_images\eng_lowercase\z_L\z_330.png
# Saved: ..\data\raw_images\eng_lowercase\a_L\a_331.png
# Saved: ..\data\raw_images\eng_lowercase\b_L\b_331.png
# Saved: ..\data\raw_images\eng_lowercase\c_L\c_331.png
# Saved: ..\data\raw_images\eng_lowercase\d_L\d_331.png
# Saved: ..\data\raw_images\eng_lowercase\e_L\e_331.png
# Saved: ..\data\raw_images\eng_lowercase\f_L\f_331.png
# Saved: ..\data\raw_images\eng_lowercase\g_L\g_331.png
# Saved: ..\data\raw_images\eng_lowercase\h_L\h_331.png
# Saved: ..\data\raw_images\eng_lowercase\i_L\i_331.png
# Saved: ..\data\raw_images\eng_lowercase\j_L\j_331.png
# Saved: ..\data\raw_images\eng_lowercase\k_L\k_331.png
# Saved: ..\data\raw_images\eng_lowercase\l_L\l_331.png
# Saved: ..\data\raw_images\eng_lowercase\m_L\m_331.png
# Saved: ..\data\raw_images\eng_lowercase\n_L\n_331.png
# Saved: ..\data\raw_images\eng_lowercase\o_L\o_331.png
# Saved: ..\data\raw_images\eng_lowercase\p_L\p_331.png
# Saved: ..\data\raw_images\eng_lowercase\q_L\q_331.png
# Saved: ..\data\raw_images\eng_lowercase\r_L\r_331.png
# Saved: ..\data\raw_images\eng_lowercase\s_L\s_331.png
# Saved: ..\data\raw_images\eng_lowercase\t_L\t_331.png
# Saved: ..\data\raw_images\eng_lowercase\u_L\u_331.png
# Saved: ..\data\raw_images\eng_lowercase\v_L\v_331.png
# Saved: ..\data\raw_images\eng_lowercase\w_L\w_331.png
# Saved: ..\data\raw_images\eng_lowercase\x_L\x_331.png
# Saved: ..\data\raw_images\eng_lowercase\y_L\y_331.png
# Saved: ..\data\raw_images\eng_lowercase\z_L\z_331.png
# Saved: ..\data\raw_images\eng_lowercase\a_L\a_332.png
# Saved: ..\data\raw_images\eng_lowercase\b_L\b_332.png
# Saved: ..\data\raw_images\eng_lowercase\c_L\c_332.png
# Saved: ..\data\raw_images\eng_lowercase\d_L\d_332.png
# Saved: ..\data\raw_images\eng_lowercase\e_L\e_332.png
# Saved: ..\data\raw_images\eng_lowercase\f_L\f_332.png
# Saved: ..\data\raw_images\eng_lowercase\g_L\g_332.png
# Saved: ..\data\raw_images\eng_lowercase\h_L\h_332.png
# Saved: ..\data\raw_images\eng_lowercase\i_L\i_332.png
# Saved: ..\data\raw_images\eng_lowercase\j_L\j_332.png
# Saved: ..\data\raw_images\eng_lowercase\k_L\k_332.png
# Saved: ..\data\raw_images\eng_lowercase\l_L\l_332.png
# Saved: ..\data\raw_images\eng_lowercase\m_L\m_332.png
# Saved: ..\data\raw_images\eng_lowercase\n_L\n_332.png
# Saved: ..\data\raw_images\eng_lowercase\o_L\o_332.png
# Saved: ..\data\raw_images\eng_lowercase\p_L\p_332.png
# Saved: ..\data\raw_images\eng_lowercase\q_L\q_332.png
# Saved: ..\data\raw_images\eng_lowercase\r_L\r_332.png
# Saved: ..\data\raw_images\eng_lowercase\s_L\s_332.png
# Saved: ..\data\raw_images\eng_lowercase\t_L\t_332.png
# Saved: ..\data\raw_images\eng_lowercase\u_L\u_332.png
# Saved: ..\data\raw_images\eng_lowercase\v_L\v_332.png
# Saved: ..\data\raw_images\eng_lowercase\w_L\w_332.png
# Saved: ..\data\raw_images\eng_lowercase\x_L\x_332.png
# Saved: ..\data\raw_images\eng_lowercase\y_L\y_332.png
# Saved: ..\data\raw_images\eng_lowercase\z_L\z_332.png
# Saved: ..\data\raw_images\eng_lowercase\a_L\a_333.png
# Saved: ..\data\raw_images\eng_lowercase\b_L\b_333.png
# Saved: ..\data\raw_images\eng_lowercase\c_L\c_333.png
# Saved: ..\data\raw_images\eng_lowercase\d_L\d_333.png
# Saved: ..\data\raw_images\eng_lowercase\e_L\e_333.png
# Saved: ..\data\raw_images\eng_lowercase\f_L\f_333.png
# Saved: ..\data\raw_images\eng_lowercase\g_L\g_333.png
# Saved: ..\data\raw_images\eng_lowercase\h_L\h_333.png
# Saved: ..\data\raw_images\eng_lowercase\i_L\i_333.png
# Saved: ..\data\raw_images\eng_lowercase\j_L\j_333.png
# Saved: ..\data\raw_images\eng_lowercase\k_L\k_333.png
# Saved: ..\data\raw_images\eng_lowercase\l_L\l_333.png
# Saved: ..\data\raw_images\eng_lowercase\m_L\m_333.png
# Saved: ..\data\raw_images\eng_lowercase\n_L\n_333.png
# Saved: ..\data\raw_images\eng_lowercase\o_L\o_333.png
# Saved: ..\data\raw_images\eng_lowercase\p_L\p_333.png
# Saved: ..\data\raw_images\eng_lowercase\q_L\q_333.png
# Saved: ..\data\raw_images\eng_lowercase\r_L\r_333.png
# Saved: ..\data\raw_images\eng_lowercase\s_L\s_333.png
# Saved: ..\data\raw_images\eng_lowercase\t_L\t_333.png
# Saved: ..\data\raw_images\eng_lowercase\u_L\u_333.png
# Saved: ..\data\raw_images\eng_lowercase\v_L\v_333.png
# Saved: ..\data\raw_images\eng_lowercase\w_L\w_333.png
# Saved: ..\data\raw_images\eng_lowercase\x_L\x_333.png
# Saved: ..\data\raw_images\eng_lowercase\y_L\y_333.png
# Saved: ..\data\raw_images\eng_lowercase\z_L\z_333.png

# %% [markdown]
# ## Thai Consonant

# %% [markdown]
# ### Classic

# %%
import os

# ระบุโฟลเดอร์ที่ต้องการอ่านไฟล์ทั้งหมด
output_folder = "dataset/th_C"
folder_path = "font/GoogleFont"
font_number = 1

# อ่านไฟล์ทั้งหมดในโฟลเดอร์และโฟลเดอร์ย่อย
# อ่านเฉพาะไฟล์ .ttf ในโฟลเดอร์และโฟลเดอร์ย่อย
for root, dirs, files in os.walk(folder_path):
    for filename in files:
        if filename.endswith(".ttf"):  # ตรวจสอบนามสกุลไฟล์
            font_file_path = os.path.join(root, filename)
            font = ImageFont.truetype(font_file_path, 48)
            for char in "กขฃคฅฆงจฉชซฌญฎฏฐฑฒณดตถทธนบปผฝพฟภมยรรฤลฦวศษสหฬอฮ":
                img = Image.new("RGB", (64, 64), "white")
                draw = ImageDraw.Draw(img)

                # คำนวณขนาดของตัวอักษรด้วย font.getbbox()
                # (left, top, right, bottom)
                bbox = font.getbbox(char)
                text_width = bbox[2] - bbox[0]
                text_height = bbox[3] - bbox[1]

                # คำนวณตำแหน่งตรงกลางของภาพ
                x = (img.width - text_width) / 2
                y = (text_height - img.height) / 4
    
                # วาดตัวอักษรตรงกลาง
                draw.text((x, -10), char, font=font, fill="black")

                # บันทึกไฟล์ในโฟลเดอร์ที่กำหนด
                img.save(os.path.join(output_folder, f"{char}_{font_number}.png"))

            font_number+=1

# %% [markdown]
# ### Padding method

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# กำหนดโฟลเดอร์
output_folder = Path("../data/raw_images/thai_consonants")
folder_path = Path("../font/GoogleFont")

if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':
        try:
            font = ImageFont.truetype(str(font_file), 28)  # โหลดฟอนต์
        except Exception as e:
            print(f"Skipping font {font_file}: {e}")
            continue

        for char in "กขฃคฅฆงจฉชซฌญฎฏฐฑฒณดตถทธนบปผฝพฟภมยรรฤลฦวศษสหฬอฮ":
            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / char
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y
            y_offset = ascent - bbox[3]
            draw.text((0, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            output_path = char_folder / f"{char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")
# Out:
# Saved: ..\data\raw_images\thai_consonants\ก\ก_1.png
# Saved: ..\data\raw_images\thai_consonants\ข\ข_1.png
# Saved: ..\data\raw_images\thai_consonants\ฃ\ฃ_1.png
# Saved: ..\data\raw_images\thai_consonants\ค\ค_1.png
# Saved: ..\data\raw_images\thai_consonants\ฅ\ฅ_1.png
# Saved: ..\data\raw_images\thai_consonants\ฆ\ฆ_1.png
# Saved: ..\data\raw_images\thai_consonants\ง\ง_1.png
# Saved: ..\data\raw_images\thai_consonants\จ\จ_1.png
# Saved: ..\data\raw_images\thai_consonants\ฉ\ฉ_1.png
# Saved: ..\data\raw_images\thai_consonants\ช\ช_1.png
# Saved: ..\data\raw_images\thai_consonants\ซ\ซ_1.png
# Saved: ..\data\raw_images\thai_consonants\ฌ\ฌ_1.png
# Saved: ..\data\raw_images\thai_consonants\ญ\ญ_1.png
# Saved: ..\data\raw_images\thai_consonants\ฎ\ฎ_1.png
# Saved: ..\data\raw_images\thai_consonants\ฏ\ฏ_1.png
# Saved: ..\data\raw_images\thai_consonants\ฐ\ฐ_1.png
# Saved: ..\data\raw_images\thai_consonants\ฑ\ฑ_1.png
# Saved: ..\data\raw_images\thai_consonants\ฒ\ฒ_1.png
# Saved: ..\data\raw_images\thai_consonants\ณ\ณ_1.png
# Saved: ..\data\raw_images\thai_consonants\ด\ด_1.png
# Saved: ..\data\raw_images\thai_consonants\ต\ต_1.png
# Saved: ..\data\raw_images\thai_consonants\ถ\ถ_1.png
# Saved: ..\data\raw_images\thai_consonants\ท\ท_1.png
# Saved: ..\data\raw_images\thai_consonants\ธ\ธ_1.png
# Saved: ..\data\raw_images\thai_consonants\น\น_1.png
# Saved: ..\data\raw_images\thai_consonants\บ\บ_1.png
# Saved: ..\data\raw_images\thai_consonants\ป\ป_1.png
# Saved: ..\data\raw_images\thai_consonants\ผ\ผ_1.png
# Saved: ..\data\raw_images\thai_consonants\ฝ\ฝ_1.png
# Saved: ..\data\raw_images\thai_consonants\พ\พ_1.png
# Saved: ..\data\raw_images\thai_consonants\ฟ\ฟ_1.png
# Saved: ..\data\raw_images\thai_consonants\ภ\ภ_1.png
# Saved: ..\data\raw_images\thai_consonants\ม\ม_1.png
# Saved: ..\data\raw_images\thai_consonants\ย\ย_1.png
# Saved: ..\data\raw_images\thai_consonants\ร\ร_1.png
# Saved: ..\data\raw_images\thai_consonants\ร\ร_1.png
# Saved: ..\data\raw_images\thai_consonants\ฤ\ฤ_1.png
# Saved: ..\data\raw_images\thai_consonants\ล\ล_1.png
# Saved: ..\data\raw_images\thai_consonants\ฦ\ฦ_1.png
# Saved: ..\data\raw_images\thai_consonants\ว\ว_1.png
# Saved: ..\data\raw_images\thai_consonants\ศ\ศ_1.png
# Saved: ..\data\raw_images\thai_consonants\ษ\ษ_1.png
# Saved: ..\data\raw_images\thai_consonants\ส\ส_1.png
# Saved: ..\data\raw_images\thai_consonants\ห\ห_1.png
# Saved: ..\data\raw_images\thai_consonants\ฬ\ฬ_1.png
# Saved: ..\data\raw_images\thai_consonants\อ\อ_1.png
# Saved: ..\data\raw_images\thai_consonants\ฮ\ฮ_1.png
# Saved: ..\data\raw_images\thai_consonants\ก\ก_2.png
# Saved: ..\data\raw_images\thai_consonants\ข\ข_2.png
# Saved: ..\data\raw_images\thai_consonants\ฃ\ฃ_2.png
# Saved: ..\data\raw_images\thai_consonants\ค\ค_2.png
# Saved: ..\data\raw_images\thai_consonants\ฅ\ฅ_2.png
# Saved: ..\data\raw_images\thai_consonants\ฆ\ฆ_2.png
# Saved: ..\data\raw_images\thai_consonants\ง\ง_2.png
# Saved: ..\data\raw_images\thai_consonants\จ\จ_2.png
# Saved: ..\data\raw_images\thai_consonants\ฉ\ฉ_2.png
# Saved: ..\data\raw_images\thai_consonants\ช\ช_2.png
# Saved: ..\data\raw_images\thai_consonants\ซ\ซ_2.png
# Saved: ..\data\raw_images\thai_consonants\ฌ\ฌ_2.png
# Saved: ..\data\raw_images\thai_consonants\ญ\ญ_2.png
# Saved: ..\data\raw_images\thai_consonants\ฎ\ฎ_2.png
# Saved: ..\data\raw_images\thai_consonants\ฏ\ฏ_2.png
# Saved: ..\data\raw_images\thai_consonants\ฐ\ฐ_2.png
# Saved: ..\data\raw_images\thai_consonants\ฑ\ฑ_2.png
# Saved: ..\data\raw_images\thai_consonants\ฒ\ฒ_2.png
# Saved: ..\data\raw_images\thai_consonants\ณ\ณ_2.png
# Saved: ..\data\raw_images\thai_consonants\ด\ด_2.png
# Saved: ..\data\raw_images\thai_consonants\ต\ต_2.png
# Saved: ..\data\raw_images\thai_consonants\ถ\ถ_2.png
# Saved: ..\data\raw_images\thai_consonants\ท\ท_2.png
# Saved: ..\data\raw_images\thai_consonants\ธ\ธ_2.png
# Saved: ..\data\raw_images\thai_consonants\น\น_2.png
# Saved: ..\data\raw_images\thai_consonants\บ\บ_2.png
# Saved: ..\data\raw_images\thai_consonants\ป\ป_2.png
# Saved: ..\data\raw_images\thai_consonants\ผ\ผ_2.png
# Saved: ..\data\raw_images\thai_consonants\ฝ\ฝ_2.png
# Saved: ..\data\raw_images\thai_consonants\พ\พ_2.png
# Saved: ..\data\raw_images\thai_consonants\ฟ\ฟ_2.png
# Saved: ..\data\raw_images\thai_consonants\ภ\ภ_2.png
# Saved: ..\data\raw_images\thai_consonants\ม\ม_2.png
# Saved: ..\data\raw_images\thai_consonants\ย\ย_2.png
# Saved: ..\data\raw_images\thai_consonants\ร\ร_2.png
# Saved: ..\data\raw_images\thai_consonants\ร\ร_2.png
# Saved: ..\data\raw_images\thai_consonants\ฤ\ฤ_2.png
# Saved: ..\data\raw_images\thai_consonants\ล\ล_2.png
# Saved: ..\data\raw_images\thai_consonants\ฦ\ฦ_2.png
# Saved: ..\data\raw_images\thai_consonants\ว\ว_2.png
# Saved: ..\data\raw_images\thai_consonants\ศ\ศ_2.png
# Saved: ..\data\raw_images\thai_consonants\ษ\ษ_2.png
# Saved: ..\data\raw_images\thai_consonants\ส\ส_2.png
# Saved: ..\data\raw_images\thai_consonants\ห\ห_2.png
# Saved: ..\data\raw_images\thai_consonants\ฬ\ฬ_2.png
# Saved: ..\data\raw_images\thai_consonants\อ\อ_2.png
# Saved: ..\data\raw_images\thai_consonants\ฮ\ฮ_2.png
# Saved: ..\data\raw_images\thai_consonants\ก\ก_3.png
# Saved: ..\data\raw_images\thai_consonants\ข\ข_3.png
# Saved: ..\data\raw_images\thai_consonants\ฃ\ฃ_3.png
# Saved: ..\data\raw_images\thai_consonants\ค\ค_3.png
# Saved: ..\data\raw_images\thai_consonants\ฅ\ฅ_3.png
# Saved: ..\data\raw_images\thai_consonants\ฆ\ฆ_3.png
# Saved: ..\data\raw_images\thai_consonants\ง\ง_3.png
# Saved: ..\data\raw_images\thai_consonants\จ\จ_3.png
# Saved: ..\data\raw_images\thai_consonants\ฉ\ฉ_3.png
# Saved: ..\data\raw_images\thai_consonants\ช\ช_3.png
# Saved: ..\data\raw_images\thai_consonants\ซ\ซ_3.png
# Saved: ..\data\raw_images\thai_consonants\ฌ\ฌ_3.png
# Saved: ..\data\raw_images\thai_consonants\ญ\ญ_3.png
# Saved: ..\data\raw_images\thai_consonants\ฎ\ฎ_3.png
# Saved: ..\data\raw_images\thai_consonants\ฏ\ฏ_3.png
# Saved: ..\data\raw_images\thai_consonants\ฐ\ฐ_3.png
# Saved: ..\data\raw_images\thai_consonants\ฑ\ฑ_3.png
# Saved: ..\data\raw_images\thai_consonants\ฒ\ฒ_3.png
# Saved: ..\data\raw_images\thai_consonants\ณ\ณ_3.png
# Saved: ..\data\raw_images\thai_consonants\ด\ด_3.png
# Saved: ..\data\raw_images\thai_consonants\ต\ต_3.png
# Saved: ..\data\raw_images\thai_consonants\ถ\ถ_3.png
# Saved: ..\data\raw_images\thai_consonants\ท\ท_3.png
# Saved: ..\data\raw_images\thai_consonants\ธ\ธ
png
# Saved: ..\data\raw_images\thai_consonants\ร\ร_333.png
# Saved: ..\data\raw_images\thai_consonants\ร\ร_333.png
# Saved: ..\data\raw_images\thai_consonants\ฤ\ฤ_333.png
# Saved: ..\data\raw_images\thai_consonants\ล\ล_333.png
# Saved: ..\data\raw_images\thai_consonants\ฦ\ฦ_333.png
# Saved: ..\data\raw_images\thai_consonants\ว\ว_333.png
# Saved: ..\data\raw_images\thai_consonants\ศ\ศ_333.png
# Saved: ..\data\raw_images\thai_consonants\ษ\ษ_333.png
# Saved: ..\data\raw_images\thai_consonants\ส\ส_333.png
# Saved: ..\data\raw_images\thai_consonants\ห\ห_333.png
# Saved: ..\data\raw_images\thai_consonants\ฬ\ฬ_333.png
# Saved: ..\data\raw_images\thai_consonants\อ\อ_333.png
# Saved: ..\data\raw_images\thai_consonants\ฮ\ฮ_333.png

# %%
import os

# ระบุโฟลเดอร์ที่ต้องการอ่านไฟล์ทั้งหมด
output_folder = "dataset/en_L"
folder_path = "font/GoogleFont"
font_number = 1

# อ่านไฟล์ทั้งหมดในโฟลเดอร์และโฟลเดอร์ย่อย
# อ่านเฉพาะไฟล์ .ttf ในโฟลเดอร์และโฟลเดอร์ย่อย
for root, dirs, files in os.walk(folder_path):
    for filename in files:
        if filename.endswith(".ttf"):  # ตรวจสอบนามสกุลไฟล์
            font_file_path = os.path.join(root, filename)
            font = ImageFont.truetype(font_file_path, 48)
            for char in "abcdefghijklmnopqrstuvwxyz":
                img = Image.new("RGB", (64, 64), "white")
                draw = ImageDraw.Draw(img)

                # คำนวณขนาดของตัวอักษรด้วย font.getbbox()
                # (left, top, right, bottom)
                bbox = font.getbbox(char)
                text_width = bbox[2] - bbox[0]
                text_height = bbox[3] - bbox[1]

                # คำนวณตำแหน่งตรงกลางของภาพ
                x = (img.width - text_width) / 2
                y = (text_height - img.height) / 4
    
                # วาดตัวอักษรตรงกลาง
                draw.text((x, -10), char, font=font, fill="black")

                # บันทึกไฟล์ในโฟลเดอร์ที่กำหนด
                img.save(os.path.join(output_folder, f"{char}_{font_number}.png"))

            font_number+=1

# %%
font_path = Path("font/GoogleFont")
type_char_path = Path("dataset/en")
char_number = 1

for file in font_path.rglob("*.ttf"):
    font = ImageFont.truetype(file, 48)
    for char in "abcdefghijklmnopqrstuvwxyz":
        char_path = Path(f"{type_char_path}/{char}_L")
        print(char_path)
        char_path.mkdir(parents=True, exist_ok=True)

        char_img = Image.new("RGB", (64, 64), "white")
        draw = ImageDraw.Draw(char_img)

        # คำนวณขนาดของตัวอักษรด้วย font.getbbox()
        # (left, top, right, bottom)
        bbox = font.getbbox(char)
        text_width = bbox[2] - bbox[0]
        text_height = bbox[3] - bbox[1]

        # คำนวณตำแหน่งตรงกลางของภาพ
        x = (char_img.width - text_width) / 2
        y = (text_height - char_img.height) / 4

        # วาดตัวอักษรตรงกลาง
        draw.text((x, -10), char, font=font, fill="black")

        # บันทึกไฟล์ในโฟลเดอร์ที่กำหนด
        char_img.save(os.path.join(char_path, f"{char}_L_{char_number}.png"))
    char_number+=1

# %% [markdown]
# ## Arabic numerals

# %% [markdown]
# ### Classic method

# %%
output_folder = Path("../data/raw_images/arabic_numerals")
folder_path = Path("../font/GoogleFont")
font_number = 1

for font_file in folder_path.rglob("*.ttf"):  # ลูปภายในโฟลเดอร์ font
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':  # ตรวจสอบเฉพาะไฟล์ฟอนต์
            font = ImageFont.truetype(str(font_file), 28)  # โหลดฟอนต์
            for char in "0123456789":
                # สร้างโฟลเดอร์สำหรับตัวอักษร
                char_folder = output_folder / char
                char_folder.mkdir(parents=True, exist_ok=True)  # ถ้าโฟลเดอร์มีอยู่แล้ว จะไม่เกิดข้อผิดพลาด

                img = Image.new("L", (32, 32), "white")
                draw = ImageDraw.Draw(img)

                # คำนวณขนาดของตัวอักษรด้วย font.getbbox()
                # (left, top, right, bottom)
                bbox = font.getbbox(char)
                text_width = bbox[2] - bbox[0]
                text_height = bbox[3] - bbox[1]

                # คำนวณตำแหน่งตรงกลางของภาพ
                x = (img.width - text_width) / 2
                y = (img.height - text_height*2) / 2

                y_manual_adjustment = -5

                #if(char == "8") : y_manual_adjustment = y
                
                # วาดตัวอักษรตรงกลาง
                draw.text((x, y_manual_adjustment), char, font=font, fill="black")
                img.save(char_folder / f"{char}_{font_number}.png")  # บันทึกภาพ
                print(f"Saved: {char_folder / f'{char}_{font_number}.png'}")
            font_number+=1

# %% [markdown]
# ### Padding method

# %%
from PIL import Image, ImageDraw, ImageFont, ImageOps
from pathlib import Path

# กำหนดโฟลเดอร์
output_folder = Path("../data/raw_images/arabic_numerals")
folder_path = Path("../font/GoogleFont")

if not folder_path.exists():
    print(f"Error: Font folder does not exist at {folder_path}")
    exit(1)
output_folder.mkdir(parents=True, exist_ok=True)

# เริ่มสร้างภาพ
for font_number, font_file in enumerate(folder_path.rglob("*.ttf"), start=1):
    if font_file.is_file() and font_file.suffix.lower() == '.ttf':
        try:
            font = ImageFont.truetype(str(font_file), 36)  # โหลดฟอนต์
        except Exception as e:
            print(f"Skipping font {font_file}: {e}")
            continue

        for char in "0123456789":
            # สร้างโฟลเดอร์สำหรับตัวเลข
            char_folder = output_folder / char
            char_folder.mkdir(parents=True, exist_ok=True)

            # คำนวณ Ascent และ Descent ของฟอนต์
            ascent, descent = font.getmetrics()

            # คำนวณ Bounding Box
            dummy_image = Image.new("L", (1, 1))
            draw = ImageDraw.Draw(dummy_image)
            bbox = draw.textbbox((0, 0), char, font=font)

            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]

            # สร้างภาพพอดีตัวอักษร
            image = Image.new('L', (text_width, ascent + descent), color=0)
            draw = ImageDraw.Draw(image)

            # ปรับตำแหน่ง Y
            y_offset = ascent - bbox[3]

            if(159 <= font_number <= 170):
                y_offset-=2
            elif(171 <= font_number <= 207):
                y_offset+=3
            elif(217 <= font_number <= 253):
                y_offset+=4
            elif(278 <= font_number <= 293):
                y_offset-=2
            elif(294 <= font_number <= 311):
                y_offset+=2

            draw.text((0, y_offset), char, fill=255, font=font)

            # เพิ่ม Padding เพื่อให้ได้ขนาด 32x32
            desired_size = 32
            delta_w = desired_size - image.width
            delta_h = desired_size - image.height
            padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
            padded_image = ImageOps.expand(image, padding, fill=0)

            # บันทึกภาพ
            output_path = char_folder / f"{char}_{font_number}.png"
            padded_image.save(output_path)
            print(f"Saved: {output_path}")
# Out:
# Saved: ..\data\raw_images\arabic_numerals\0\0_1.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_1.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_1.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_1.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_1.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_1.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_1.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_1.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_1.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_1.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_2.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_2.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_2.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_2.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_2.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_2.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_2.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_2.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_2.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_2.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_3.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_3.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_3.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_3.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_3.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_3.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_3.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_3.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_3.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_3.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_4.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_4.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_4.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_4.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_4.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_4.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_4.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_4.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_4.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_4.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_5.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_5.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_5.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_5.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_5.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_5.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_5.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_5.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_5.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_5.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_6.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_6.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_6.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_6.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_6.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_6.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_6.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_6.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_6.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_6.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_7.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_7.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_7.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_7.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_7.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_7.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_7.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_7.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_7.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_7.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_8.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_8.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_8.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_8.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_8.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_8.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_8.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_8.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_8.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_8.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_9.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_9.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_9.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_9.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_9.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_9.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_9.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_9.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_9.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_9.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_10.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_10.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_10.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_10.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_10.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_10.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_10.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_10.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_10.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_10.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_11.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_11.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_11.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_11.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_11.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_11.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_11.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_11.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_11.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_11.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_12.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_12.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_12.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_12.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_12.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_12.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_12.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_12.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_12.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_12.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_13.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_13.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_13.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_13.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_13.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_13.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_13.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_13.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_13.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_13.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_14.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_14.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_14.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_14.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_14.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_14.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_14.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_14.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_14.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_14.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_15.png
# Saved: ..\data\raw_images\arabic_numerals\1\1_15.png
# Saved: ..\data\raw_images\arabic_numerals\2\2_15.png
# Saved: ..\data\raw_images\arabic_numerals\3\3_15.png
# Saved: ..\data\raw_images\arabic_numerals\4\4_15.png
# Saved: ..\data\raw_images\arabic_numerals\5\5_15.png
# Saved: ..\data\raw_images\arabic_numerals\6\6_15.png
# Saved: ..\data\raw_images\arabic_numerals\7\7_15.png
# Saved: ..\data\raw_images\arabic_numerals\8\8_15.png
# Saved: ..\data\raw_images\arabic_numerals\9\9_15.png
# Saved: ..\data\raw_images\arabic_numerals\0\0_16.png
# Saved: ..\data\raw_images\arabic_numerals\1\1